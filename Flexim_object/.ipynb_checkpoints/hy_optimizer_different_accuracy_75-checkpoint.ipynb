# %%
import pandas as pd
data = pd.read_csv("./"+"all_stocks_5yr.csv",index_col = None)
data = data["close"].values

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
data = scaler.fit_transform(data.reshape(-1,1))

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import skopt
from scikeras.wrappers import KerasClassifier
import tensorflow as tf
from modAL.batch import uncertainty_batch_sampling
#from Active_Emulate_TestD_gp import Active_Emulate_Test as ace
#from NN import NN as nn
from keras.utils.np_utils import to_categorical
from sklearn.preprocessing import MinMaxScaler
from dtaidistance import dtw
from numpy import dot
from numpy.linalg import norm
import sys
from sklearn.utils import shuffle
import copy
import emulate_st500_em_new_write_exac as et
import importlib
import Active_Emulate_st500_em_new_exac as at

# %%
parameter_directory = "all_stocks_5yr"
file = open("./"+parameter_directory+".txt","r")
lines = file.readlines()
sample_size = int(lines[0].strip('\n'))
simi_kind = 3
cluster_number = int(lines[2].strip('\n'))
similarity_threshold = 0.75

# %%
#emulate single new
def obj(params,params_2,simi_kind):
    print("simi_kind is {}".format(simi_kind))
    emulate = et.Emulate_TestD(data,parameter_directory,simi_kind,cluster_number,sample_size,similarity_threshold)
    emulate.load_encoder_model(parameter_directory)
    emulate.load_kmeans_model(parameter_directory)
    emulate.__init_lin__()
    emulate.__init_both_cluster_directory__(cluster_number)
    emulate.__init_limit_dictionary__()
    emulate.add_cluster_dict()
    emulate.get_max_distance(instance_number = 30000)
    emulate.sample()
    emulate.load_parameter(params_2)
    emulate.__fetch__(simi_kind,params)
    print("final accuracy is {}".format(emulate.final_accuracy))
    print("accuracy threshold is {}".format(emulate.similarity_threshold))
    print("wass distance is {}".format(emulate.wasserstein_distance_flexim))
    print('#######################################################################################')
    return emulate.wasserstein_distance_flexim

# %%
params = [-2.16,6,9]

# %%
SPACE = [
   skopt.space.Integer(0,50,name = 'gamma 1'),
   skopt.space.Real(0,1,name = 'label_smoothing'),
   skopt.space.Integer(0,50,name = 'gamma 2'),
   skopt.space.Real(0,1,name = 'label_smoothing 2')
]

# %%
res = skopt.gp_minimize(lambda x: obj(params,x,simi_kind),SPACE,n_calls = 50,random_state = 44,n_jobs = -1)
# Out:
# simi_kind is 3
# Metal device set to: Apple M1 Max
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# 2022-10-18 22:15:00.222262: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2022-10-18 22:15:00.222420: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# length of distance list is 30000
# self.max_distance is 13.016
# random value is 40
# start point is 395718
# has already got sample
# params_2[0] is 22
# params_2[1] is 0.031774802093509365
# self.training_done is False
# simi kind is 3
# run first fetch
# new1
# 1 binary fetch
# self.training_done is False
# simi kind is 3
# run active learning fetch for current cluster
# generate naive complex alpha parameter
# finish generating naive parameters for current cluster
# finish generating naive parameters for current cluster
# initial active learner model
# load l2 model
# load cosine model
# active learning keras model run
# gamma is 22
# label smoothing is 0.031774802093509365
# batch size is 5
# 2022-10-18 22:15:01.461297: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2022-10-18 22:15:01.668634: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 3/3 [==============================] - 0s 22ms/step - loss: 1.9827e-07 - accuracy: 0.4875
# 2022-10-18 22:15:02.138172: W tensorflow/core/common_runtime/forward_type_inference.cc:231] Type inference failed. This indicates an invalid graph that escaped type checking. Error message: INVALID_ARGUMENT: expected compatible input types, but input 1:
# type_id: TFT_OPTIONAL
# args {
#   type_id: TFT_PRODUCT
#   args {
#     type_id: TFT_TENSOR
#     args {
#       type_id: TFT_BOOL
#     }
#   }
# }
#  is neither a subtype nor a supertype of the combined inputs preceding it:
# type_id: TFT_OPTIONAL
# args {
#   type_id: TFT_PRODUCT
#   args {
#     type_id: TFT_TENSOR
#     args {
#       type_id: TFT_LEGACY_VARIANT
#     }
#   }
# }
#
# 	while inferring type of node 'binary_focal_crossentropy/cond/output/_11'
# 2022-10-18 22:15:02.141426: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 3/3 [==============================] - 0s 27ms/step - loss: 1.8876e-07 - accuracy: 0.4500
# 5/5 [==============================] - 0s 14ms/step - loss: 1.8355e-07 - accuracy: 0.4375
# execute by search for different accuracy threshold
# accuracy threshold is 0.75
# run into active learning emulate process
# 1/1 [==============================] - 0s 50ms/step
# active learning initial score is 0.286
# emulate train unlabel shape is (192, 9)
# query instance shape is (48, 9)
# query instance shape is (44, 9)
# transform result shape is (44, 100)
# 6/6 [==============================] - 0s 2ms/step
# 2022-10-18 22:15:02.592462: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 6/6 [==============================] - 0s 17ms/step - loss: 1.7095e-07 - accuracy: 0.4970
# 2/2 [==============================] - 0s 10ms/step
# 1 time active learning score is 0.523
# 6/6 [==============================] - 0s 3ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 6/6 [==============================] - 0s 16ms/step - loss: 1.5982e-07 - accuracy: 0.6176
# 2/2 [==============================] - 0s 4ms/step
# 2 time active learning score is 0.545
# 6/6 [==============================] - 0s 6ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 6/6 [==============================] - 0s 18ms/step - loss: 1.5279e-07 - accuracy: 0.7086
# 2/2 [==============================] - 0s 3ms/step
# 3 time active learning score is 0.523
# 6/6 [==============================] - 0s 4ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 6/6 [==============================] - 0s 17ms/step - loss: 1.4954e-07 - accuracy: 0.7222
# 2/2 [==============================] - 0s 5ms/step
# 4 time active learning score is 0.545
# 6/6 [==============================] - 0s 2ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 6/6 [==============================] - 0s 16ms/step - loss: 1.4675e-07 - accuracy: 0.7081
# 2/2 [==============================] - 0s 3ms/step
# 5 time active learning score is 0.523
# emulate process finishes
# query time is 5
# first stage total query time is 5
# self.training_done is True
# simi kind is 3
# run next cluster
# random value is 106
# start point is 36071
# has already resample
# self.training_done is False
# simi kind is 3
# run first fetch
# new1
# 2 binary fetch
# self.training_done is False
# simi kind is 3
# run active learning fetch for current cluster
# generate naive complex alpha parameter
# finish generating naive parameters for current cluster
# finish generating naive parameters for current cluster
# continue training active learner mdoel
# teach active learning model
# 9/9 [==============================] - 0s 14ms/step - loss: 1.5208e-07 - accuracy: 0.6377
# train unlabel shape is (192, 9)
# run into active learning emulate process
# 1/1 [==============================] - 0s 9ms/step
# active learning initial score is 0.429
# emulate train unlabel shape is (192, 9)
# query instance shape is (48, 9)
# query instance shape is (48, 9)
# transform result shape is (48, 100)
# 6/6 [==============================] - 0s 2ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 9/9 [==============================] - 0s 13ms/step - loss: 1.4757e-07 - accuracy: 0.7074
# 2/2 [==============================] - 0s 8ms/step
# 1 time active learning score is 0.458
# 6/6 [==============================] - 0s 2ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 9/9 [==============================] - 0s 13ms/step - loss: 1.4364e-07 - accuracy: 0.7164
# 2/2 [==============================] - 0s 3ms/step
# 2 time active learning score is 0.458
# 6/6 [==============================] - 0s 2ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 9/9 [==============================] - 0s 15ms/step - loss: 1.4102e-07 - accuracy: 0.7750
# 2/2 [==============================] - 0s 3ms/step
# 3 time active learning score is 0.438
# 6/6 [==============================] - 0s 3ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 9/9 [==============================] - 0s 15ms/step - loss: 1.4017e-07 - accuracy: 0.7088
# 2/2 [==============================] - 0s 4ms/step
# 4 time active learning score is 0.417
# 6/6 [==============================] - 0s 3ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 10/10 [==============================] - 0s 17ms/step - loss: 1.3760e-07 - accuracy: 0.7586
# 2/2 [==============================] - 0s 3ms/step
# 5 time active learning score is 0.458
# emulate process finishes
# query time is 5
# first stage total query time is 10
# self.training_done is True
# simi kind is 3
# run next cluster
# random value is 2
# start point is 70704
# has already resample
# self.training_done is False
# simi kind is 3
# run first fetch
# new1
# 3 binary fetch
# self.training_done is False
# simi kind is 3
# run active learning fetch for current cluster
# generate naive complex alpha parameter
# finish generating naive parameters for current cluster
# finish generating naive parameters for current cluster
# continue training active learner mdoel
# teach active learning model
# 12/12 [==============================] - 0s 12ms/step - loss: 1.5691e-07 - accuracy: 0.7000
# train unlabel shape is (192, 9)
# run into active learning emulate process
# 1/1 [==============================] - 0s 9ms/step
# active learning initial score is 0.81
# emulate train unlabel shape is (192, 9)
# query instance shape is (48, 9)
# query instance shape is (44, 9)
# transform result shape is (44, 100)
# 6/6 [==============================] - 0s 2ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 12/12 [==============================] - 0s 12ms/step - loss: 1.3956e-07 - accuracy: 0.7360
# 2/2 [==============================] - 0s 3ms/step
# 1 time active learning score is 0.455
# 6/6 [==============================] - 0s 2ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 12/12 [==============================] - 0s 14ms/step - loss: 1.3837e-07 - accuracy: 0.7237
# 2/2 [==============================] - 0s 3ms/step
# 2 time active learning score is 0.5
# 6/6 [==============================] - 0s 2ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 13/13 [==============================] - 0s 20ms/step - loss: 1.3301e-07 - accuracy: 0.7610
# 2/2 [==============================] - 0s 3ms/step
# 3 time active learning score is 0.409
# 6/6 [==============================] - 0s 2ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 13/13 [==============================] - 0s 13ms/step - loss: 1.3677e-07 - accuracy: 0.7308
# 2/2 [==============================] - 0s 3ms/step
# 4 time active learning score is 0.5
# 6/6 [==============================] - 0s 2ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 13/13 [==============================] - 0s 13ms/step - loss: 1.3315e-07 - accuracy: 0.7342
# 2/2 [==============================] - 0s 2ms/step
# 5 time active learning score is 0.432
# emulate process finishes
# query time is 5
# first stage total query time is 15
# self.training_done is True
# simi kind is 3
# finish all cluster binary and active search
# make modification new new
# generate DTW naive positive and negative data
# (generator pid=16322) has change code 3
# (generator pid=16326) has change code 3
# (generator pid=16324) has change code 3
# length of next_result_table is 2
# result table shape is (9000, 101)
# (generator pid=16325) has change code 3
# (generator pid=16323) has change code 3
# finish generating complex parameters for all clusters and predict label by using active learner
# shape of table is (150000, 9)
# finish split
# finish generate label
# train data shape is (92115, 10)
# validate data shape is (23027, 10)
# 938/938 [==============================] - 2s 2ms/step
# initial active learning accuracy is 0.52
# 720/720 [==============================] - 1s 2ms/step
# further learning teach, generate more data
# 2879/2879 [==============================] - 6s 2ms/step
# train complex shape is (92115, 10)
# query index shape is (5,)
# 13/13 [==============================] - 0s 12ms/step - loss: 1.3512e-07 - accuracy: 0.7300
# 720/720 [==============================] - 1s 2ms/step
# 1 time fur active learning score is 0.381
# 720/720 [==============================] - 1s 2ms/step
# further learning teach, generate more data
# 2879/2879 [==============================] - 7s 2ms/step
# train complex shape is (92110, 10)
# query index shape is (5,)
# 13/13 [==============================] - 0s 12ms/step - loss: 1.3037e-07 - accuracy: 0.7605
# 720/720 [==============================] - 1s 2ms/step
# 2 time fur active learning score is 0.418
# 720/720 [==============================] - 2s 3ms/step
# further learning teach, generate more data
# 2879/2879 [==============================] - 6s 2ms/step
# train complex shape is (92105, 10)
# query index shape is (5,)
# 13/13 [==============================] - 0s 16ms/step - loss: 1.3050e-07 - accuracy: 0.7317
# 720/720 [==============================] - 2s 2ms/step
# 3 time fur active learning score is 0.457
# 720/720 [==============================] - 2s 2ms/step
# further learning teach, generate more data
# 2879/2879 [==============================] - 7s 3ms/step
# train complex shape is (92100, 10)
# query index shape is (5,)
# 13/13 [==============================] - 0s 15ms/step - loss: 1.2531e-07 - accuracy: 0.8265
# 720/720 [==============================] - 2s 2ms/step
# 4 time fur active learning score is 0.459
# 720/720 [==============================] - 2s 2ms/step
# further learning teach, generate more data
# 2878/2878 [==============================] - 7s 2ms/step
# train complex shape is (92095, 10)
# query index shape is (5,)
# 14/14 [==============================] - 0s 14ms/step - loss: 1.1942e-07 - accuracy: 0.8000
# 720/720 [==============================] - 2s 2ms/step
# 5 time fur active learning score is 0.479
# 720/720 [==============================] - 2s 2ms/step
# second stage total query time is 5
# total query time is 20
# 938/938 [==============================] - 2s 2ms/step
# final AL accuracy is 0.5
# accuracy threshold is 0.75
# final accuracy is 0.5
# accuracy threshold is 0.75
# #######################################################################################
# simi_kind is 3
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# length of distance list is 30000
# self.max_distance is 13.016
# random value is 40
# start point is 395718
# has already got sample
# params_2[0] is 32
# params_2[1] is 0.18441869586192697
# self.training_done is False
# simi kind is 3
# run first fetch
# new1
# 1 binary fetch
# self.training_done is False
# simi kind is 3
# run active learning fetch for current cluster
# generate naive complex alpha parameter
# finish generating naive parameters for current cluster
# finish generating naive parameters for current cluster
# initial active learner model
# load l2 model
# load cosine model
# active learning keras model run
# gamma is 32
# label smoothing is 0.18441869586192697
# batch size is 5
# 1/3 [=========>....................] - ETA: 0s - loss: 2.1516e-10 - accuracy: 0.4375
# 2022-10-18 22:16:20.846864: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 3/3 [==============================] - 0s 24ms/step - loss: 2.1480e-10 - accuracy: 0.5000
# 2022-10-18 22:16:21.278589: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 3/3 [==============================] - 1s 31ms/step - loss: 2.1476e-10 - accuracy: 0.5000
# 5/5 [==============================] - 0s 14ms/step - loss: 2.1466e-10 - accuracy: 0.5000
# execute by search for different accuracy threshold
# accuracy threshold is 0.75
# run into active learning emulate process
# 1/1 [==============================] - 0s 35ms/step
# active learning initial score is 0.476
# emulate train unlabel shape is (192, 9)
# query instance shape is (48, 9)
# query instance shape is (44, 9)
# transform result shape is (44, 100)
# 6/6 [==============================] - 0s 2ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 6/6 [==============================] - 0s 17ms/step - loss: 2.1287e-10 - accuracy: 0.5030
# 2022-10-18 22:16:21.760684: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2/2 [==============================] - 0s 9ms/step
# 1 time active learning score is 0.545
# 6/6 [==============================] - 0s 4ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 6/6 [==============================] - 0s 19ms/step - loss: 2.1122e-10 - accuracy: 0.5000
# 2/2 [==============================] - 0s 3ms/step
# 2 time active learning score is 0.545
# 6/6 [==============================] - 0s 4ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 6/6 [==============================] - 0s 17ms/step - loss: 2.0981e-10 - accuracy: 0.4914
# 2/2 [==============================] - 0s 3ms/step
# 3 time active learning score is 0.545
# 6/6 [==============================] - 0s 5ms/step
# query instance shape is (5, 9)
# query instance shape is (4, 9)
# transform result shape is (4, 100)
# train
# 6/6 [==============================] - 0s 22ms/step - loss: 2.0855e-10 - accuracy: 0.4916
# 2/2 [==============================] - 0s 4ms/step
# 4 time active learning score is 0.545
# 6/6 [==============================] - 0s 2ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 6/6 [==============================] - 0s 18ms/step - loss: 2.0703e-10 - accuracy: 0.4946
# 2/2 [==============================] - 0s 4ms/step
# 5 time active learning score is 0.545
# emulate process finishes
# query time is 5
# first stage total query time is 5
# self.training_done is True
# simi kind is 3
# run next cluster
# random value is 106
# start point is 36071
# has already resample
# self.training_done is False
# simi kind is 3
# run first fetch
# new1
# 2 binary fetch
# self.training_done is False
# simi kind is 3
# run active learning fetch for current cluster
# generate naive complex alpha parameter
# finish generating naive parameters for current cluster
# finish generating naive parameters for current cluster
# continue training active learner mdoel
# teach active learning model
# 9/9 [==============================] - 0s 15ms/step - loss: 2.0806e-10 - accuracy: 0.4659
# train unlabel shape is (192, 9)
# run into active learning emulate process
# 1/1 [==============================] - 0s 12ms/step
# active learning initial score is 0.286
# emulate train unlabel shape is (192, 9)
# query instance shape is (48, 9)
# query instance shape is (48, 9)
# transform result shape is (48, 100)
# 6/6 [==============================] - 0s 2ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 9/9 [==============================] - 0s 15ms/step - loss: 2.0703e-10 - accuracy: 0.4647
# 2/2 [==============================] - 0s 8ms/step
# 1 time active learning score is 0.521
# 6/6 [==============================] - 0s 2ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 9/9 [==============================] - 0s 18ms/step - loss: 2.0591e-10 - accuracy: 0.4635
# 2/2 [==============================] - 0s 3ms/step
# 2 time active learning score is 0.521
# 6/6 [==============================] - 0s 3ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 9/9 [==============================] - 0s 17ms/step - loss: 2.0497e-10 - accuracy: 0.4624
# 2/2 [==============================] - 0s 3ms/step
# 3 time active learning score is 0.521
# 6/6 [==============================] - 0s 3ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 9/9 [==============================] - 0s 17ms/step - loss: 2.0406e-10 - accuracy: 0.4613
# 2/2 [==============================] - 0s 3ms/step
# 4 time active learning score is 0.521
# 6/6 [==============================] - 0s 2ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 10/10 [==============================] - 0s 15ms/step - loss: 2.0336e-10 - accuracy: 0.4567
# 2/2 [==============================] - 0s 4ms/step
# 5 time active learning score is 0.521
# emulate process finishes
# query time is 5
# first stage total query time is 10
# self.training_done is True
# simi kind is 3
# run next cluster
# random value is 2
# start point is 70704
# has already resample
# self.training_done is False
# simi kind is 3
# run first fetch
# new1
# 3 binary fetch
# self.training_done is False
# simi kind is 3
# run active learning fetch for current cluster
# generate naive complex alpha parameter
# finish generating naive parameters for current cluster
# finish generating naive parameters for current cluster
# continue training active learner mdoel
# teach active learning model
# 12/12 [==============================] - 0s 17ms/step - loss: 2.0604e-10 - accuracy: 0.4607
# train unlabel shape is (192, 9)
# run into active learning emulate process
# 1/1 [==============================] - 0s 10ms/step
# active learning initial score is 0.333
# emulate train unlabel shape is (192, 9)
# query instance shape is (48, 9)
# query instance shape is (44, 9)
# transform result shape is (44, 100)
# 6/6 [==============================] - 0s 2ms/step
# query instance shape is (5, 9)
# query instance shape is (4, 9)
# transform result shape is (4, 100)
# train
# 12/12 [==============================] - 0s 14ms/step - loss: 2.0529e-10 - accuracy: 0.4665
# 2/2 [==============================] - 0s 3ms/step
# 1 time active learning score is 0.477
# 6/6 [==============================] - 0s 3ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 12/12 [==============================] - 0s 14ms/step - loss: 2.0442e-10 - accuracy: 0.4709
# 2/2 [==============================] - 0s 3ms/step
# 2 time active learning score is 0.5
# 6/6 [==============================] - 0s 2ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 12/12 [==============================] - 0s 18ms/step - loss: 2.0349e-10 - accuracy: 0.4752
# 2/2 [==============================] - 0s 3ms/step
# 3 time active learning score is 0.5
# 6/6 [==============================] - 0s 3ms/step
# query instance shape is (5, 9)
# query instance shape is (4, 9)
# transform result shape is (4, 100)
# train
# 13/13 [==============================] - 0s 19ms/step - loss: 2.0275e-10 - accuracy: 0.4755
# 2/2 [==============================] - 0s 4ms/step
# 4 time active learning score is 0.5
# 6/6 [==============================] - 0s 3ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 13/13 [==============================] - 0s 13ms/step - loss: 2.0199e-10 - accuracy: 0.4745
# 2/2 [==============================] - 0s 13ms/step
# 5 time active learning score is 0.5
# emulate process finishes
# query time is 5
# first stage total query time is 15
# self.training_done is True
# simi kind is 3
# finish all cluster binary and active search
# make modification new new
# generate DTW naive positive and negative data
# length of next_result_table is 2
# result table shape is (9000, 101)
# (generator pid=16404) has change code 3
# (generator pid=16400) has change code 3
# (generator pid=16403) has change code 3
# (generator pid=16402) has change code 3
# (generator pid=16401) has change code 3
# finish generating complex parameters for all clusters and predict label by using active learner
# shape of table is (150000, 9)
# finish split
# finish generate label
# train data shape is (92115, 10)
# validate data shape is (23027, 10)
# 938/938 [==============================] - 2s 3ms/step
# initial active learning accuracy is 0.46
# 720/720 [==============================] - 2s 2ms/step
# further learning teach, generate more data
# 2879/2879 [==============================] - 7s 3ms/step
# train complex shape is (92115, 10)
# query index shape is (5,)
# 13/13 [==============================] - 0s 15ms/step - loss: 2.0085e-10 - accuracy: 0.5340
# 720/720 [==============================] - 2s 3ms/step
# 1 time fur active learning score is 0.45
# 720/720 [==============================] - 2s 3ms/step
# further learning teach, generate more data
# 2879/2879 [==============================] - 8s 3ms/step
# train complex shape is (92110, 10)
# query index shape is (5,)
# 13/13 [==============================] - 0s 15ms/step - loss: 2.0937e-10 - accuracy: 0.4826
# 720/720 [==============================] - 2s 2ms/step
# 2 time fur active learning score is 0.45
# 720/720 [==============================] - 2s 3ms/step
# further learning teach, generate more data
# 2879/2879 [==============================] - 7s 3ms/step
# train complex shape is (92105, 10)
# query index shape is (5,)
# 13/13 [==============================] - 0s 18ms/step - loss: 1.9828e-10 - accuracy: 0.5184
# 720/720 [==============================] - 2s 3ms/step
# 3 time fur active learning score is 0.45
# 720/720 [==============================] - 2s 3ms/step
# further learning teach, generate more data
# 2879/2879 [==============================] - 7s 2ms/step
# train complex shape is (92100, 10)
# query index shape is (5,)
# 13/13 [==============================] - 0s 19ms/step - loss: 2.0134e-10 - accuracy: 0.4927
# 720/720 [==============================] - 2s 2ms/step
# 4 time fur active learning score is 0.451
# 720/720 [==============================] - 2s 2ms/step
# further learning teach, generate more data
# 2878/2878 [==============================] - 7s 2ms/step
# train complex shape is (92095, 10)
# query index shape is (5,)
# 14/14 [==============================] - 0s 13ms/step - loss: 1.8655e-10 - accuracy: 0.5540
# 720/720 [==============================] - 2s 2ms/step
# 5 time fur active learning score is 0.452
# 720/720 [==============================] - 2s 3ms/step
# second stage total query time is 5
# total query time is 20
# 938/938 [==============================] - 3s 3ms/step
# final AL accuracy is 0.47
# accuracy threshold is 0.75
# final accuracy is 0.47
# accuracy threshold is 0.75
# #######################################################################################
# simi_kind is 3
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# length of distance list is 30000
# self.max_distance is 13.016
# random value is 40
# start point is 395718
# has already got sample
# params_2[0] is 16
# params_2[1] is 0.25696756984129215
# self.training_done is False
# simi kind is 3
# run first fetch
# new1
# 1 binary fetch
# self.training_done is False
# simi kind is 3
# run active learning fetch for current cluster
# generate naive complex alpha parameter
# finish generating naive parameters for current cluster
# finish generating naive parameters for current cluster
# initial active learner model
# load l2 model
# load cosine model
# active learning keras model run
# gamma is 16
# label smoothing is 0.25696756984129215
# batch size is 5
# 2022-10-18 22:17:49.042482: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 3/3 [==============================] - 2s 32ms/step - loss: 1.1176e-05 - accuracy: 0.5250
# 2022-10-18 22:17:49.545193: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 3/3 [==============================] - 1s 47ms/step - loss: 9.8072e-06 - accuracy: 0.6500
# 5/5 [==============================] - 0s 15ms/step - loss: 8.9381e-06 - accuracy: 0.7438
# execute by search for different accuracy threshold
# accuracy threshold is 0.75
# run into active learning emulate process
# 1/1 [==============================] - 0s 41ms/step
# active learning initial score is 0.762
# emulate train unlabel shape is (192, 9)
# query instance shape is (48, 9)
# query instance shape is (44, 9)
# transform result shape is (44, 100)
# 6/6 [==============================] - 0s 4ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 1/6 [====>.........................] - ETA: 0s - loss: 8.4002e-06 - accuracy: 0.7500
# 2022-10-18 22:17:50.216552: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 6/6 [==============================] - 0s 23ms/step - loss: 8.6032e-06 - accuracy: 0.7697
# 2/2 [==============================] - 0s 9ms/step
# 1 time active learning score is 0.432
# 6/6 [==============================] - 0s 4ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 6/6 [==============================] - 0s 21ms/step - loss: 7.7510e-06 - accuracy: 0.8118
# 2/2 [==============================] - 0s 3ms/step
# 2 time active learning score is 0.455
# 6/6 [==============================] - 0s 22ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 6/6 [==============================] - 0s 31ms/step - loss: 7.4753e-06 - accuracy: 0.8000
# 2/2 [==============================] - 0s 4ms/step
# 3 time active learning score is 0.432
# 6/6 [==============================] - 0s 5ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 6/6 [==============================] - 0s 22ms/step - loss: 7.1520e-06 - accuracy: 0.8222
# 2/2 [==============================] - 0s 4ms/step
# 4 time active learning score is 0.432
# 6/6 [==============================] - 0s 3ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 6/6 [==============================] - 0s 20ms/step - loss: 7.0002e-06 - accuracy: 0.8216
# 2/2 [==============================] - 0s 3ms/step
# 5 time active learning score is 0.455
# emulate process finishes
# query time is 5
# first stage total query time is 5
# self.training_done is True
# simi kind is 3
# run next cluster
# random value is 106
# start point is 36071
# has already resample
# self.training_done is False
# simi kind is 3
# run first fetch
# new1
# 2 binary fetch
# self.training_done is False
# simi kind is 3
# run active learning fetch for current cluster
# generate naive complex alpha parameter
# finish generating naive parameters for current cluster
# finish generating naive parameters for current cluster
# continue training active learner mdoel
# teach active learning model
# 9/9 [==============================] - 0s 19ms/step - loss: 8.4045e-06 - accuracy: 0.7321
# train unlabel shape is (192, 9)
# run into active learning emulate process
# 1/1 [==============================] - 0s 12ms/step
# active learning initial score is 0.714
# emulate train unlabel shape is (192, 9)
# query instance shape is (48, 9)
# query instance shape is (48, 9)
# transform result shape is (48, 100)
# 6/6 [==============================] - 0s 4ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 9/9 [==============================] - 0s 17ms/step - loss: 6.9834e-06 - accuracy: 0.7926
# 2/2 [==============================] - 0s 11ms/step
# 1 time active learning score is 0.417
# 6/6 [==============================] - 0s 3ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 9/9 [==============================] - 0s 19ms/step - loss: 6.9079e-06 - accuracy: 0.8182
# 2/2 [==============================] - 0s 3ms/step
# 2 time active learning score is 0.438
# 6/6 [==============================] - 0s 3ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 9/9 [==============================] - 0s 17ms/step - loss: 6.2777e-06 - accuracy: 0.8464
# 2/2 [==============================] - 0s 3ms/step
# 3 time active learning score is 0.396
# 6/6 [==============================] - 0s 3ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 9/9 [==============================] - 0s 16ms/step - loss: 5.8248e-06 - accuracy: 0.8632
# 2/2 [==============================] - 0s 4ms/step
# 4 time active learning score is 0.396
# 6/6 [==============================] - 0s 3ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 10/10 [==============================] - 0s 25ms/step - loss: 6.0021e-06 - accuracy: 0.8379
# 2/2 [==============================] - 0s 4ms/step
# 5 time active learning score is 0.5
# emulate process finishes
# query time is 5
# first stage total query time is 10
# self.training_done is True
# simi kind is 3
# run next cluster
# random value is 2
# start point is 70704
# has already resample
# self.training_done is False
# simi kind is 3
# run first fetch
# new1
# 3 binary fetch
# self.training_done is False
# simi kind is 3
# run active learning fetch for current cluster
# generate naive complex alpha parameter
# finish generating naive parameters for current cluster
# finish generating naive parameters for current cluster
# continue training active learner mdoel
# teach active learning model
# 12/12 [==============================] - 0s 17ms/step - loss: 1.5721e-05 - accuracy: 0.7108
# train unlabel shape is (192, 9)
# run into active learning emulate process
# 1/1 [==============================] - 0s 12ms/step
# active learning initial score is 0.619
# emulate train unlabel shape is (192, 9)
# query instance shape is (48, 9)
# query instance shape is (44, 9)
# transform result shape is (44, 100)
# 6/6 [==============================] - 0s 3ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 12/12 [==============================] - 0s 14ms/step - loss: 8.3377e-06 - accuracy: 0.7253
# 2/2 [==============================] - 0s 3ms/step
# 1 time active learning score is 0.364
# 6/6 [==============================] - 0s 3ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 12/12 [==============================] - 0s 18ms/step - loss: 7.4500e-06 - accuracy: 0.8132
# 2/2 [==============================] - 0s 4ms/step
# 2 time active learning score is 0.636
# 6/6 [==============================] - 0s 2ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 13/13 [==============================] - 0s 18ms/step - loss: 6.6643e-06 - accuracy: 0.8260
# 2/2 [==============================] - 0s 5ms/step
# 3 time active learning score is 0.591
# 6/6 [==============================] - 0s 7ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 13/13 [==============================] - 0s 14ms/step - loss: 6.0582e-06 - accuracy: 0.8667
# 2/2 [==============================] - 0s 4ms/step
# 4 time active learning score is 0.614
# 6/6 [==============================] - 0s 3ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 13/13 [==============================] - 0s 19ms/step - loss: 5.9907e-06 - accuracy: 0.8405
# 2/2 [==============================] - 0s 6ms/step
# 5 time active learning score is 0.636
# emulate process finishes
# query time is 5
# first stage total query time is 15
# self.training_done is True
# simi kind is 3
# finish all cluster binary and active search
# make modification new new
# generate DTW naive positive and negative data
# (generator pid=16476) has change code 3
# (generator pid=16479) has change code 3
# (generator pid=16475) has change code 3
# length of next_result_table is 2
# result table shape is (9000, 101)
# (generator pid=16478) has change code 3
# (generator pid=16477) has change code 3
# finish generating complex parameters for all clusters and predict label by using active learner
# shape of table is (150000, 9)
# finish split
# finish generate label
# train data shape is (92115, 10)
# validate data shape is (23027, 10)
# 938/938 [==============================] - 3s 3ms/step
# initial active learning accuracy is 0.56
# 720/720 [==============================] - 2s 3ms/step
# further learning teach, generate more data
# 2879/2879 [==============================] - 9s 3ms/step
# train complex shape is (92115, 10)
# query index shape is (5,)
# 13/13 [==============================] - 0s 28ms/step - loss: 4.9652e-06 - accuracy: 0.8800
# 720/720 [==============================] - 3s 4ms/step
# 1 time fur active learning score is 0.523
# 720/720 [==============================] - 2s 3ms/step
# further learning teach, generate more data
# 2879/2879 [==============================] - 9s 3ms/step
# train complex shape is (92110, 10)
# query index shape is (5,)
# 13/13 [==============================] - 0s 23ms/step - loss: 5.7755e-06 - accuracy: 0.8420
# 720/720 [==============================] - 3s 4ms/step
# 2 time fur active learning score is 0.526
# 720/720 [==============================] - 3s 4ms/step
# further learning teach, generate more data
# 2879/2879 [==============================] - 7s 3ms/step
# train complex shape is (92105, 10)
# query index shape is (5,)
# 13/13 [==============================] - 0s 16ms/step - loss: 4.6181e-06 - accuracy: 0.8951
# 720/720 [==============================] - 2s 3ms/step
# 3 time fur active learning score is 0.504
# 720/720 [==============================] - 2s 3ms/step
# further learning teach, generate more data
# 2879/2879 [==============================] - 9s 3ms/step
# train complex shape is (92100, 10)
# query index shape is (5,)
# 13/13 [==============================] - 0s 20ms/step - loss: 4.8640e-06 - accuracy: 0.8602
# 720/720 [==============================] - 2s 3ms/step
# 4 time fur active learning score is 0.59
# 720/720 [==============================] - 2s 3ms/step
# further learning teach, generate more data
# 2878/2878 [==============================] - 9s 3ms/step
# train complex shape is (92095, 10)
# query index shape is (5,)
# 14/14 [==============================] - 0s 24ms/step - loss: 4.2053e-06 - accuracy: 0.9071
# 720/720 [==============================] - 2s 3ms/step
# 5 time fur active learning score is 0.641
# 720/720 [==============================] - 2s 3ms/step
# second stage total query time is 5
# total query time is 20
# 938/938 [==============================] - 5s 6ms/step
# final AL accuracy is 0.64
# accuracy threshold is 0.75
# final accuracy is 0.64
# accuracy threshold is 0.75
# #######################################################################################
# simi_kind is 3
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# length of distance list is 30000
# self.max_distance is 13.016
# random value is 40
# start point is 395718
# has already got sample
# params_2[0] is 34
# params_2[1] is 0.28256021819936045
# self.training_done is False
# simi kind is 3
# run first fetch
# new1
# 1 binary fetch
# self.training_done is False
# simi kind is 3
# run active learning fetch for current cluster
# generate naive complex alpha parameter
# finish generating naive parameters for current cluster
# finish generating naive parameters for current cluster
# initial active learner model
# load l2 model
# load cosine model
# active learning keras model run
# gamma is 34
# label smoothing is 0.28256021819936045
# batch size is 5
# 2022-10-18 22:19:36.823485: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 3/3 [==============================] - 1s 47ms/step - loss: 5.1747e-11 - accuracy: 0.5000
# 2022-10-18 22:19:37.901471: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 3/3 [==============================] - 1s 54ms/step - loss: 5.1745e-11 - accuracy: 0.5000
# 5/5 [==============================] - 0s 19ms/step - loss: 5.1741e-11 - accuracy: 0.5000
# execute by search for different accuracy threshold
# accuracy threshold is 0.75
# run into active learning emulate process
# 1/1 [==============================] - 0s 44ms/step
# active learning initial score is 0.476
# emulate train unlabel shape is (192, 9)
# query instance shape is (48, 9)
# query instance shape is (44, 9)
# transform result shape is (44, 100)
# 6/6 [==============================] - 0s 4ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 1/6 [====>.........................] - ETA: 0s - loss: 5.6396e-11 - accuracy: 0.5625
# 2022-10-18 22:19:38.610765: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 6/6 [==============================] - 0s 25ms/step - loss: 5.1384e-11 - accuracy: 0.5030
# 2/2 [==============================] - 0s 10ms/step
# 1 time active learning score is 0.545
# 6/6 [==============================] - 0s 6ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 6/6 [==============================] - 0s 25ms/step - loss: 5.1055e-11 - accuracy: 0.5000
# 2/2 [==============================] - 0s 8ms/step
# 2 time active learning score is 0.545
# 6/6 [==============================] - 0s 6ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 6/6 [==============================] - 0s 38ms/step - loss: 5.0778e-11 - accuracy: 0.4914
# 2/2 [==============================] - 0s 11ms/step
# 3 time active learning score is 0.545
# 6/6 [==============================] - 0s 6ms/step
# query instance shape is (5, 9)
# query instance shape is (4, 9)
# transform result shape is (4, 100)
# train
# 6/6 [==============================] - 0s 37ms/step - loss: 5.0539e-11 - accuracy: 0.4916
# 2/2 [==============================] - 0s 13ms/step
# 4 time active learning score is 0.545
# 6/6 [==============================] - 0s 7ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 6/6 [==============================] - 0s 24ms/step - loss: 5.0236e-11 - accuracy: 0.4946
# 2/2 [==============================] - 0s 9ms/step
# 5 time active learning score is 0.545
# emulate process finishes
# query time is 5
# first stage total query time is 5
# self.training_done is True
# simi kind is 3
# run next cluster
# random value is 106
# start point is 36071
# has already resample
# self.training_done is False
# simi kind is 3
# run first fetch
# new1
# 2 binary fetch
# self.training_done is False
# simi kind is 3
# run active learning fetch for current cluster
# generate naive complex alpha parameter
# finish generating naive parameters for current cluster
# finish generating naive parameters for current cluster
# continue training active learner mdoel
# teach active learning model
# 9/9 [==============================] - 0s 17ms/step - loss: 5.0518e-11 - accuracy: 0.4659
# train unlabel shape is (192, 9)
# run into active learning emulate process
# 1/1 [==============================] - 0s 13ms/step
# active learning initial score is 0.286
# emulate train unlabel shape is (192, 9)
# query instance shape is (48, 9)
# query instance shape is (48, 9)
# transform result shape is (48, 100)
# 6/6 [==============================] - 0s 5ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 9/9 [==============================] - 0s 25ms/step - loss: 5.0319e-11 - accuracy: 0.4684
# 2/2 [==============================] - 0s 10ms/step
# 1 time active learning score is 0.521
# 6/6 [==============================] - 0s 3ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 9/9 [==============================] - 0s 21ms/step - loss: 5.0136e-11 - accuracy: 0.4672
# 2/2 [==============================] - 0s 4ms/step
# 2 time active learning score is 0.521
# 6/6 [==============================] - 0s 3ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 9/9 [==============================] - 0s 21ms/step - loss: 4.9986e-11 - accuracy: 0.4624
# 2/2 [==============================] - 0s 3ms/step
# 3 time active learning score is 0.521
# 6/6 [==============================] - 0s 3ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 9/9 [==============================] - 0s 16ms/step - loss: 4.9798e-11 - accuracy: 0.4648
# 2/2 [==============================] - 0s 6ms/step
# 4 time active learning score is 0.521
# 6/6 [==============================] - 0s 3ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 10/10 [==============================] - 0s 24ms/step - loss: 4.9611e-11 - accuracy: 0.4671
# 2/2 [==============================] - 0s 5ms/step
# 5 time active learning score is 0.521
# emulate process finishes
# query time is 5
# first stage total query time is 10
# self.training_done is True
# simi kind is 3
# run next cluster
# random value is 2
# start point is 70704
# has already resample
# self.training_done is False
# simi kind is 3
# run first fetch
# new1
# 3 binary fetch
# self.training_done is False
# simi kind is 3
# run active learning fetch for current cluster
# generate naive complex alpha parameter
# finish generating naive parameters for current cluster
# finish generating naive parameters for current cluster
# continue training active learner mdoel
# teach active learning model
# 12/12 [==============================] - 0s 18ms/step - loss: 5.0130e-11 - accuracy: 0.4715
# train unlabel shape is (192, 9)
# run into active learning emulate process
# 1/1 [==============================] - 0s 15ms/step
# active learning initial score is 0.333
# emulate train unlabel shape is (192, 9)
# query instance shape is (48, 9)
# query instance shape is (44, 9)
# transform result shape is (44, 100)
# 6/6 [==============================] - 0s 3ms/step
# query instance shape is (5, 9)
# query instance shape is (4, 9)
# transform result shape is (4, 100)
# train
# 12/12 [==============================] - 0s 18ms/step - loss: 5.0020e-11 - accuracy: 0.4692
# 2/2 [==============================] - 0s 7ms/step
# 1 time active learning score is 0.5
# 6/6 [==============================] - 0s 5ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 12/12 [==============================] - 0s 22ms/step - loss: 4.9862e-11 - accuracy: 0.4735
# 2/2 [==============================] - 0s 3ms/step
# 2 time active learning score is 0.5
# 6/6 [==============================] - 0s 3ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 12/12 [==============================] - 0s 18ms/step - loss: 4.9695e-11 - accuracy: 0.4778
# 2/2 [==============================] - 0s 5ms/step
# 3 time active learning score is 0.5
# 6/6 [==============================] - 0s 3ms/step
# query instance shape is (5, 9)
# query instance shape is (4, 9)
# transform result shape is (4, 100)
# train
# 13/13 [==============================] - 0s 32ms/step - loss: 4.9584e-11 - accuracy: 0.4780
# 2/2 [==============================] - 0s 4ms/step
# 4 time active learning score is 0.5
# 6/6 [==============================] - 0s 4ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 13/13 [==============================] - 0s 16ms/step - loss: 4.9474e-11 - accuracy: 0.4770
# 2/2 [==============================] - 0s 4ms/step
# 5 time active learning score is 0.5
# emulate process finishes
# query time is 5
# first stage total query time is 15
# self.training_done is True
# simi kind is 3
# finish all cluster binary and active search
# make modification new new
# generate DTW naive positive and negative data
# (generator pid=16544) has change code 3
# (generator pid=16542) has change code 3
# (generator pid=16541) has change code 3
# (generator pid=16540) has change code 3
# (generator pid=16543) has change code 3
# length of next_result_table is 2
# result table shape is (9000, 101)
# finish generating complex parameters for all clusters and predict label by using active learner
# shape of table is (150000, 9)
# finish split
# finish generate label
# train data shape is (92115, 10)
# validate data shape is (23027, 10)
# 938/938 [==============================] - 3s 4ms/step
# initial active learning accuracy is 0.47
# 720/720 [==============================] - 2s 2ms/step
# further learning teach, generate more data
# 2879/2879 [==============================] - 9s 3ms/step
# train complex shape is (92115, 10)
# query index shape is (5,)
# 13/13 [==============================] - 0s 15ms/step - loss: 4.9294e-11 - accuracy: 0.5189
# 720/720 [==============================] - 2s 3ms/step
# 1 time fur active learning score is 0.449
# 720/720 [==============================] - 2s 3ms/step
# further learning teach, generate more data
# 2879/2879 [==============================] - 8s 3ms/step
# train complex shape is (92110, 10)
# query index shape is (5,)
# ...
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 13/13 [==============================] - 0s 19ms/step - loss: 0.1815 - accuracy: 0.8205
# 2/2 [==============================] - 0s 4ms/step
# 4 time active learning score is 0.523
# 6/6 [==============================] - 0s 4ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 13/13 [==============================] - 0s 22ms/step - loss: 0.1595 - accuracy: 0.8405
# 2/2 [==============================] - 0s 3ms/step
# 5 time active learning score is 0.523
# emulate process finishes
# query time is 5
# first stage total query time is 15
# self.training_done is True
# simi kind is 3
# finish all cluster binary and active search
# make modification new new
# generate DTW naive positive and negative data
# length of next_result_table is 2
# result table shape is (9000, 101)
# (generator pid=19651) has change code 3
# (generator pid=19652) has change code 3
# (generator pid=19653) has change code 3
# (generator pid=19650) has change code 3
# (generator pid=19654) has change code 3
# finish generating complex parameters for all clusters and predict label by using active learner
# shape of table is (150000, 9)
# finish split
# finish generate label
# train data shape is (92115, 10)
# validate data shape is (23027, 10)
# 938/938 [==============================] - 3s 3ms/step
# initial active learning accuracy is 0.48
# 720/720 [==============================] - 2s 3ms/step
# further learning teach, generate more data
# 2879/2879 [==============================] - 8s 3ms/step
# train complex shape is (92115, 10)
# query index shape is (5,)
# 13/13 [==============================] - 0s 31ms/step - loss: 0.1296 - accuracy: 0.8925
# 720/720 [==============================] - 2s 3ms/step
# 1 time fur active learning score is 0.522
# 720/720 [==============================] - 2s 3ms/step
# further learning teach, generate more data
# 2879/2879 [==============================] - 8s 3ms/step
# train complex shape is (92110, 10)
# query index shape is (5,)
# 13/13 [==============================] - 0s 26ms/step - loss: 0.1259 - accuracy: 0.8938
# 720/720 [==============================] - 2s 3ms/step
# 2 time fur active learning score is 0.508
# 720/720 [==============================] - 2s 3ms/step
# further learning teach, generate more data
# 2879/2879 [==============================] - 8s 3ms/step
# train complex shape is (92105, 10)
# query index shape is (5,)
# 13/13 [==============================] - 0s 20ms/step - loss: 0.1046 - accuracy: 0.9171
# 720/720 [==============================] - 2s 3ms/step
# 3 time fur active learning score is 0.542
# 720/720 [==============================] - 2s 3ms/step
# further learning teach, generate more data
# 2879/2879 [==============================] - 8s 3ms/step
# train complex shape is (92100, 10)
# query index shape is (5,)
# 13/13 [==============================] - 0s 21ms/step - loss: 0.1180 - accuracy: 0.8988
# 720/720 [==============================] - 2s 3ms/step
# 4 time fur active learning score is 0.55
# 720/720 [==============================] - 2s 3ms/step
# further learning teach, generate more data
# 2878/2878 [==============================] - 8s 3ms/step
# train complex shape is (92095, 10)
# query index shape is (5,)
# 14/14 [==============================] - 0s 27ms/step - loss: 0.1035 - accuracy: 0.9095
# 720/720 [==============================] - 2s 3ms/step
# 5 time fur active learning score is 0.587
# 720/720 [==============================] - 2s 3ms/step
# second stage total query time is 5
# total query time is 20
# 938/938 [==============================] - 2s 3ms/step
# final AL accuracy is 0.59
# accuracy threshold is 0.75
# final accuracy is 0.59
# accuracy threshold is 0.75
# #######################################################################################
# simi_kind is 3
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# /Users/wangzhuo/miniforge3/lib/python3.9/site-packages/skopt/optimizer/optimizer.py:449: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# length of distance list is 30000
# self.max_distance is 13.016
# random value is 40
# start point is 395718
# has already got sample
# params_2[0] is 1
# params_2[1] is 0.0
# self.training_done is False
# simi kind is 3
# run first fetch
# new1
# 1 binary fetch
# self.training_done is False
# simi kind is 3
# run active learning fetch for current cluster
# generate naive complex alpha parameter
# finish generating naive parameters for current cluster
# finish generating naive parameters for current cluster
# initial active learner model
# load l2 model
# load cosine model
# active learning keras model run
# gamma is 1
# label smoothing is 0.0
# batch size is 5
# 2022-10-18 23:17:23.838849: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 3/3 [==============================] - 2s 101ms/step - loss: 0.3549 - accuracy: 0.4625
# 2022-10-18 23:17:24.793598: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 3/3 [==============================] - 1s 65ms/step - loss: 0.3091 - accuracy: 0.7750
# 5/5 [==============================] - 0s 25ms/step - loss: 0.2662 - accuracy: 0.8063
# execute by search for different accuracy threshold
# accuracy threshold is 0.75
# run into active learning emulate process
# 1/1 [==============================] - 0s 51ms/step
# active learning initial score is 0.81
# emulate train unlabel shape is (192, 9)
# query instance shape is (48, 9)
# query instance shape is (44, 9)
# transform result shape is (44, 100)
# 6/6 [==============================] - 0s 3ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 1/6 [====>.........................] - ETA: 0s - loss: 0.2644 - accuracy: 0.7188
# 2022-10-18 23:17:25.485623: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 6/6 [==============================] - 0s 38ms/step - loss: 0.2199 - accuracy: 0.8242
# 2/2 [==============================] - 0s 20ms/step
# 1 time active learning score is 0.295
# 6/6 [==============================] - 0s 5ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 6/6 [==============================] - 0s 31ms/step - loss: 0.2000 - accuracy: 0.8412
# 2/2 [==============================] - 0s 5ms/step
# 2 time active learning score is 0.364
# 6/6 [==============================] - 0s 5ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 6/6 [==============================] - 0s 28ms/step - loss: 0.1975 - accuracy: 0.8229
# 2/2 [==============================] - 0s 6ms/step
# 3 time active learning score is 0.386
# 6/6 [==============================] - 0s 6ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 6/6 [==============================] - 0s 32ms/step - loss: 0.1963 - accuracy: 0.7944
# 2/2 [==============================] - 0s 3ms/step
# 4 time active learning score is 0.364
# 6/6 [==============================] - 0s 3ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 6/6 [==============================] - 0s 29ms/step - loss: 0.1687 - accuracy: 0.8757
# 2/2 [==============================] - 0s 3ms/step
# 5 time active learning score is 0.386
# emulate process finishes
# query time is 5
# first stage total query time is 5
# self.training_done is True
# simi kind is 3
# run next cluster
# random value is 106
# start point is 36071
# has already resample
# self.training_done is False
# simi kind is 3
# run first fetch
# new1
# 2 binary fetch
# self.training_done is False
# simi kind is 3
# run active learning fetch for current cluster
# generate naive complex alpha parameter
# finish generating naive parameters for current cluster
# finish generating naive parameters for current cluster
# continue training active learner mdoel
# teach active learning model
# 9/9 [==============================] - 0s 22ms/step - loss: 0.3418 - accuracy: 0.7660
# train unlabel shape is (192, 9)
# run into active learning emulate process
# 1/1 [==============================] - 0s 13ms/step
# active learning initial score is 0.714
# emulate train unlabel shape is (192, 9)
# query instance shape is (48, 9)
# query instance shape is (48, 9)
# transform result shape is (48, 100)
# 6/6 [==============================] - 0s 3ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 9/9 [==============================] - 0s 20ms/step - loss: 0.2305 - accuracy: 0.7778
# 2/2 [==============================] - 0s 19ms/step
# 1 time active learning score is 0.479
# 6/6 [==============================] - 0s 3ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 9/9 [==============================] - 0s 21ms/step - loss: 0.1828 - accuracy: 0.8400
# 2/2 [==============================] - 0s 4ms/step
# 2 time active learning score is 0.396
# 6/6 [==============================] - 0s 3ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 9/9 [==============================] - 0s 21ms/step - loss: 0.1597 - accuracy: 0.8607
# 2/2 [==============================] - 0s 5ms/step
# 3 time active learning score is 0.417
# 6/6 [==============================] - 0s 3ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 9/9 [==============================] - 0s 21ms/step - loss: 0.1489 - accuracy: 0.8561
# 2/2 [==============================] - 0s 5ms/step
# 4 time active learning score is 0.458
# 6/6 [==============================] - 0s 3ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 10/10 [==============================] - 0s 26ms/step - loss: 0.1349 - accuracy: 0.8621
# 2/2 [==============================] - 0s 3ms/step
# 5 time active learning score is 0.5
# emulate process finishes
# query time is 5
# first stage total query time is 10
# self.training_done is True
# simi kind is 3
# run next cluster
# random value is 2
# start point is 70704
# has already resample
# self.training_done is False
# simi kind is 3
# run first fetch
# new1
# 3 binary fetch
# self.training_done is False
# simi kind is 3
# run active learning fetch for current cluster
# generate naive complex alpha parameter
# finish generating naive parameters for current cluster
# finish generating naive parameters for current cluster
# continue training active learner mdoel
# teach active learning model
# 12/12 [==============================] - 0s 17ms/step - loss: 0.3106 - accuracy: 0.7595
# train unlabel shape is (192, 9)
# run into active learning emulate process
# 1/1 [==============================] - 0s 12ms/step
# active learning initial score is 0.667
# emulate train unlabel shape is (192, 9)
# query instance shape is (48, 9)
# query instance shape is (44, 9)
# transform result shape is (44, 100)
# 6/6 [==============================] - 0s 3ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 12/12 [==============================] - 0s 19ms/step - loss: 0.2055 - accuracy: 0.8027
# 2/2 [==============================] - 0s 5ms/step
# 1 time active learning score is 0.523
# 6/6 [==============================] - 0s 3ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 12/12 [==============================] - 0s 19ms/step - loss: 0.1625 - accuracy: 0.8289
# 2/2 [==============================] - 0s 3ms/step
# 2 time active learning score is 0.568
# 6/6 [==============================] - 0s 3ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 13/13 [==============================] - 0s 22ms/step - loss: 0.1455 - accuracy: 0.8649
# 2/2 [==============================] - 0s 4ms/step
# 3 time active learning score is 0.636
# 6/6 [==============================] - 0s 3ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 13/13 [==============================] - 0s 20ms/step - loss: 0.1227 - accuracy: 0.8949
# 2/2 [==============================] - 0s 3ms/step
# 4 time active learning score is 0.523
# 6/6 [==============================] - 0s 3ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 13/13 [==============================] - 0s 17ms/step - loss: 0.1285 - accuracy: 0.8633
# 2/2 [==============================] - 0s 5ms/step
# 5 time active learning score is 0.636
# emulate process finishes
# query time is 5
# first stage total query time is 15
# self.training_done is True
# simi kind is 3
# finish all cluster binary and active search
# make modification new new
# generate DTW naive positive and negative data
# length of next_result_table is 2
# result table shape is (9000, 101)
# (generator pid=19672) has change code 3
# (generator pid=19671) has change code 3
# (generator pid=19675) has change code 3
# (generator pid=19673) has change code 3
# (generator pid=19674) has change code 3
# finish generating complex parameters for all clusters and predict label by using active learner
# shape of table is (150000, 9)
# finish split
# finish generate label
# train data shape is (92115, 10)
# validate data shape is (23027, 10)
# 938/938 [==============================] - 2s 2ms/step
# initial active learning accuracy is 0.59
# 720/720 [==============================] - 1s 2ms/step
# further learning teach, generate more data
# 2879/2879 [==============================] - 5s 2ms/step
# train complex shape is (92115, 10)
# query index shape is (5,)
# 13/13 [==============================] - 0s 15ms/step - loss: 0.1195 - accuracy: 0.8675
# 720/720 [==============================] - 1s 2ms/step
# 1 time fur active learning score is 0.569
# 720/720 [==============================] - 1s 2ms/step
# further learning teach, generate more data
# 2879/2879 [==============================] - 5s 2ms/step
# train complex shape is (92110, 10)
# query index shape is (5,)
# 13/13 [==============================] - 0s 14ms/step - loss: 0.1195 - accuracy: 0.8889
# 720/720 [==============================] - 1s 2ms/step
# 2 time fur active learning score is 0.586
# 720/720 [==============================] - 2s 2ms/step
# further learning teach, generate more data
# 2879/2879 [==============================] - 6s 2ms/step
# train complex shape is (92105, 10)
# query index shape is (5,)
# 13/13 [==============================] - 0s 14ms/step - loss: 0.1060 - accuracy: 0.9049
# 720/720 [==============================] - 1s 2ms/step
# 3 time fur active learning score is 0.527
# 720/720 [==============================] - 1s 2ms/step
# further learning teach, generate more data
# 2879/2879 [==============================] - 4s 2ms/step
# train complex shape is (92100, 10)
# query index shape is (5,)
# 13/13 [==============================] - 0s 14ms/step - loss: 0.1372 - accuracy: 0.8602
# 720/720 [==============================] - 1s 2ms/step
# 4 time fur active learning score is 0.513
# 720/720 [==============================] - 1s 2ms/step
# further learning teach, generate more data
# 2878/2878 [==============================] - 4s 2ms/step
# train complex shape is (92095, 10)
# query index shape is (5,)
# 14/14 [==============================] - 0s 14ms/step - loss: 0.1047 - accuracy: 0.9071
# 720/720 [==============================] - 1s 2ms/step
# 5 time fur active learning score is 0.578
# 720/720 [==============================] - 1s 2ms/step
# second stage total query time is 5
# total query time is 20
# 938/938 [==============================] - 1s 2ms/step
# final AL accuracy is 0.59
# accuracy threshold is 0.75
# final accuracy is 0.59
# accuracy threshold is 0.75
# #######################################################################################

# %%
res.x
# Out:
# [8, 0.0]
