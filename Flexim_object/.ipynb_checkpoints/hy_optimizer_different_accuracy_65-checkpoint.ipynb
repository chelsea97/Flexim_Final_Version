# %%
import pandas as pd
data = pd.read_csv("./"+"all_stocks_5yr.csv",index_col = None)
data = data["close"].values
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
data = scaler.fit_transform(data.reshape(-1,1))
import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import skopt
from scikeras.wrappers import KerasClassifier
import tensorflow as tf
from modAL.batch import uncertainty_batch_sampling
#from Active_Emulate_TestD_gp import Active_Emulate_Test as ace
#from NN import NN as nn
from keras.utils.np_utils import to_categorical
from sklearn.preprocessing import MinMaxScaler
from dtaidistance import dtw
from numpy import dot
from numpy.linalg import norm
import sys
from sklearn.utils import shuffle
import copy
import emulate_st500_em_new_write_exac as et
import importlib
import Active_Emulate_st500_em_new_exac as at

# %%
parameter_directory = "all_stocks_5yr"
file = open("./"+parameter_directory+".txt","r")
lines = file.readlines()
sample_size = int(lines[0].strip('\n'))
simi_kind = 3
cluster_number = int(lines[2].strip('\n'))
similarity_threshold = 0.65

# %%
#emulate single new
def obj(params,params_2,simi_kind):
    print("simi_kind is {}".format(simi_kind))
    emulate = et.Emulate_TestD(data,parameter_directory,simi_kind,cluster_number,sample_size,similarity_threshold)
    emulate.load_encoder_model(parameter_directory)
    emulate.load_kmeans_model(parameter_directory)
    emulate.__init_lin__()
    emulate.__init_both_cluster_directory__(cluster_number)
    emulate.__init_limit_dictionary__()
    emulate.add_cluster_dict()
    emulate.get_max_distance(instance_number = 30000)
    emulate.sample()
    emulate.load_parameter(params_2)
    emulate.__fetch__(simi_kind,params)
    print("final accuracy is {}".format(emulate.final_accuracy))
    print("accuracy threshold is {}".format(emulate.similarity_threshold))
    print("wass distance is {}".format(emulate.wasserstein_distance_flexim))
    print('#######################################################################################')
    return emulate.wasserstein_distance_flexim

# %%
params = [-2.16,6,9]
SPACE = [
   skopt.space.Integer(0,50,name = 'gamma 1'),
   skopt.space.Real(0,1,name = 'label_smoothing'),
   skopt.space.Integer(0,50,name = 'gamma 2'),
   skopt.space.Real(0,1,name = 'label_smoothing 2'),
]

# %%
res = skopt.gp_minimize(lambda x: obj(params,x,simi_kind),SPACE,n_calls = 50,random_state = 44,n_jobs = -1)
# Out:
# simi_kind is 3
# Metal device set to: Apple M1 Max
# 2022-10-26 11:39:55.317876: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2022-10-26 11:39:55.318072: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# length of distance list is 30000
# self.max_distance is 13.016
# random value is 40
# start point is 395718
# has already got sample
# self.training_done is False
# simi kind is 3
# run first fetch
# new1
# 1 binary fetch
# self.training_done is False
# simi kind is 3
# run active learning fetch for current cluster
# generate naive complex alpha parameter
# finish generating naive parameters for current cluster
# finish generating naive parameters for current cluster
# initial active learner model
# active learning keras model run
# gamma is 22
# label smoothing is 0.031774802093509365
# batch size is 5
# active learning keras model run
# gamma is 0
# label smoothing is 0
# 2022-10-26 11:39:57.174061: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2022-10-26 11:39:57.338513: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 3/3 [==============================] - 2s 27ms/step - loss: 1.6033e-07 - accuracy: 0.5500
# 5/5 [==============================] - 0s 8ms/step - loss: 1.5615e-07 - accuracy: 0.6562
# accuracy threshold is 0.65
# run into active learning emulate process
# 1/1 [==============================] - 0s 44ms/step
# active learning initial score is 0.571
# emulate train unlabel shape is (192, 9)
# query instance shape is (48, 9)
# query instance shape is (44, 9)
# transform result shape is (44, 100)
# 6/6 [==============================] - 0s 2ms/step
# query instance shape is (5, 9)
# query instance shape is (2, 9)
# transform result shape is (2, 100)
# train
# 1/6 [====>.........................] - ETA: 0s - loss: 1.5927e-07 - accuracy: 0.7188
# 2022-10-26 11:39:59.472911: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 6/6 [==============================] - 1s 115ms/step - loss: 1.5511e-07 - accuracy: 0.6543
# 2/2 [==============================] - 0s 169ms/step
# 1 time active learning score is 0.455
# 6/6 [==============================] - 0s 4ms/step
# query instance shape is (5, 9)
# query instance shape is (4, 9)
# transform result shape is (4, 100)
# train
# 6/6 [==============================] - 0s 88ms/step - loss: 1.5337e-07 - accuracy: 0.6446
# 2/2 [==============================] - 0s 3ms/step
# 2 time active learning score is 0.432
# 6/6 [==============================] - 0s 3ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 6/6 [==============================] - 0s 71ms/step - loss: 1.5282e-07 - accuracy: 0.6901
# 2/2 [==============================] - 0s 3ms/step
# 3 time active learning score is 0.386
# 6/6 [==============================] - 0s 3ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 6/6 [==============================] - 0s 8ms/step - loss: 1.5342e-07 - accuracy: 0.7102
# 2/2 [==============================] - 0s 3ms/step
# 4 time active learning score is 0.386
# 6/6 [==============================] - 0s 2ms/step
# query instance shape is (5, 9)
# query instance shape is (4, 9)
# transform result shape is (4, 100)
# train
# 6/6 [==============================] - 0s 17ms/step - loss: 1.5119e-07 - accuracy: 0.6944
# 2/2 [==============================] - 0s 2ms/step
# 5 time active learning score is 0.409
# 6/6 [==============================] - 0s 28ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 6/6 [==============================] - 0s 14ms/step - loss: 1.4987e-07 - accuracy: 0.6703
# 2/2 [==============================] - 0s 2ms/step
# 6 time active learning score is 0.477
# 6/6 [==============================] - 0s 4ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 6/6 [==============================] - 0s 14ms/step - loss: 1.4592e-07 - accuracy: 0.7421
# 2/2 [==============================] - 0s 3ms/step
# 7 time active learning score is 0.432
# 5/5 [==============================] - 0s 4ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 7/7 [==============================] - 0s 49ms/step - loss: 1.4482e-07 - accuracy: 0.7128
# 2/2 [==============================] - 0s 2ms/step
# 8 time active learning score is 0.432
# 5/5 [==============================] - 0s 4ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 7/7 [==============================] - 0s 54ms/step - loss: 1.4478e-07 - accuracy: 0.7250
# 2/2 [==============================] - 0s 2ms/step
# 9 time active learning score is 0.432
# 5/5 [==============================] - 0s 3ms/step
# query instance shape is (5, 9)
# query instance shape is (4, 9)
# transform result shape is (4, 100)
# train
# 7/7 [==============================] - 0s 37ms/step - loss: 1.3949e-07 - accuracy: 0.7353
# 2/2 [==============================] - 0s 3ms/step
# 10 time active learning score is 0.455
# emulate process finishes
# query time is 10
# first stage total query time is 10
# self.training_done is True
# simi kind is 3
# run next cluster
# random value is 106
# start point is 36071
# has already resample
# self.training_done is False
# simi kind is 3
# run first fetch
# new1
# 2 binary fetch
# self.training_done is False
# simi kind is 3
# run active learning fetch for current cluster
# generate naive complex alpha parameter
# finish generating naive parameters for current cluster
# finish generating naive parameters for current cluster
# continue training active learner mdoel
# teach active learning model
# 9/9 [==============================] - 0s 11ms/step - loss: 1.4675e-07 - accuracy: 0.6761
# train unlabel shape is (192, 9)
# run into active learning emulate process
# 1/1 [==============================] - 0s 8ms/step
# active learning initial score is 0.476
# emulate train unlabel shape is (192, 9)
# query instance shape is (48, 9)
# query instance shape is (48, 9)
# transform result shape is (48, 100)
# 6/6 [==============================] - 0s 2ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 10/10 [==============================] - 1s 122ms/step - loss: 1.4400e-07 - accuracy: 0.6609
# 2/2 [==============================] - 0s 9ms/step
# 1 time active learning score is 0.562
# 6/6 [==============================] - 0s 2ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 10/10 [==============================] - 0s 8ms/step - loss: 1.4526e-07 - accuracy: 0.6939
# 2/2 [==============================] - 0s 3ms/step
# 2 time active learning score is 0.5
# 6/6 [==============================] - 0s 2ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 10/10 [==============================] - 0s 8ms/step - loss: 1.4188e-07 - accuracy: 0.6957
# 2/2 [==============================] - 0s 3ms/step
# 3 time active learning score is 0.542
# 6/6 [==============================] - 0s 2ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 10/10 [==============================] - 0s 8ms/step - loss: 1.3998e-07 - accuracy: 0.7303
# 2/2 [==============================] - 0s 3ms/step
# 4 time active learning score is 0.542
# 6/6 [==============================] - 0s 2ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 10/10 [==============================] - 0s 14ms/step - loss: 1.3856e-07 - accuracy: 0.7120
# 2/2 [==============================] - 0s 3ms/step
# 5 time active learning score is 0.562
# 6/6 [==============================] - 0s 2ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 10/10 [==============================] - 0s 13ms/step - loss: 1.3539e-07 - accuracy: 0.7389
# 2/2 [==============================] - 0s 2ms/step
# 6 time active learning score is 0.562
# 6/6 [==============================] - 0s 2ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 10/10 [==============================] - 0s 11ms/step - loss: 1.3378e-07 - accuracy: 0.7586
# 2/2 [==============================] - 0s 3ms/step
# 7 time active learning score is 0.562
# 5/5 [==============================] - 0s 2ms/step
# query instance shape is (5, 9)
# query instance shape is (4, 9)
# transform result shape is (4, 100)
# train
# 11/11 [==============================] - 0s 8ms/step - loss: 1.3194e-07 - accuracy: 0.7678
# 2/2 [==============================] - 0s 2ms/step
# 8 time active learning score is 0.562
# 5/5 [==============================] - 0s 2ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 11/11 [==============================] - 0s 8ms/step - loss: 1.3126e-07 - accuracy: 0.7530
# 2/2 [==============================] - 0s 2ms/step
# 9 time active learning score is 0.583
# 5/5 [==============================] - 0s 2ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 11/11 [==============================] - 0s 43ms/step - loss: 1.3315e-07 - accuracy: 0.7357
# 2/2 [==============================] - 0s 3ms/step
# 10 time active learning score is 0.542
# emulate process finishes
# query time is 10
# first stage total query time is 20
# self.training_done is True
# simi kind is 3
# run next cluster
# random value is 2
# start point is 70704
# has already resample
# self.training_done is False
# simi kind is 3
# run first fetch
# new1
# 3 binary fetch
# self.training_done is False
# simi kind is 3
# run active learning fetch for current cluster
# generate naive complex alpha parameter
# finish generating naive parameters for current cluster
# finish generating naive parameters for current cluster
# continue training active learner mdoel
# teach active learning model
# 13/13 [==============================] - 0s 12ms/step - loss: 1.8647e-07 - accuracy: 0.6102
# train unlabel shape is (192, 9)
# run into active learning emulate process
# 1/1 [==============================] - 0s 9ms/step
# active learning initial score is 0.19
# emulate train unlabel shape is (192, 9)
# query instance shape is (48, 9)
# query instance shape is (44, 9)
# transform result shape is (44, 100)
# 6/6 [==============================] - 0s 2ms/step
# query instance shape is (5, 9)
# query instance shape is (2, 9)
# transform result shape is (2, 100)
# train
# 13/13 [==============================] - 0s 12ms/step - loss: 1.5736e-07 - accuracy: 0.6410
# 2/2 [==============================] - 0s 3ms/step
# 1 time active learning score is 0.523
# 6/6 [==============================] - 0s 2ms/step
# query instance shape is (5, 9)
# query instance shape is (3, 9)
# transform result shape is (3, 100)
# train
# 14/14 [==============================] - 0s 11ms/step - loss: 1.4129e-07 - accuracy: 0.7105
# 2/2 [==============================] - 0s 3ms/step
# 2 time active learning score is 0.545
# 6/6 [==============================] - 0s 2ms/step
# query instance shape is (5, 9)
# query instance shape is (4, 9)
# transform result shape is (4, 100)
# train
# 14/14 [==============================] - 0s 11ms/step - loss: 1.4055e-07 - accuracy: 0.7227
# 2/2 [==============================] - 0s 3ms/step
# 3 time active learning score is 0.5
# 6/6 [==============================] - 0s 2ms/step
# query instance shape is (5, 9)
# query instance shape is (4, 9)
# transform result shape is (4, 100)
# train
# 14/14 [==============================] - 0s 33ms/step - loss: 1.3517e-07 - accuracy: 0.7559
# 2/2 [==============================] - 0s 2ms/step
# 4 time active learning score is 0.568
# 6/6 [==============================] - 0s 2ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 14/14 [==============================] - 1s 43ms/step - loss: 1.3852e-07 - accuracy: 0.6984
# 2/2 [==============================] - 0s 2ms/step
# 5 time active learning score is 0.591
# 6/6 [==============================] - 0s 2ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 14/14 [==============================] - 0s 10ms/step - loss: 1.3167e-07 - accuracy: 0.7385
# 2/2 [==============================] - 0s 2ms/step
# 6 time active learning score is 0.591
# 6/6 [==============================] - 0s 2ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 14/14 [==============================] - 0s 10ms/step - loss: 1.2940e-07 - accuracy: 0.7891
# 2/2 [==============================] - 0s 2ms/step
# 7 time active learning score is 0.545
# 5/5 [==============================] - 0s 2ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 14/14 [==============================] - 0s 9ms/step - loss: 1.2735e-07 - accuracy: 0.7758
# 2/2 [==============================] - 0s 2ms/step
# 8 time active learning score is 0.5
# 5/5 [==============================] - 0s 2ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 15/15 [==============================] - 0s 10ms/step - loss: 1.3033e-07 - accuracy: 0.7539
# 2/2 [==============================] - 0s 3ms/step
# 9 time active learning score is 0.477
# 5/5 [==============================] - 0s 2ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 15/15 [==============================] - 0s 10ms/step - loss: 1.2966e-07 - accuracy: 0.7500
# 2/2 [==============================] - 0s 2ms/step
# 10 time active learning score is 0.591
# emulate process finishes
# query time is 10
# first stage total query time is 30
# self.training_done is True
# simi kind is 3
# finish all cluster binary and active search
# make modification new new
# generate DTW naive positive and negative data
# (generator pid=5300) has change code 3
# (generator pid=5302) has change code 3
# (generator pid=5299) has change code 3
# (generator pid=5301) has change code 3
# (generator pid=5298) has change code 3
# length of next_result_table is 2
