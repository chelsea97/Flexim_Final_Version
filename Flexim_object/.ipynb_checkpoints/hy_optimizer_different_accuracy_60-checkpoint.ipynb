# %%
import pandas as pd
data = pd.read_csv("./"+"all_stocks_5yr.csv",index_col = None)
data = data["close"].values
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
data = scaler.fit_transform(data.reshape(-1,1))

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import skopt
from scikeras.wrappers import KerasClassifier
import tensorflow as tf
from modAL.batch import uncertainty_batch_sampling
#from Active_Emulate_TestD_gp import Active_Emulate_Test as ace
#from NN import NN as nn
from keras.utils.np_utils import to_categorical
from sklearn.preprocessing import MinMaxScaler
from dtaidistance import dtw
from numpy import dot
from numpy.linalg import norm
import sys
from sklearn.utils import shuffle
import copy
import emulate_st500_em_new_write_exac as et
import importlib
import Active_Emulate_st500_em_new_exac as at

# %%
parameter_directory = "all_stocks_5yr"
file = open("./"+parameter_directory+".txt","r")
lines = file.readlines()
sample_size = int(lines[0].strip('\n'))
simi_kind = 3
cluster_number = int(lines[2].strip('\n'))
similarity_threshold = 0.6

# %%
#emulate single new
def obj(params,params_2,simi_kind):
    print("simi_kind is {}".format(simi_kind))
    emulate = et.Emulate_TestD(data,parameter_directory,simi_kind,cluster_number,sample_size,similarity_threshold)
    emulate.load_encoder_model(parameter_directory)
    emulate.load_kmeans_model(parameter_directory)
    emulate.__init_lin__()
    emulate.__init_both_cluster_directory__(cluster_number)
    emulate.__init_limit_dictionary__()
    emulate.add_cluster_dict()
    emulate.get_max_distance(instance_number = 30000)
    emulate.sample()
    emulate.load_parameter(params_2)
    emulate.__fetch__(simi_kind,params)
    print("final accuracy is {}".format(emulate.final_accuracy))
    print("accuracy threshold is {}".format(emulate.similarity_threshold))
    print("wass distance is {}".format(emulate.wasserstein_distance_flexim))
    print('#######################################################################################')
    return emulate.wasserstein_distance_flexim

# %%
params = [-2.16,6,9]
SPACE = [
   skopt.space.Integer(0,50,name = 'gamma 1'),
   skopt.space.Real(0,1,name = 'label_smoothing'),
   skopt.space.Integer(0,50,name = 'gamma 2'),
   skopt.space.Real(0,1,name = 'label_smoothing 2'),
]

# %%
res = skopt.gp_minimize(lambda x: obj(params,x,simi_kind),SPACE,n_calls = 50,random_state = 44,n_jobs = -1)
# Out:
# simi_kind is 3
# Metal device set to: Apple M1 Max
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# 2022-10-25 23:06:36.244032: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2022-10-25 23:06:36.244178: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# length of distance list is 30000
# self.max_distance is 13.016
# random value is 40
# start point is 395718
# has already got sample
# self.training_done is False
# simi kind is 3
# run first fetch
# new1
# 1 binary fetch
# self.training_done is False
# simi kind is 3
# run active learning fetch for current cluster
# generate naive complex alpha parameter
# finish generating naive parameters for current cluster
# finish generating naive parameters for current cluster
# initial active learner model
# active learning keras model run
# gamma is 22
# label smoothing is 0.031774802093509365
# batch size is 5
# active learning keras model run
# gamma is 0
# label smoothing is 0
# 2022-10-25 23:06:37.916969: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2022-10-25 23:06:38.161818: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 3/3 [==============================] - 1s 34ms/step - loss: 1.7241e-07 - accuracy: 0.4500
# 5/5 [==============================] - 0s 15ms/step - loss: 1.6857e-07 - accuracy: 0.6000
# accuracy threshold is 0.6
# run into active learning emulate process
# 1/1 [==============================] - 0s 76ms/step
# active learning initial score is 0.429
# emulate train unlabel shape is (192, 9)
# query instance shape is (48, 9)
# query instance shape is (44, 9)
# transform result shape is (44, 100)
# 6/6 [==============================] - 0s 7ms/step
# query instance shape is (5, 9)
# query instance shape is (2, 9)
# transform result shape is (2, 100)
# train
# 1/6 [====>.........................] - ETA: 0s - loss: 1.7140e-07 - accuracy: 0.5938
# 2022-10-25 23:06:38.709665: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 6/6 [==============================] - 0s 25ms/step - loss: 1.6269e-07 - accuracy: 0.6975
# 2/2 [==============================] - 0s 29ms/step
# 1 time active learning score is 0.5
# 6/6 [==============================] - 0s 5ms/step
# query instance shape is (5, 9)
# query instance shape is (4, 9)
# transform result shape is (4, 100)
# train
# 6/6 [==============================] - 0s 29ms/step - loss: 1.6233e-07 - accuracy: 0.6325
# 2/2 [==============================] - 0s 5ms/step
# 2 time active learning score is 0.523
# 6/6 [==============================] - 0s 6ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 6/6 [==============================] - 0s 15ms/step - loss: 1.5751e-07 - accuracy: 0.6959
# 2/2 [==============================] - 0s 5ms/step
# 3 time active learning score is 0.432
# 6/6 [==============================] - 0s 4ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 6/6 [==============================] - 0s 25ms/step - loss: 1.5474e-07 - accuracy: 0.6932
# 2/2 [==============================] - 0s 8ms/step
# 4 time active learning score is 0.409
# 6/6 [==============================] - 0s 4ms/step
# query instance shape is (5, 9)
# query instance shape is (4, 9)
# transform result shape is (4, 100)
# train
# 6/6 [==============================] - 0s 13ms/step - loss: 1.5420e-07 - accuracy: 0.7000
# 2/2 [==============================] - 0s 6ms/step
# 5 time active learning score is 0.432
# 6/6 [==============================] - 0s 4ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 6/6 [==============================] - 0s 24ms/step - loss: 1.5093e-07 - accuracy: 0.7081
# 2/2 [==============================] - 0s 7ms/step
# 6 time active learning score is 0.432
# 6/6 [==============================] - 0s 8ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 6/6 [==============================] - 0s 14ms/step - loss: 1.4809e-07 - accuracy: 0.7632
# 2/2 [==============================] - 0s 4ms/step
# 7 time active learning score is 0.386
# 5/5 [==============================] - 0s 12ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 7/7 [==============================] - 0s 29ms/step - loss: 1.4775e-07 - accuracy: 0.7487
# 2/2 [==============================] - 0s 9ms/step
# 8 time active learning score is 0.386
# 5/5 [==============================] - 0s 5ms/step
# query instance shape is (5, 9)
# query instance shape is (4, 9)
# transform result shape is (4, 100)
# train
# 7/7 [==============================] - 0s 23ms/step - loss: 1.4793e-07 - accuracy: 0.6432
# 2/2 [==============================] - 0s 4ms/step
# 9 time active learning score is 0.386
# 5/5 [==============================] - 0s 4ms/step
# query instance shape is (5, 9)
# query instance shape is (4, 9)
# transform result shape is (4, 100)
# train
# 7/7 [==============================] - 0s 10ms/step - loss: 1.4684e-07 - accuracy: 0.7488
# 2/2 [==============================] - 0s 4ms/step
# 10 time active learning score is 0.341
# emulate process finishes
# query time is 10
# first stage total query time is 10
# self.training_done is True
# simi kind is 3
# run next cluster
# random value is 106
# start point is 36071
# has already resample
# self.training_done is False
# simi kind is 3
# run first fetch
# new1
# 2 binary fetch
# self.training_done is False
# simi kind is 3
# run active learning fetch for current cluster
# generate naive complex alpha parameter
# finish generating naive parameters for current cluster
# finish generating naive parameters for current cluster
# continue training active learner mdoel
# teach active learning model
# 9/9 [==============================] - 0s 13ms/step - loss: 2.8171e-07 - accuracy: 0.5618
# train unlabel shape is (192, 9)
# run into active learning emulate process
# 1/1 [==============================] - 0s 12ms/step
# active learning initial score is 0.286
# emulate train unlabel shape is (192, 9)
# query instance shape is (48, 9)
# query instance shape is (48, 9)
# transform result shape is (48, 100)
# 6/6 [==============================] - 0s 3ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 9/9 [==============================] - 0s 19ms/step - loss: 1.6574e-07 - accuracy: 0.5903
# 2/2 [==============================] - 0s 8ms/step
# 1 time active learning score is 0.375
# 6/6 [==============================] - 0s 3ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 10/10 [==============================] - 0s 16ms/step - loss: 1.6411e-07 - accuracy: 0.5973
# 2/2 [==============================] - 0s 4ms/step
# 2 time active learning score is 0.375
# 6/6 [==============================] - 0s 3ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 10/10 [==============================] - 0s 23ms/step - loss: 1.4749e-07 - accuracy: 0.6812
# 2/2 [==============================] - 0s 19ms/step
# 3 time active learning score is 0.396
# 6/6 [==============================] - 0s 7ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 10/10 [==============================] - 0s 15ms/step - loss: 1.4838e-07 - accuracy: 0.7063
# 2/2 [==============================] - 0s 13ms/step
# 4 time active learning score is 0.417
# 6/6 [==============================] - 0s 7ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 10/10 [==============================] - 0s 11ms/step - loss: 1.4605e-07 - accuracy: 0.7143
# 2/2 [==============================] - 0s 17ms/step
# 5 time active learning score is 0.479
# 6/6 [==============================] - 0s 3ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 10/10 [==============================] - 0s 18ms/step - loss: 1.4464e-07 - accuracy: 0.6997
# 2/2 [==============================] - 0s 7ms/step
# 6 time active learning score is 0.479
# 6/6 [==============================] - 0s 3ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 10/10 [==============================] - 0s 12ms/step - loss: 1.4296e-07 - accuracy: 0.6761
# 2/2 [==============================] - 0s 3ms/step
# 7 time active learning score is 0.5
# 5/5 [==============================] - 0s 5ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 11/11 [==============================] - 0s 18ms/step - loss: 1.4170e-07 - accuracy: 0.7461
# 2/2 [==============================] - 0s 11ms/step
# 8 time active learning score is 0.521
# 5/5 [==============================] - 0s 3ms/step
# query instance shape is (5, 9)
# query instance shape is (4, 9)
# transform result shape is (4, 100)
# train
# 11/11 [==============================] - 0s 10ms/step - loss: 1.3777e-07 - accuracy: 0.7187
# 2/2 [==============================] - 0s 9ms/step
# 9 time active learning score is 0.5
# 5/5 [==============================] - 0s 11ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 11/11 [==============================] - 0s 14ms/step - loss: 1.3630e-07 - accuracy: 0.7620
# 2/2 [==============================] - 0s 5ms/step
# 10 time active learning score is 0.479
# emulate process finishes
# query time is 10
# first stage total query time is 20
# self.training_done is True
# simi kind is 3
# run next cluster
# random value is 2
# start point is 70704
# has already resample
# self.training_done is False
# simi kind is 3
# run first fetch
# new1
# 3 binary fetch
# self.training_done is False
# simi kind is 3
# run active learning fetch for current cluster
# generate naive complex alpha parameter
# finish generating naive parameters for current cluster
# finish generating naive parameters for current cluster
# continue training active learner mdoel
# teach active learning model
# 13/13 [==============================] - 0s 23ms/step - loss: 1.5654e-07 - accuracy: 0.6602
# train unlabel shape is (192, 9)
# run into active learning emulate process
# 1/1 [==============================] - 0s 13ms/step
# active learning initial score is 0.429
# emulate train unlabel shape is (192, 9)
# query instance shape is (48, 9)
# query instance shape is (44, 9)
# transform result shape is (44, 100)
# 6/6 [==============================] - 0s 4ms/step
# query instance shape is (5, 9)
# query instance shape is (2, 9)
# transform result shape is (2, 100)
# train
# 13/13 [==============================] - 0s 11ms/step - loss: 1.4176e-07 - accuracy: 0.7295
# 2/2 [==============================] - 0s 7ms/step
# 1 time active learning score is 0.568
# 6/6 [==============================] - 0s 3ms/step
# query instance shape is (5, 9)
# query instance shape is (3, 9)
# transform result shape is (3, 100)
# train
# 14/14 [==============================] - 0s 21ms/step - loss: 1.3714e-07 - accuracy: 0.7698
# 2/2 [==============================] - 0s 4ms/step
# 2 time active learning score is 0.591
# 6/6 [==============================] - 0s 3ms/step
# query instance shape is (5, 9)
# query instance shape is (4, 9)
# transform result shape is (4, 100)
# train
# 14/14 [==============================] - 0s 16ms/step - loss: 1.4348e-07 - accuracy: 0.6770
# 2/2 [==============================] - 0s 4ms/step
# 3 time active learning score is 0.523
# 6/6 [==============================] - 0s 8ms/step
# query instance shape is (5, 9)
# query instance shape is (4, 9)
# transform result shape is (4, 100)
# train
# 14/14 [==============================] - 0s 25ms/step - loss: 1.3253e-07 - accuracy: 0.7718
# 2/2 [==============================] - 0s 5ms/step
# 4 time active learning score is 0.591
# 6/6 [==============================] - 0s 8ms/step
# query instance shape is (5, 9)
# query instance shape is (3, 9)
# transform result shape is (3, 100)
# train
# 14/14 [==============================] - 0s 10ms/step - loss: 1.3102e-07 - accuracy: 0.8037
# 2/2 [==============================] - 0s 8ms/step
# 5 time active learning score is 0.636
# 6/6 [==============================] - 0s 16ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 14/14 [==============================] - 0s 19ms/step - loss: 1.3034e-07 - accuracy: 0.7783
# 2/2 [==============================] - 0s 15ms/step
# 6 time active learning score is 0.591
# 6/6 [==============================] - 0s 3ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 14/14 [==============================] - 0s 18ms/step - loss: 1.3013e-07 - accuracy: 0.7831
# 2/2 [==============================] - 0s 4ms/step
# 7 time active learning score is 0.568
# 5/5 [==============================] - 0s 8ms/step
# query instance shape is (5, 9)
# query instance shape is (4, 9)
# transform result shape is (4, 100)
# train
# 14/14 [==============================] - 0s 18ms/step - loss: 1.2842e-07 - accuracy: 0.7896
# 2/2 [==============================] - 0s 5ms/step
# 8 time active learning score is 0.614
# 5/5 [==============================] - 0s 3ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 14/14 [==============================] - 0s 17ms/step - loss: 1.2758e-07 - accuracy: 0.7808
# 2/2 [==============================] - 0s 6ms/step
# 9 time active learning score is 0.591
# 5/5 [==============================] - 0s 11ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 15/15 [==============================] - 0s 12ms/step - loss: 1.2799e-07 - accuracy: 0.7876
# 2/2 [==============================] - 0s 4ms/step
# 10 time active learning score is 0.682
# emulate process finishes
# query time is 10
# first stage total query time is 30
# self.training_done is True
# simi kind is 3
# finish all cluster binary and active search
# make modification new new
# generate DTW naive positive and negative data
# length of next_result_table is 2
# result table shape is (9000, 101)
# (generator pid=13967) has change code 3
# (generator pid=13966) has change code 3
# (generator pid=13963) has change code 3
# (generator pid=13965) has change code 3
# (generator pid=13964) has change code 3
# finish generating complex parameters for all clusters and predict label by using active learner
# shape of table is (150000, 9)
# finish split
# finish generate label
# train data shape is (92115, 10)
# validate data shape is (23027, 10)
# 938/938 [==============================] - 4s 4ms/step
# initial active learning accuracy is 0.58
# further learning teach, generate more data
# 2879/2879 [==============================] - 13s 5ms/step
# train complex shape is (92115, 10)
# query index shape is (5,)
# 15/15 [==============================] - 0s 18ms/step - loss: 1.2400e-07 - accuracy: 0.7790
# 720/720 [==============================] - 3s 4ms/step
# 1 time fur active learning score is 0.566
# further learning teach, generate more data
# 2879/2879 [==============================] - 11s 4ms/step
# train complex shape is (92110, 10)
# query index shape is (5,)
# 15/15 [==============================] - 0s 18ms/step - loss: 1.2689e-07 - accuracy: 0.7857
# 720/720 [==============================] - 3s 4ms/step
# 2 time fur active learning score is 0.583
# further learning teach, generate more data
# 2879/2879 [==============================] - 11s 4ms/step
# train complex shape is (92105, 10)
# query index shape is (5,)
# 15/15 [==============================] - 0s 27ms/step - loss: 1.2223e-07 - accuracy: 0.7944
# 720/720 [==============================] - 3s 4ms/step
# 3 time fur active learning score is 0.606
# further learning teach, generate more data
# 2879/2879 [==============================] - 11s 4ms/step
# train complex shape is (92100, 10)
# query index shape is (5,)
# 15/15 [==============================] - 0s 20ms/step - loss: 1.2699e-07 - accuracy: 0.7775
# 720/720 [==============================] - 3s 4ms/step
# 4 time fur active learning score is 0.56
# further learning teach, generate more data
# 2878/2878 [==============================] - 12s 4ms/step
# train complex shape is (92095, 10)
# query index shape is (5,)
# 15/15 [==============================] - 0s 15ms/step - loss: 1.2740e-07 - accuracy: 0.7673
# 720/720 [==============================] - 3s 5ms/step
# 5 time fur active learning score is 0.563
# further learning teach, generate more data
# 2878/2878 [==============================] - 11s 4ms/step
# train complex shape is (92090, 10)
# query index shape is (5,)
# 16/16 [==============================] - 0s 27ms/step - loss: 1.2197e-07 - accuracy: 0.7988
# 720/720 [==============================] - 2s 3ms/step
# 6 time fur active learning score is 0.568
# further learning teach, generate more data
# 2878/2878 [==============================] - 11s 4ms/step
# train complex shape is (92085, 10)
# query index shape is (5,)
# 16/16 [==============================] - 1s 38ms/step - loss: 1.2291e-07 - accuracy: 0.7885
# 720/720 [==============================] - 4s 5ms/step
# 7 time fur active learning score is 0.562
# further learning teach, generate more data
# 2878/2878 [==============================] - 14s 5ms/step
# train complex shape is (92080, 10)
# query index shape is (5,)
# 16/16 [==============================] - 0s 18ms/step - loss: 1.2017e-07 - accuracy: 0.7805
# 720/720 [==============================] - 4s 5ms/step
# 8 time fur active learning score is 0.527
# further learning teach, generate more data
# 2878/2878 [==============================] - 15s 5ms/step
# train complex shape is (92075, 10)
# query index shape is (5,)
# 16/16 [==============================] - 0s 24ms/step - loss: 1.1683e-07 - accuracy: 0.8270
# 720/720 [==============================] - 4s 5ms/step
# 9 time fur active learning score is 0.556
# further learning teach, generate more data
# 2878/2878 [==============================] - 15s 5ms/step
# train complex shape is (92070, 10)
# query index shape is (5,)
# 16/16 [==============================] - 0s 30ms/step - loss: 1.1769e-07 - accuracy: 0.8068
# 720/720 [==============================] - 4s 5ms/step
# 10 time fur active learning score is 0.578
# second stage total query time is 10
# total query time is 40
# 2879/2879 [==============================] - 14s 5ms/step
# 938/938 [==============================] - 5s 5ms/step
# final train AL accuracy is 0.57
# final test AL accuracy is 0.57
# accuracy threshold is 0.6
# 938/938 [==============================] - 6s 6ms/step
# finish generating naive data and complex data
# 2879/2879 [==============================] - 13s 4ms/step
# 2879/2879 [==============================] - 12s 4ms/step
# 720/720 [==============================] - 2s 3ms/step
# 720/720 [==============================] - 3s 4ms/step
# real prob shape is (115142, 1)
# score shape is (9000, 1)
# real train data shape is (101115, 101)
# flexim train data shape is (101115, 101)
# neg number flexim is 47017
# pos number flexim is 54098
# use bias is False
# gamma is 31
# label smoothing is 0.18441869586192697
# new version 1
# Epoch 1/10
# 2022-10-25 23:11:05.172752: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 3160/3160 [==============================] - ETA: 0s - loss: 8.0683e-10 - accuracy: 0.4984 - precision: 0.5218 - recall: 0.7455
# 2022-10-25 23:12:01.688899: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 3160/3160 [==============================] - 65s 20ms/step - loss: 8.0683e-10 - accuracy: 0.4984 - precision: 0.5218 - recall: 0.7455 - val_loss: 3.9473e-10 - val_accuracy: 0.4751 - val_precision: 0.4946 - val_recall: 0.6827
# Epoch 2/10
# 1575/3160 [=============>................] - ETA: 28s - loss: 3.7914e-10 - accuracy: 0.4829 - precision: 0.5117 - recall: 0.6909
