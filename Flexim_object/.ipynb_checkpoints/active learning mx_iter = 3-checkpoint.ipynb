# %% [markdown]
# # new model architecture active learning hy mx_iter = 3

# %%
import pandas as pd
data = pd.read_csv("./"+"all_stocks_5yr.csv",index_col = None)
data = data["close"].values

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
data = scaler.fit_transform(data.reshape(-1,1))

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import skopt
from scikeras.wrappers import KerasClassifier
import tensorflow as tf
from modAL.batch import uncertainty_batch_sampling
#from Active_Emulate_TestD_gp import Active_Emulate_Test as ace
#from NN import NN as nn
from keras.utils.np_utils import to_categorical
from sklearn.preprocessing import MinMaxScaler
from dtaidistance import dtw
from numpy import dot
from numpy.linalg import norm
import sys
from sklearn.utils import shuffle
import copy
import emulate_st500_em_by as et
import importlib
import Active_Emulate_st500_em_by as at
import NN_st500 as nt

# %%
parameter_directory = "all_stocks_5yr"
file = open("./"+parameter_directory+".txt","r")
lines = file.readlines()
sample_size = int(lines[0].strip('\n'))
simi_kind = 1
cluster_number = int(lines[2].strip('\n'))

# %%
#emulate single new
def obj(params,simi_kind):
    print("simi_kind is {}".format(simi_kind))
    emulate = et.Emulate_TestD(data,parameter_directory,simi_kind,cluster_number,sample_size)
    emulate.load_encoder_model(parameter_directory)
    emulate.load_kmeans_model(parameter_directory)
    emulate.__init_lin__()
    emulate.__init_both_cluster_directory__(cluster_number)
    emulate.__init_limit_dictionary__()
    emulate.add_cluster_dict()
    emulate.get_max_distance(instance_number = 30000)
    #emulate.load_parameter(params_2)
    emulate.sample()
    emulate.__fetch__(simi_kind,params)
    print('#######################################################################################')
    return -1 * emulate.final_accuracy

# %%
SPACE = [
   skopt.space.Real(-4,-1, name = 'learning_rate'),
   skopt.space.Integer(1,10, name='fl number'),
   skopt.space.Integer(1,10, name='sl number'),
   skopt.space.Integer(0,40, name='gamma1'),
   skopt.space.Real(0, 0.7, name='label_smoothing1')
]

# %%
res = skopt.gp_minimize(lambda x: obj(x,simi_kind=1),SPACE,n_calls = 50,random_state = 44)
# Out:
# simi_kind is 1
# Metal device set to: Apple M1 Max
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# 2022-09-30 12:10:28.593824: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2022-09-30 12:10:28.594001: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# length of distance list is 30000
# self.max_distance is 13.016
# random value is 40
# start point is 395718
# has already got sample
# self.training_done is False
# simi kind is 1
# run first fetch
# new1
# 1 binary fetch
# self.training_done is False
# simi kind is 1
# run active learning fetch for current cluster
# generate naive complex alpha parameter
# finish generating naive parameters for current cluster
# finish generating naive parameters for current cluster
# initial active learner model
# active learning keras model run
# gamma is 7
# label smoothing is 0.2074631491785263
# batch size is 5
# 2022-09-30 12:10:29.337987: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2022-09-30 12:10:29.525366: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0277 - accuracy: 0.6000
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0219 - accuracy: 0.6000
# run into active learning emulate process
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 11ms/step
# active learning initial score is 0.905
# emulate train unlabel shape is (192, 9)
# query instance shape is (48, 9)
# query instance shape is (44, 9)
# transform result shape is (44, 100)
# 6/6 [==============================] - 0s 3ms/step
# 6/6 [==============================] - 0s 3ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 2022-09-30 12:10:29.849784: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0161 - accuracy: 0.5882
# 3/3 [==============================] - 0s 10ms/step - loss: 0.0132 - accuracy: 0.5647
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 3ms/step
# 1 time active learning score is 0.545
# 6/6 [==============================] - 0s 3ms/step
# 6/6 [==============================] - 0s 2ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0107 - accuracy: 0.6222
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0094 - accuracy: 0.6222
# 2/2 [==============================] - 0s 3ms/step
# 2/2 [==============================] - 0s 3ms/step
# 2 time active learning score is 0.523
# 6/6 [==============================] - 0s 3ms/step
# 6/6 [==============================] - 0s 2ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0085 - accuracy: 0.6211
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0077 - accuracy: 0.5895
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 3ms/step
# 3 time active learning score is 0.523
# emulate process finishes
# query time is 3
# first stage total query time is 3
# self.training_done is True
# simi kind is 1
# run next cluster
# random value is 106
# start point is 36071
# has already resample
# self.training_done is False
# simi kind is 1
# run first fetch
# new1
# 2 binary fetch
# self.training_done is False
# simi kind is 1
# run active learning fetch for current cluster
# generate naive complex alpha parameter
# finish generating naive parameters for current cluster
# finish generating naive parameters for current cluster
# continue training active learner mdoel
# teach active learning model
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0067 - accuracy: 0.5086
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0063 - accuracy: 0.5257
# train unlabel shape is (192, 9)
# run into active learning emulate process
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# active learning initial score is 0.81
# emulate train unlabel shape is (192, 9)
# query instance shape is (48, 9)
# query instance shape is (48, 9)
# transform result shape is (48, 100)
# 6/6 [==============================] - 0s 2ms/step
# 6/6 [==============================] - 0s 2ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 6/6 [==============================] - 0s 11ms/step - loss: 0.0061 - accuracy: 0.4611
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0060 - accuracy: 0.4278
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 3ms/step
# 1 time active learning score is 0.479
# 6/6 [==============================] - 0s 2ms/step
# 6/6 [==============================] - 0s 2ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 6/6 [==============================] - 0s 12ms/step - loss: 0.0059 - accuracy: 0.4541
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0058 - accuracy: 0.4595
# 2/2 [==============================] - 0s 3ms/step
# 2/2 [==============================] - 0s 2ms/step
# 2 time active learning score is 0.583
# 6/6 [==============================] - 0s 2ms/step
# 6/6 [==============================] - 0s 2ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 6/6 [==============================] - 0s 13ms/step - loss: 0.0059 - accuracy: 0.4368
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0058 - accuracy: 0.4316
# 2/2 [==============================] - 0s 3ms/step
# 2/2 [==============================] - 0s 2ms/step
# 3 time active learning score is 0.562
# emulate process finishes
# query time is 3
# first stage total query time is 6
# self.training_done is True
# simi kind is 1
# run next cluster
# random value is 2
# start point is 70704
# has already resample
# self.training_done is False
# simi kind is 1
# run first fetch
# new1
# 3 binary fetch
# self.training_done is False
# simi kind is 1
# run active learning fetch for current cluster
# generate naive complex alpha parameter
# finish generating naive parameters for current cluster
# finish generating naive parameters for current cluster
# continue training active learner mdoel
# teach active learning model
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0069 - accuracy: 0.4259
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0059 - accuracy: 0.4370
# train unlabel shape is (192, 9)
# run into active learning emulate process
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# active learning initial score is 0.952
# emulate train unlabel shape is (192, 9)
# query instance shape is (48, 9)
# query instance shape is (44, 9)
# transform result shape is (44, 100)
# 6/6 [==============================] - 0s 2ms/step
# 6/6 [==============================] - 0s 2ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0058 - accuracy: 0.4618
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0057 - accuracy: 0.4764
# 2/2 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 2ms/step
# 1 time active learning score is 0.568
# 6/6 [==============================] - 0s 2ms/step
# 6/6 [==============================] - 0s 2ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0057 - accuracy: 0.4750
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0057 - accuracy: 0.4893
# 2/2 [==============================] - 0s 3ms/step
# 2/2 [==============================] - 0s 3ms/step
# 2 time active learning score is 0.659
# 6/6 [==============================] - 0s 2ms/step
# 6/6 [==============================] - 0s 2ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0056 - accuracy: 0.4982
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0056 - accuracy: 0.4982
# 2/2 [==============================] - 0s 3ms/step
# 2/2 [==============================] - 0s 3ms/step
# 3 time active learning score is 0.614
# emulate process finishes
# query time is 3
# first stage total query time is 9
# self.training_done is True
# simi kind is 1
# finish all cluster binary and active search
# make modification new new
# generate L2 naive positive and negative data
# (generator pid=7083) has change code 3
# (generator pid=7086) has change code 3
# (generator pid=7085) has change code 3
# length of next_result_table is 2
# result table shape is (4500, 101)
# (generator pid=7084) has change code 3
# (generator pid=7087) has change code 3
# finish generating complex parameters for all clusters and predict label by using active learner
# shape of table is (150000, 9)
# finish split
# finish generate label
# train data shape is (92115, 10)
# validate data shape is (23027, 10)
# 938/938 [==============================] - 2s 2ms/step
# 938/938 [==============================] - 2s 2ms/step
# initial active learning accuracy is 0.69
# further learning teach, generate more data
# 2879/2879 [==============================] - 5s 2ms/step
#  371/2879 [==>...........................] - ETA: 4s
