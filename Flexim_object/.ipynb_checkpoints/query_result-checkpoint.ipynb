# %% [markdown]
# # plot query result

# %%
import matplotlib.pyplot as plt
query_limit = [2,5,10,20]
Accuracy_batch_size_20 = [0.66,0.76,0.82,0.78]
Accuracy_batch_size_10 = [0.52,0.7,0.81,0.8]
Accuracy_batch_size_5 = [0.53,0.71,0.79,0.79]
Accuracy_batch_size_2 = [0.42,0.45,0.7,0.79]
plt.plot(query_limit,Accuracy_batch_size_2,marker = 'o',label = 'batch size 2')
plt.plot(query_limit,Accuracy_batch_size_5,marker = '*',label = 'batch size 5')
plt.plot(query_limit,Accuracy_batch_size_10,marker = 'x',label = 'batch size 10')
plt.plot(query_limit,Accuracy_batch_size_20,marker = ',',label = 'batch size 20')
plt.xlabel('query limit per cluster')
plt.ylabel('Accuracy')
plt.legend()

# %%
query_sample_batch_2 = [14,40,80,146]
query_sample_batch_5 = [40,100,175,140]
query_sample_batch_10 = [150,200,160,270]
query_sample_batch_20 = [160,260,260,260]
plt.plot(query_sample_batch_2,Accuracy_batch_size_2,marker = 'o',label = 'batch size 2')
plt.plot(query_sample_batch_5,Accuracy_batch_size_5,marker = '*',label = 'batch size 5')
plt.plot(query_sample_batch_10,Accuracy_batch_size_10,marker = 'x',label = 'batch size 10')
plt.plot(query_sample_batch_20,Accuracy_batch_size_20,marker = ',',label = 'batch size 20')
plt.xlabel('total query sample')
plt.ylabel('Accuracy')
plt.legend()

# %%
#batch size is 10
import matplotlib.pyplot as plt
query_limit = [5,10,20]
query_time = [200,160,270]
query_time_rf = [140,120,110]
query_time_rf_committee = [200,140,170]
query_time_em2 = [200,270,280]
query_time_em3 = [90,90,90]
accuracy = [0.7,0.81,0.8]
accuracy_1_a = [0.72,0.77,0.76]
accuracy_1 = [0.76,0.78,0.8]
accuracy_2 = [0.75,0.79,0.75]
accuracy_3 = [0.8,0.81,0.8]
fig,axs = plt.subplots(2,1)
axs[0].plot(query_limit,query_time,label = 'single estimator')
axs[0].plot(query_limit,query_time_rf,label = 'single forest')
axs[0].plot(query_limit,query_time_rf_committee,label = 'random forest committe')
axs[0].plot(query_limit,query_time_em2,label = '')
axs[0].plot(query_limit,query_time_em3,label = 'committee 3')
axs[0].set_xticks([5,10,20])
axs[0].set_xlabel('query limit per cluster')
axs[0].set_ylabel('total query sample')
axs[1].plot(query_limit,accuracy,label = 'single estimator')
axs[1].plot(query_limit,accuracy_1_a,label = 'single forest')
axs[1].plot(query_limit,accuracy_1,label = 'random forest committe')
axs[1].plot(query_limit,accuracy_2,label = 'committee 2')
axs[1].plot(query_limit,accuracy_3,label = 'committee 3')
axs[1].set_xticks([5,10,20])
axs[1].set_xlabel('query limit per cluster')
axs[1].set_ylabel('Accuracy')
axs[0].legend()
axs[1].legend()

# %%
#batch size is 5
import matplotlib.pyplot as plt
query_limit = [5,10,20]
query_time = [125,175,140]
query_time_2 = [110,125,125]
query_time_em = [110,180,145]
query_time_em2 = [125,170,225]
query_time_em3 = [96,90,90]
accuracy = [0.7,0.79,0.79]
accuracy_1_a = [0.72,0.76,0.78]
accuracy_1 = [0.69,0.81,0.8]
accuracy_2 = [0.72,0.79,0.8]
accuracy_3 = [0.74,0.8,0.81]
fig,axs = plt.subplots(2,1)
axs[0].plot(query_limit,query_time,label = 'single estimator')
axs[0].plot(query_limit,query_time_2,label = 'single forest')
axs[0].plot(query_limit,query_time_em,label = 'random forest committe')
axs[0].plot(query_limit,query_time_em2,label = 'new committee 1')
axs[0].plot(query_limit,query_time_em3,label = 'new committee 2')
axs[0].set_xticks([5,10,20])
axs[0].set_xlabel('query limit per cluster')
axs[0].set_ylabel('total query sample')
axs[1].plot(query_limit,accuracy,label = 'single estimator')
axs[1].plot(query_limit,accuracy_1_a,label = 'single forest')
axs[1].plot(query_limit,accuracy_1,label = 'random forest committe')
axs[1].plot(query_limit,accuracy_2,label = 'new committee 1')
axs[1].plot(query_limit,accuracy_3,label = 'new committee 2')
axs[1].set_xticks([5,10,20])
axs[1].set_xlabel('query limit per cluster')
axs[1].set_ylabel('Accuracy')
axs[0].legend()
axs[1].legend()

# %%
#batch size 5 l2
import matplotlib.pyplot as plt
query_limit = [2,3,4,5,10,20,30,60]
query_limit_2 = [2,3,4,5,10,20,30]
accuracy_single_estimator_l2 = [0.39,0.68,0.64,0.59,0.7,0.8,0.87,0.9]
accuracy_single_estimator_l2_ =  [0.39,0.68,0.64,0.59,0.7,0.8,0.87]
accuracy_single_forest_l2 = [0.64,0.53,0.72,0.7,0.81,0.81,0.85,0.9]
accuracy_single_forest_l2_ = [0.64,0.53,0.72,0.7,0.81,0.81,0.85]
accuracy_all_random_forest_l2 = [0.67,0.69,0.74,0.72,0.79,0.87,0.9,0.92]
accuracy_all_random_forest_l2_ = [0.67,0.69,0.74,0.72,0.79,0.87,0.9]
accuracy_committee_another_l2 = [0.64,0.67,0.74,0.71,0.82,0.89,0.88,0.9]
accuracy_committee_another_l2_ = [0.64,0.67,0.74,0.71,0.82,0.89,0.88]
accuracy_committee_another_2_l2 = [0.69,0.72,0.78,0.82,0.85,0.9,0.89,0.93]
accuracy_committee_another_2_l2_ = [0.69,0.72,0.78,0.82,0.85,0.9,0.89]

accuracy_single_estimator_dtw = [0.54,0.41,0.72,0.66,0.8,0.83,0.88,0.9]
accuracy_single_estimator_dtw_ = [0.54,0.41,0.72,0.66,0.8,0.83,0.88]
accuracy_single_forest_dtw = [0.64,0.58,0.49,0.67,0.81,0.87,0.85,0.9]
accuracy_single_forest_dtw_ = [0.64,0.58,0.49,0.67,0.81,0.87,0.85]
accuracy_all_random_forest_dtw = [0.67,0.67,0.71,0.72,0.78,0.87,0.86,0.94]
accuracy_all_random_forest_dtw_ = [0.67,0.67,0.71,0.72,0.78,0.87,0.86]
accuracy_committee_another_dtw = [0.69,0.66,0.64,0.67,0.78,0.88,0.89,0.92]
accuracy_committee_another_dtw_ = [0.69,0.66,0.64,0.67,0.78,0.88,0.89]
accuracy_committee_another_2_dtw = [0.71,0.72,0.76,0.78,0.85,0.9,0.91,0.94]
accuracy_committee_another_2_dtw_ = [0.71,0.72,0.76,0.78,0.85,0.9,0.91]
fig,axs = plt.subplots(2,1)
axs[0].plot(query_limit_2,accuracy_single_estimator_l2_,marker = '*',linestyle="--",label = 'single estimator')
axs[0].plot(query_limit_2,accuracy_single_forest_l2_,marker = 'o',linestyle="--",label = 'single forest')
axs[0].plot(query_limit_2,accuracy_all_random_forest_l2_,marker = '.',linestyle="--",label = 'random forest committe')
axs[0].plot(query_limit_2,accuracy_committee_another_l2_,marker = 'v',linestyle="--",label = 'committee 1')
axs[0].plot(query_limit_2,accuracy_committee_another_2_l2_,marker = '8',linestyle="--",label = 'Flexim committee')
axs[0].set_xticks([2,3,4,5,10,20,30])
axs[0].set_xlabel('query limit per cluster')
axs[0].set_ylabel('final accuracy')
axs[0].set_title('emulate l2 with different model')

axs[1].plot(query_limit_2,accuracy_single_estimator_dtw_,marker = '*',linestyle="--",label = 'single estimator')
axs[1].plot(query_limit_2,accuracy_single_forest_dtw_,marker = 'o',linestyle="--",label = 'single forest')
axs[1].plot(query_limit_2,accuracy_all_random_forest_dtw_,marker = '.',linestyle="--",label = 'random forest committe')
axs[1].plot(query_limit_2,accuracy_committee_another_dtw_,marker = 'v',linestyle="--",label = 'committee 1')
axs[1].plot(query_limit_2,accuracy_committee_another_2_dtw_,marker = '8',linestyle="--",label = 'Flexim committee')
axs[1].set_xticks([2,3,4,5,10,20,30])
axs[1].set_xlabel('query limit per cluster')
axs[1].set_ylabel('Accuracy')
axs[1].set_title('emulate dtw with different model')
axs[0].legend()
axs[1].legend()

# %%
#pretrained model 5 30
import matplotlib.pyplot as plt
query_limit = [2,3,4,5,6,7,8,9,10,20,30]
accuracy_l2_l2 = [0.82,0.84,0.84,0.85,0.85,0.85,0.81,0.86,0.86,0.9,0.91]
accuracy_l2_dtw = [0.81,0.82,0.81,0.81,0.81,0.83,0.83,0.83,0.84,0.89,0.92]
accuracy_l2_cosine = [0.94,0.95,0.95,0.95,0.95,0.95,0.95,0.95,0.95,0.96,0.96]

accuracy_l2 = [0.64,0.64,0.71,0.75,0.81,0.81,0.8,0.83,0.84,0.88,0.89]
accuracy_dtw = [0.64,0.72,0.77,0.75,0.79,0.8,0.82,0.85,0.82,0.85,0.85]
accuracy_cosine = [0.93,0.94,0.95,0.95,0.95,0.95,0.95,0.95,0.95,0.95,0.95]

accuracy_dtw_l2 = [0.76,0.71,0.78,0.79,0.83,0.83,0.82,0.82,0.81,0.88,0.91]
accuracy_dtw_dtw = [0.77,0.76,0.78,0.79,0.83,0.82,0.83,0.84,0.81,0.88,0.9]
accuracy_dtw_cosine = [0.94,0.94,0.95,0.95,0.95,0.95,0.95,0.95,0.95,0.95,0.95]


accuracy_cosine_l2 = [0.62,0.69,0.74,0.74,0.79,0.8,0.83,0.82,0.81,0.87,0.92]
accuracy_cosine_dtw = [0.66,0.7,0.76,0.75,0.77,0.81,0.81,0.84,0.82,0.89,0.9]
accuracy_cosine_cosine = [0.95,0.95,0.95,0.95,0.95,0.95,0.95,0.95,0.95,0.95,0.95]

fig,axs = plt.subplots(1,1)
axs.plot(query_limit,accuracy_l2_l2,marker = '*',linestyle="--",label = 'pretrain - emualte l2')
axs.plot(query_limit,accuracy_l2_dtw,marker = '.',linestyle="--",label = 'pretrain - emualte dtw')
axs.plot(query_limit,accuracy_l2_cosine,marker = 'o',linestyle="--",label = 'pretrain - emulate cosine')
axs.plot(query_limit,accuracy_l2,marker = 'v',linestyle="--",label = 'emulate l2')
axs.plot(query_limit,accuracy_dtw,marker = '8',linestyle="--",label = 'emulate dtw')
axs.plot(query_limit,accuracy_cosine,marker = '>',linestyle="--",label = 'emulate cosine')
axs.set_xticks([2,3,4,5,6,7,8,9,10,20,30])
axs.set_xlabel('query limit per cluster')
axs.set_ylabel('final accuracy')
axs.set_title('pretrained l2 model')

# axs[1].plot(query_limit,accuracy_dtw_l2,label = 'pretrain - emualte l2')
# axs[1].plot(query_limit,accuracy_dtw_dtw,label = 'pretrain - emualte dtw')
# axs[1].plot(query_limit,accuracy_dtw_cosine,label = 'pretrain - emulate cosine')
# axs[1].plot(query_limit,accuracy_l2,label = 'emulate l2')
# axs[1].plot(query_limit,accuracy_dtw,label = 'emulate dtw')
# axs[1].plot(query_limit,accuracy_cosine,label = 'emulate cosine')
# axs[1].set_xticks([2,3,4,5,10,30])
# axs[1].set_xlabel('query limit per cluster')
# axs[1].set_ylabel('Accuracy')
# axs[1].set_title('pretrained dtw model')

# axs[2].plot(query_limit,accuracy_cosine_l2,label = 'pretrain - emualte l2')
# axs[2].plot(query_limit,accuracy_cosine_dtw,label = 'pretrain - emualte dtw')
# axs[2].plot(query_limit,accuracy_cosine_cosine,label = 'pretrain - emulate cosine')
# axs[2].plot(query_limit,accuracy_l2,label = 'emulate l2')
# axs[2].plot(query_limit,accuracy_dtw,label = 'emulate dtw')
# axs[2].plot(query_limit,accuracy_cosine,label = 'emulate cosine')
# axs[2].set_xticks([2,3,4,5,10,30])
# axs[2].set_xlabel('query limit per cluster')
# axs[2].set_ylabel('Accuracy')
# axs[2].set_title('pretrained cosine model')

axs.legend()
# axs[1].legend()
# axs[2].legend()

# %%
import matplotlib.pyplot as plt
query_limit = [2,3,4,5,6,7,8,9,10,20,30]
accuracy_dtw_l2 = [0.76,0.77,0.78,0.79,0.81,0.82,0.83,0.83,0.85,0.88,0.91]
accuracy_dtw_dtw = [0.77,0.76,0.78,0.8,0.82,0.83,0.83,0.84,0.81,0.88,0.9]
accuracy_l2 = [0.64,0.64,0.71,0.75,0.81,0.81,0.82,0.83,0.84,0.88,0.89]
accuracy_dtw = [0.64,0.72,0.77,0.75,0.79,0.8,0.82,0.85,0.82,0.85,0.85]
fig,axs = plt.subplots(1,1)
axs.plot(query_limit,accuracy_dtw_l2,marker = '*',linestyle="--",label = 'pretrain - emualte l2')
#axs.plot(query_limit,accuracy_dtw_dtw,label = 'pretrain - emualte dtw')
axs.plot(query_limit,accuracy_l2,marker = 'o',linestyle="--",label = 'emulate l2 ')
#axs.plot(query_limit,accuracy_dtw,label = 'emulate dtw')
axs.set_xticks([2,3,4,5,6,7,8,9,10,20,30])
axs.set_xlabel('query limit per cluster')
axs.set_ylabel('final accuracy')
axs.set_title('pretrained dtw model')
axs.legend()

# %%
import matplotlib.pyplot as plt
query_limit = [2,3,4,5,6,7,8,9,10,20,30]
accuracy_cosine_l2 = [0.62,0.69,0.74,0.74,0.79,0.8,0.83,0.82,0.81,0.87,0.92]
accuracy_cosine_dtw = [0.66,0.7,0.76,0.75,0.77,0.81,0.81,0.84,0.82,0.89,0.9]
accuracy_l2 = [0.64,0.64,0.71,0.75,0.81,0.81,0.8,0.83,0.84,0.88,0.89]
accuracy_dtw = [0.64,0.72,0.77,0.75,0.79,0.8,0.82,0.85,0.82,0.85,0.85]
fig,axs = plt.subplots(1,1)
axs.plot(query_limit,accuracy_cosine_l2,marker = '*',linestyle="--",label = 'pretrain - emualte l2')
axs.plot(query_limit,accuracy_cosine_dtw,marker = 'o',linestyle="--",label = 'pretrain - emualte dtw')
#axs.plot(query_limit,accuracy_l2_cosine,label = 'pretrain - emulate cosine')
axs.plot(query_limit,accuracy_l2,marker = 'v',linestyle="--",label = 'emulate l2')
axs.plot(query_limit,accuracy_dtw,marker = '>',linestyle="--",label = 'emulate dtw')
#axs.plot(query_limit,accuracy_cosine,label = 'emulate cosine')
axs.set_xticks([2,3,4,5,10,30])
axs.set_xlabel('query limit per cluster')
axs.set_ylabel('final accuracy')
axs.set_title('pretrained cosine model')
axs.legend()

# %%
#change pretrained model type to second version(mx_iter = 60, batch size 5)
import matplotlib.pyplot as plt
query_limit = [8,12,16,20,24,28,32,36,40,80,120]
accuracy_l2_l2 = [0.84,0.83,0.85,0.85,0.86,0.84,0.86,0.88,0.87,0.89,0.9]
accuracy_l2_dtw = [0.81,0.84,0.84,0.85,0.85,0.85,0.86,0.87,0.87,0.88,0.9]
accuracy_l2_cosine = [0.93,0.95,0.95,0.95,0.95,0.95,0.95,0.96,0.96,0.96,0.96]

accuracy_dtw_l2 = [0.79,0.82,0.82,0.86,0.86,0.86,0.84,0.86,0.82,0.91,0.91]
accuracy_dtw_dtw = [0.82,0.81,0.83,0.85,0.87,0.88,0.88,0.86,0.88,0.91,0.9]
accuracy_dtw_cosine = [0.94,0.95,0.95,0.95,0.95,0.95,0.95,0.95,0.95,0.95,0.95,0.95]

accuracy_cosine_l2 = [0.69,0.73,0.74,0.77,0.8,0.83,0.85,0.81,0.85,0.91,0.91]
accuracy_cosine_dtw = [0.71,0.71,0.8,0.78,0.83,0.83,0.84,0.87,0.85,0.91,0.92]
accuracy_cosine_cosine = [0.93,0.94,0.95,0.95,0.95,0.95,0.95,0.95,0.95,0.95,0.95]

accuracy_l2 = [0.64,0.64,0.71,0.75,0.81,0.81,0.8,0.83,0.84,0.88,0.89]
accuracy_dtw = [0.64,0.72,0.77,0.78,0.79,0.8,0.81,0.82,0.84,0.85,0.85]
accuracy_cosine = [0.93,0.94,0.95,0.95,0.95,0.95,0.95,0.95,0.95,0.95,0.95]

accuracy_flexim_final_predict_blank = [0.54,0.57,0.65,0.67,0.72,0.74,0.75,0.76,0.8,0.83,0.85]

fig,axs = plt.subplots(1,1)
plt.tick_params(axis='x', labelsize=8.5)
#axs.plot(query_limit,accuracy_l2_l2,marker = '*',linestyle="--",label = 'pretrain - emualte l2')
axs.plot(query_limit,accuracy_l2_dtw,marker = '.',linestyle="--",label = 'Pre-trained(L2 -> DTW)')
#axs.plot(query_limit,accuracy_l2_cosine,marker = 'o',linestyle="--",label = 'pretrain - emulate cosine')
#axs.plot(query_limit,accuracy_l2,marker = 'v',linestyle="--",label = 'emulate l2')
#axs.plot(query_limit,accuracy_dtw,marker = '8',linestyle="--",label = 'blank model')
axs.plot(query_limit,accuracy_flexim_final_predict_blank,marker = '8',linestyle="--",label = 'blank model')
#axs.plot(query_limit,accuracy_cosine,marker = '>',linestyle="--",label = 'emulate cosine')
axs.set_xticks([8,12,16,20,24,28,32,36,40,80,120])
axs.set_ylabel('emulate dtw accuracy')
axs.set_title('pretrained l2 model')
axs.set_xlabel('user label samples number')
axs.legend()
image_format = 'png'
image_name = "l2->DTW.png"
fig.savefig(image_name, format = image_format,dpi=400)

# %%
#change pretrained model type to second version(mx_iter = 60, batch size 5)
import matplotlib.pyplot as plt
query_limit = [8,12,16,20,24,28,32,36,40,80,120]
accuracy_l2_l2 = [0.84,0.83,0.85,0.85,0.86,0.84,0.86,0.88,0.87,0.89,0.9]
accuracy_l2_dtw = [0.81,0.84,0.84,0.85,0.85,0.87,0.86,0.85,0.88,0.87,0.9]
accuracy_l2_cosine = [0.93,0.95,0.95,0.95,0.95,0.95,0.95,0.96,0.96,0.96,0.96]

accuracy_dtw_l2 = [0.79,0.82,0.82,0.86,0.86,0.86,0.865,0.87,0.87,0.91,0.91]
accuracy_dtw_dtw = [0.82,0.81,0.83,0.85,0.87,0.88,0.88,0.86,0.88,0.91,0.9]
accuracy_dtw_cosine = [0.94,0.95,0.95,0.95,0.95,0.95,0.95,0.95,0.95,0.95,0.95]

accuracy_cosine_l2 = [0.69,0.73,0.74,0.77,0.8,0.83,0.85,0.81,0.85,0.91,0.91]
accuracy_cosine_dtw = [0.71,0.71,0.8,0.78,0.83,0.83,0.84,0.87,0.85,0.91,0.92]
accuracy_cosine_cosine = [0.93,0.94,0.95,0.95,0.95,0.95,0.95,0.95,0.95,0.95,0.95]

accuracy_l2 = [0.64,0.64,0.71,0.75,0.81,0.81,0.82,0.83,0.84,0.88,0.89]
accuracy_dtw = [0.64,0.72,0.77,0.75,0.79,0.8,0.82,0.85,0.82,0.85,0.85]
accuracy_cosine = [0.93,0.94,0.95,0.95,0.95,0.95,0.95,0.95,0.95,0.95,0.95]
fig,axs = plt.subplots(1,1)
plt.tick_params(axis='x', labelsize=8.5)
axs.plot(query_limit,accuracy_dtw_l2,marker = '*',linestyle="--",label = 'pretrain DTW-> L2')
#axs.plot(query_limit,accuracy_dtw_dtw,marker = '.',linestyle="--",label = 'pretrain - emualte dtw')
#axs.plot(query_limit,accuracy_dtw_cosine,marker = 'o',linestyle="--",label = 'pretrain - emulate cosine')
axs.plot(query_limit,accuracy_l2,marker = 'v',linestyle="--",label = 'blank')
#axs.plot(query_limit,accuracy_dtw,marker = '8',linestyle="--",label = 'emulate dtw')
#axs.plot(query_limit,accuracy_cosine,marker = '>',linestyle="--",label = 'emulate cosine')
axs.set_xticks([8,12,16,20,24,28,32,36,40,80,120])
axs.set_xlabel('user label samples number')
axs.set_ylabel('emulate L2 accuracy')
axs.set_title('pretrained dtw model')
axs.legend()
image_format = 'png'
image_name = "DTW->L2.png"
fig.savefig(image_name, format = image_format,dpi=400)

# %%
#change pretrained model type to second version(mx_iter = 60, batch size 5)
import matplotlib.pyplot as plt
query_limit = [8,12,16,20,24,28,32,36,40,80,120]
accuracy_l2_l2 = [0.84,0.83,0.85,0.85,0.86,0.84,0.86,0.88,0.87,0.89,0.9]
accuracy_l2_dtw = [0.81,0.84,0.84,0.85,0.85,0.87,0.86,0.85,0.88,0.87,0.9]
accuracy_l2_cosine = [0.93,0.95,0.95,0.95,0.95,0.95,0.95,0.96,0.96,0.96,0.96]

accuracy_dtw_l2 = [0.79,0.82,0.82,0.86,0.86,0.86,0.865,0.87,0.87,0.87,0.91]
accuracy_dtw_dtw = [0.82,0.81,0.83,0.85,0.87,0.88,0.88,0.86,0.88,0.91,0.9]
accuracy_dtw_cosine = [0.94,0.95,0.95,0.95,0.95,0.95,0.95,0.95,0.95,0.95,0.95]

accuracy_cosine_l2 = [0.69,0.73,0.74,0.77,0.8,0.83,0.85,0.81,0.85,0.91,0.91]
accuracy_cosine_dtw = [0.71,0.71,0.8,0.78,0.83,0.83,0.84,0.87,0.85,0.91,0.92]
accuracy_cosine_cosine = [0.93,0.94,0.95,0.95,0.95,0.95,0.95,0.95,0.95,0.95,0.95]

accuracy_l2 = [0.64,0.64,0.71,0.75,0.81,0.81,0.82,0.83,0.84,0.88,0.89]
accuracy_dtw =  [0.64,0.72,0.77,0.78,0.79,0.8,0.81,0.82,0.84,0.85,0.85]
accuracy_cosine = [0.93,0.94,0.95,0.95,0.95,0.95,0.95,0.95,0.95,0.95,0.95]
accuracy_dtw_l2_cosine = [0.8,0.83,0.84,0.865,0.87,0.87,0.89,0.89,0.88,0.89,0.91]
fig,axs = plt.subplots(1,1)
plt.tick_params(axis='x', labelsize=8.5)
axs.plot(query_limit,accuracy_dtw_l2_cosine,marker = '*',linestyle="--",label = 'l2,cosine -> DTW')
axs.plot(query_limit,accuracy_dtw_l2,marker = '.',linestyle="--",label = 'l2 -> DTW')
#axs.plot(query_limit,accuracy_dtw_dtw,marker = '.',linestyle="--",label = 'pretrain - emualte dtw')
#axs.plot(query_limit,accuracy_dtw_cosine,marker = 'o',linestyle="--",label = 'pretrain - emulate cosine')
#axs.plot(query_limit,accuracy_dtw,marker = 'v',linestyle="--",label = 'blank model')
#axs.plot(query_limit,accuracy_dtw,marker = '8',linestyle="--",label = 'emulate dtw')
#axs.plot(query_limit,accuracy_cosine,marker = '>',linestyle="--",label = 'emulate cosine')
axs.set_xticks([8,12,16,20,24,28,32,36,40,80,120])
axs.set_xlabel('user label samples number')
axs.set_ylabel('emulate L2 accuracy')
axs.set_title('emulate dtw by using different model')
axs.legend()
image_format = 'png'
image_name = "accuracy emualte dtw stack compare.png"
fig.savefig(image_name, format = image_format,dpi=400)

# %%
#change pretrained model type to second version(mx_iter = 60, batch size 5)
import matplotlib.pyplot as plt
query_limit = [2,3,4,5,6,7,8,9,10,20,30]
accuracy_l2_l2 = [0.84,0.83,0.85,0.85,0.86,0.84,0.86,0.88,0.87,0.89,0.9]
accuracy_l2_dtw = [0.81,0.84,0.84,0.85,0.85,0.87,0.86,0.85,0.88,0.87,0.9]
accuracy_l2_cosine = [0.93,0.95,0.95,0.95,0.95,0.95,0.95,0.96,0.96,0.96,0.96]

accuracy_dtw_l2 = [0.79,0.82,0.82,0.86,0.86,0.86,0.84,0.86,0.82,0.91,0.91]
accuracy_dtw_dtw = [0.82,0.81,0.83,0.85,0.87,0.88,0.88,0.86,0.88,0.91,0.9]
accuracy_dtw_cosine = [0.94,0.95,0.95,0.95,0.95,0.95,0.95,0.95,0.95,0.95,0.95]

accuracy_cosine_l2 = [0.69,0.73,0.74,0.77,0.8,0.83,0.85,0.81,0.85,0.91,0.91]
accuracy_cosine_dtw = [0.71,0.71,0.8,0.78,0.83,0.83,0.84,0.87,0.85,0.91,0.92]
accuracy_cosine_cosine = [0.93,0.94,0.95,0.95,0.95,0.95,0.95,0.95,0.95,0.95,0.95]

accuracy_l2 = [0.64,0.64,0.71,0.75,0.81,0.81,0.8,0.83,0.84,0.88,0.89]
accuracy_dtw = [0.64,0.72,0.77,0.75,0.79,0.8,0.82,0.85,0.82,0.85,0.85]
accuracy_cosine = [0.93,0.94,0.95,0.95,0.95,0.95,0.95,0.95,0.95,0.95,0.95]
fig,axs = plt.subplots(1,1)
axs.plot(query_limit,accuracy_cosine_l2,marker = '*',linestyle="--",label = 'pretrain - emualte l2')
axs.plot(query_limit,accuracy_cosine_dtw,marker = '.',linestyle="--",label = 'pretrain - emualte dtw')
axs.plot(query_limit,accuracy_cosine_cosine,marker = 'o',linestyle="--",label = 'pretrain - emulate cosine')
axs.plot(query_limit,accuracy_l2,marker = 'v',linestyle="--",label = 'emulate l2')
axs.plot(query_limit,accuracy_dtw,marker = '8',linestyle="--",label = 'emulate dtw')
axs.plot(query_limit,accuracy_cosine,marker = '>',linestyle="--",label = 'emulate cosine')
axs.set_xticks([2,3,4,5,6,7,8,9,10,20,30])
axs.set_xlabel('query limit per cluster')
axs.set_ylabel('final accuracy')
axs.set_title('pretrained cosine model')
axs.legend()

# %%
#compare emulate l2
emulate_l2_model_30_cosine = [0.62,0.69,0.74,0.74,0.79,0.8,0.83,0.82,0.81,0.87,0.92]
emulate_l2_model_30_dtw = [0.76,0.71,0.78,0.79,0.83,0.83,0.82,0.82,0.81,0.88,0.91]
emulate_l2_model_60_cosine = [0.69,0.73,0.74,0.77,0.8,0.83,0.85,0.81,0.85,0.91,0.91]
emulate_l2_model_60_dtw = [0.79,0.82,0.82,0.86,0.86,0.86,0.84,0.86,0.82,0.91,0.91]
accuracy_l2 = [0.64,0.64,0.71,0.75,0.81,0.81,0.8,0.83,0.84,0.88,0.89]
fig,axs = plt.subplots(1,1)
axs.plot(query_limit,emulate_l2_model_30_cosine,marker = '*',linestyle="--",label = 'pretrain cosine 1')
axs.plot(query_limit,emulate_l2_model_30_dtw,marker = '.',linestyle="--",label = 'pretrain dtw 1')
axs.plot(query_limit,emulate_l2_model_60_cosine,marker = 'o',linestyle="--",label = 'pretrain cosine 2')
axs.plot(query_limit,emulate_l2_model_60_dtw,marker = 'v',linestyle="--",label = 'pretrain dtw 2')
axs.plot(query_limit,accuracy_l2,marker = '8',linestyle="--",label = 'emulate l2')
axs.set_xticks([2,3,4,5,6,7,8,9,10,20,30])
axs.set_xlabel('query limit per cluster')
axs.set_ylabel('final accuracy')
axs.set_title('emualte l2 by using different model')
axs.legend()

# %%
#compare emualte dtw
emulate_dtw_model_30_l2 = [0.81,0.82,0.81,0.81,0.81,0.83,0.83,0.83,0.84,0.89,0.92] 
emulate_dtw_model_30_cosine = [0.66,0.7,0.76,0.75,0.77,0.81,0.81,0.84,0.82,0.89,0.9]
emulate_dtw_model_60_l2 = [0.81,0.84,0.84,0.85,0.85,0.87,0.86,0.85,0.88,0.87,0.9]
emulate_dtw_model_60_cosine = [0.71,0.71,0.8,0.78,0.83,0.83,0.84,0.87,0.85,0.91,0.92]
accuracy_dtw = [0.64,0.72,0.77,0.75,0.79,0.8,0.82,0.85,0.82,0.85,0.85]
fig,axs = plt.subplots(1,1)
axs.plot(query_limit,emulate_dtw_model_30_cosine,marker = '*',linestyle="--",label = 'pretrain cosine 1')
axs.plot(query_limit,emulate_dtw_model_30_l2,marker = '.',linestyle="--",label = 'pretrain l2 1')
axs.plot(query_limit,emulate_dtw_model_60_cosine,marker = 'o',linestyle="--",label = 'pretrain cosine 2')
axs.plot(query_limit,emulate_dtw_model_60_l2,marker = 'v',linestyle="--",label = 'pretrain l2 2')
axs.plot(query_limit,accuracy_l2,marker = '8',linestyle="--",label = 'emulate dtw')
axs.set_xticks([2,3,4,5,6,7,8,9,10,20,30])
axs.set_xlabel('query limit per cluster')
axs.set_ylabel('final accuracy')
axs.set_title('emualte dtw by using different model')
axs.legend()

# %%
#compare different active learning model to emulate l2
import matplotlib.pyplot as plt
query_limit = [2,3,4,5,6,7,8,9,10,20,30]
accuracy_l2_l2 = [0.84,0.83,0.85,0.85,0.86,0.84,0.86,0.88,0.87,0.89,0.9]
accuracy_dtw_l2 = [0.79,0.82,0.82,0.86,0.86,0.86,0.84,0.86,0.82,0.91,0.91]
accuracy_cosine_l2 = [0.69,0.73,0.74,0.77,0.8,0.83,0.85,0.81,0.85,0.91,0.91]
accuracy_stack_classifier_all = [0.84,0.87,0.89,0.87,0.87,0.88,0.88,0.89,0.89,0.91,0.93]
accuracy_stack_classifier_cosine_dtw = [0.69,0.73,0.78,0.83,0.84,0.85,0.86,0.86,0.88,0.89,0.9]
accuracy_stack_classifier_cosine_dtw_freeze = [0.65,0.71,0.76,0.78,0.81,0.83,0.84,0.85,0.87,0.87,0.89]
accuracy_new_committee_all = [0.82,0.84,0.86,0.86,0.87,0.86,0.88,0.88,0.88,0.89,0.9]
accuracy_new_committee_cosine_dtw = [0.67,0.67,0.77,0.8,0.82,0.82,0.83,0.85,0.86,0.89,0.9]
accuracy_l2 = [0.64,0.64,0.71,0.75,0.81,0.81,0.82,0.83,0.84,0.88,0.89]
fig,axs = plt.subplots(1,1)
#axs.plot(query_limit,accuracy_l2_l2,marker = '*',linestyle="--",label = 'pretrain l2')
#axs.plot(query_limit,accuracy_dtw_l2,marker = '.',linestyle="--",label = 'pretrain dtw')
#axs.plot(query_limit,accuracy_cosine_l2,marker = 'o',linestyle="--",label = 'pretrain cosine model')
#axs.plot(query_limit,accuracy_stack_classifier_all,marker = '+',linestyle="--",label = 'pretrain stack model')
axs.plot(query_limit,accuracy_stack_classifier_cosine_dtw,marker = 'v',linestyle="--",label = 'pretrain stack cosine+dtw')
#axs.plot(query_limit,accuracy_stack_classifier_cosine_dtw_freeze,marker = '8',linestyle="--",label = 'pretrain stack freeze')
#axs.plot(query_limit,accuracy_new_committee_all,marker = '4',linestyle = '--',label = 'pretrain committee model')
#axs.plot(query_limit,accuracy_new_committee_cosine_dtw,marker = '1',linestyle='--',label = 'pretrain commitee cosine dtw')
axs.plot(query_limit,accuracy_l2,marker = 's', label = 'blank model')
axs.set_xticks([2,3,4,5,6,7,8,9,10,20,30])
axs.set_xlabel('query limit per cluster')
axs.set_ylabel('accuracy')
axs.set_title('emulate l2 by using different model')
axs.legend()

# %%
#compare different active learning model emulate dtw
import matplotlib.pyplot as plt
query_limit = [8,12,16,20,24,28,32,36,40,80,120]
#accuracy_dtw_dtw = [0.82,0.81,0.83,0.85,0.87,0.88,0.88,0.88,0.88,0.91,0.9]
#accuracy_l2_dtw = [0.81,0.84,0.84,0.85,0.85,0.87,0.87,0.85,0.88,0.87,0.9]
#accuracy_cosine_dtw = [0.71,0.71,0.8,0.78,0.83,0.83,0.84,0.87,0.85,0.91,0.92]
accuracy_stack_classifier_all_dtw = [0.84,0.87,0.88,0.89,0.87,0.88,0.88,0.88,0.9,0.92,0.92]
accuracy_stack_classifier_cosine_l2 = [0.83,0.84,0.85,0.86,0.86,0.88,0.9,0.9,0.91,0.91,0.91]
#accuracy_stack_classifier_cosine_l2_freeze = [0.82,0.85,0.87,0.87,0.88,0.89,0.88,0.89,0.91,0.9,0.91]
#accuracy_new_committee_all = [0.82,0.85,0.86,0.88,0.88,0.88,0.88,0.88,0.9,0.91,0.92]
accuracy_new_committee_cosine_l2 = [0.75,0.83,0.82,0.83,0.81,0.81,0.87,0.86,0.86,0.89,0.9]
accuracy_dtw = [0.64,0.72,0.77,0.78,0.79,0.8,0.81,0.82,0.84,0.85,0.85]
accuracy_dtw_l2_cosine = [0.8,0.81,0.84,0.86,0.87,0.87,0.89,0.89,0.88,0.89,0.91]
fig,axs = plt.subplots(1,1)
plt.tick_params(axis='x', labelsize=8.5)
#axs.plot(query_limit,accuracy_dtw_dtw,marker = '*',linestyle="--",label = 'pretrain dtw')
#axs.plot(query_limit,accuracy_l2_dtw,marker = '.',linestyle="--",label = 'pretrain l2')
#axs.plot(query_limit,accuracy_cosine_dtw,marker = 'o',linestyle="--",label = 'pretrain cosine')
#axs.plot(query_limit,accuracy_stack_classifier_all_dtw,marker = 'v',linestyle="--",label = 'pretrain stack')
axs.plot(query_limit,accuracy_dtw_l2_cosine,marker = '*',linestyle="--",label = 'stack model(l2,cosine > DTW)')
axs.plot(query_limit,accuracy_stack_classifier_cosine_l2,marker = '8',linestyle="--",label = 'stack model(l2,cosine,blank > DTW)')
#axs.plot(query_limit,accuracy_stack_classifier_cosine_l2_freeze,marker = '1',linestyle='--',label = 'pretrain freeze')
#axs.plot(query_limit,accuracy_new_committee_all,marker = '+',linestyle='--',label = 'pretrain commitee')
#axs.plot(query_limit,accuracy_new_committee_cosine_l2,marker = '4',linestyle = '--', label = 'pretrain commitee cosine dtw')
#axs.plot(query_limit,accuracy_dtw,marker = 's', label = 'blank model')
axs.set_xticks([8,12,16,20,24,28,32,36,40,80,120])
axs.set_xlabel('query limit per cluster')
axs.set_ylabel('emulate DTW accuracy')
axs.set_title('emulate dtw with/without blank model')
axs.legend()
# image_format = 'png'
# image_name = "accuracy stack compare.png"
# fig.savefig(image_name, format = image_format,dpi=400)

# %%
#compare different active learning model emulate cosine
import matplotlib.pyplot as plt
query_limit = [2,3,4,5,6,7,8,9,10,20,30]
accuracy_cosine_cosine = [0.94,0.94,0.94,0.95,0.95,0.95,0.95,0.95,0.95,0.95,0.95]
accuracy_cosine_l2 = [0.93,0.93,0.93,0.93,0.93,0.93,0.93,0.93,0.94,0.95,0.95]
accuracy_cosine_dtw = [0.94,0.95,0.95,0.95,0.95,0.95,0.95,0.95,0.95,0.95,0.95]
accuracy_stack_classifier_all_cosine = [0.95,0.95,0.95,0.95,0.95,0.95,0.95,0.95,0.95,0.95,0.95]
accuracy_stack_classifier_dtw_l2 = [0.23,0.28,0.33,0.37,0.43,0.5,0.94,0.94,0.95,0.95,0.95]
accuracy_stack_classifier_dtw_l2_freeze = [0.2,0.2,0.21,0.24,0.27,0.27,0.33,0.94,0.94,0.94,0.94]
accuracy_new_committee_all = [0.93,0.95,0.95,0.95,0.95,0.95,0.95,0.95,0.95,0.95,0.95]
accuracy_new_committee_dtw_l2 = [0.6,0.91,0.9,0.94,0.92,0.93,0.94,0.94,0.95,0.95,0.95]
accuracy_cosine = [0.93,0.94,0.95,0.95,0.95,0.95,0.95,0.95,0.95,0.95,0.95]
fig,axs = plt.subplots(1,1)
#axs.plot(query_limit,accuracy_cosine_cosine,marker = '*',linestyle="--",label = 'pretrain cosine')
#axs.plot(query_limit,accuracy_cosine_l2,marker = '.',linestyle="--",label = 'pretrain l2')
#axs.plot(query_limit,accuracy_cosine_dtw,marker = 'o',linestyle="--",label = 'pretrain dtw')
#axs.plot(query_limit,accuracy_stack_classifier_all_cosine,marker = 'v',linestyle="--",label = 'pretrain stack')
axs.plot(query_limit,accuracy_stack_classifier_dtw_l2,marker = '8',linestyle="--",label = 'pretrain stack l2+dtw')
#axs.plot(query_limit,accuracy_stack_classifier_dtw_l2_freeze,marker = '1',linestyle='--',label = 'pretrain freeze')
#axs.plot(query_limit,accuracy_new_committee_all,marker = '+',linestyle='--',label = 'pretrain commitee')
#axs.plot(query_limit,accuracy_new_committee_dtw_l2,marker = '4',linestyle = '--', label = 'pretrain commitee l2 dtw')
axs.plot(query_limit,accuracy_cosine,marker = 's', label = 'random')
axs.set_xticks([2,3,4,5,6,7,8,9,10,20,30])
axs.set_xlabel('query limit per cluster')
axs.set_ylabel('final accuracy')
axs.set_title('emualte cosine by using different model')
axs.legend()

# %%
#search result mx_iter = 10
import matplotlib.pyplot as plt
threshold = [0.6,0.65,0.7,0.75,0.8,0.85,0.9,0.95]
accuracy = [0.91,0.88,0.85,0.8,0.75,0.68,0.57,0.54]
accuracy_random = [0.68,0.67,0.66,0.65,0.6,0.58,0.46,0.39]
fig,axs = plt.subplots(1,1)
axs.plot(threshold,accuracy,marker = '*',linestyle="--",label = 'l2 + cosine')
axs.plot(threshold,accuracy_random,marker = 'v',linestyle="--",label = 'blank model')
axs.set_xticks([0.6,0.65,0.7,0.75,0.8,0.85,0.9,0.95])
axs.set_xlabel('accuracy threshold')
axs.set_ylabel('final accuracy')
axs.set_title('emualte dtw by using different accuracy threshold')
axs.legend()

# %%
#search result mx_iter = 5
import matplotlib.pyplot as plt
threshold = [0.6,0.65,0.7,0.75,0.8,0.85,0.9,0.95]
accuracy = [0.86,0.85,0.83,0.76,0.7,0.69,0.57,0.55]
accuracy_random = [0.69,0.67,0.67,0.65,0.62,0.6,0.56,0.55]
fig,axs = plt.subplots(1,1)
axs.plot(threshold,accuracy,marker = '*',linestyle="--",label = 'l2 + cosine')
axs.plot(threshold,accuracy_random,marker = 'v',linestyle="--",label = 'blank model')
axs.set_xticks([0.6,0.65,0.7,0.75,0.8,0.85,0.9,0.95])
axs.set_xlabel('accuracy threshold')
axs.set_ylabel('final accuracy')
axs.set_title('emualte dtw by using different accuracy threshold')
axs.legend()

# %%
#search result
import matplotlib.pyplot as plt
threshold = [0.6,0.65,0.7,0.75,0.8,0.85,0.9,0.95]
accuracy = [0.83,0.83,0.8,0.78,0.71,0.68,0.55,0.53]
query_time = [3,6,10,20,20,20,20,20]
fig,axs = plt.subplots(2,1)
axs[0].plot(threshold,accuracy,marker = '*',linestyle="--",label = 'emulate dtw')
axs[0].set_xticks([0.6,0.65,0.7,0.75,0.8,0.85,0.9,0.95])
axs[0].set_xlabel('accuracy threshold')
axs[0].set_ylabel('final accuracy')
axs[0].set_title('emualte dtw by using different accuracy threshold')
axs[0].legend()
axs[1].plot(threshold,query_time,marker = '*',linestyle="--",label = 'emulate dtw')
axs[1].set_xticks([0.6,0.65,0.7,0.75,0.8,0.85,0.9,0.95])
axs[1].set_xlabel('accuracy threshold')
axs[1].set_ylabel('query_time')
axs[1].set_title('emualte dtw by using different accuracy threshold')
axs[1].legend()

# %%
#accuracy threshold - train and test accuracy stack classifier
import matplotlib.pyplot as plt
threshold = [0.6,0.65,0.7,0.75,0.8,0.85,0.9,0.95]
train_accuracy = [0.91,0.91,0.89,0.8,0.72,0.71,0.57,0.52]
test_accuracy = [0.89,0.88,0.87,0.77,0.7,0.69,0.56,0.51]
train_accuracy_blank = [0.71,0.7,0.66,0.67,0.64,0.62,0.55,0.5]
test_accuracy_blank = [0.68,0.68,0.67,0.65,0.62,0.61,0.54,0.52]
fig,axs = plt.subplots(2,1)
axs[0].plot(threshold,train_accuracy,marker = '*',linestyle="--",label = 'train accuracy')
axs[0].plot(threshold,test_accuracy,marker = '8',linestyle="--",label = 'test accuracy')
axs[0].set_xticks([0.6,0.65,0.7,0.75,0.8,0.85,0.9,0.95])
axs[0].set_xlabel('accuracy threshold')
axs[0].set_ylabel('final accuracy')
axs[0].set_title('emualte dtw by using different accuracy threshold')
axs[0].legend()
axs[1].plot(threshold,train_accuracy_blank,marker = 'v',linestyle="--",label = 'train accuracy')
axs[1].plot(threshold,test_accuracy_blank,marker = '.',linestyle="--",label = 'test accuracy')
axs[1].set_xticks([0.6,0.65,0.7,0.75,0.8,0.85,0.9,0.95])
axs[1].set_xlabel('accuracy threshold')
axs[1].set_ylabel('accuracy')
axs[1].set_title('emualte dtw by using different accuracy threshold')
axs[1].legend()

# %%
#accuracy threshold - train and test accuracy stack classifier - final estimator nn model
import matplotlib.pyplot as plt
threshold = [0.6,0.65,0.7,0.75,0.8,0.85,0.9,0.95]
train_accuracy = [0.92,0.90,0.89,0.8,0.72,0.71,0.57,0.55]
test_accuracy = [0.89,0.88,0.87,0.77,0.7,0.69,0.56,0.51]
fig,axs = plt.subplots(1,1)
axs.plot(threshold,train_accuracy,marker = '*',linestyle="--",label = 'train accuracy')
axs.plot(threshold,test_accuracy,marker = '8',linestyle="--",label = 'test accuracy')
axs.set_xticks([0.6,0.65,0.7,0.75,0.8,0.85,0.9,0.95])
axs.set_xlabel('accuracy threshold')
axs.set_ylabel('accuracy')
axs.set_title('emualte dtw with pretrain model')
axs.legend()

# %%
#accuracy threshold - train and test accuracy stack classifier - final estimator nn model
import matplotlib.pyplot as plt
threshold = [0.6,0.65,0.7,0.75,0.8,0.85,0.9,0.95]
train_accuracy = [0.71,0.7,0.66,0.67,0.64,0.62,0.55,0.53]
test_accuracy = [0.68,0.68,0.67,0.65,0.62,0.61,0.54,0.52]
fig,axs = plt.subplots(1,1)
axs.plot(threshold,train_accuracy,marker = '*',linestyle="--",label = 'train accuracy')
axs.plot(threshold,test_accuracy,marker = '8',linestyle="--",label = 'test accuracy')
axs.set_xticks([0.6,0.65,0.7,0.75,0.8,0.85,0.9,0.95])
axs.set_xlabel('accuracy threshold')
axs.set_ylabel('accuracy')
axs.set_title('emualte dtw with random initialized model 10')
axs.legend()

# %%
#accuracy threshold - train and test accuracy stack classifier - mx_iter 50
import matplotlib.pyplot as plt
threshold = [0.6,0.65,0.7,0.75,0.8,0.85,0.9,0.95]
train_accuracy = [0.85,0.81,0.7,0.64,0.64,0.64,0.54,0.54]
test_accuracy = [0.82,0.79,0.67,0.65,0.62,0.62,0.55,0.56]
fig,axs = plt.subplots(1,1)
axs.plot(threshold,train_accuracy,marker = '*',linestyle="--",label = 'train accuracy')
axs.plot(threshold,test_accuracy,marker = '8',linestyle="--",label = 'test accuracy')
axs.set_xticks([0.6,0.65,0.7,0.75,0.8,0.85,0.9,0.95])
axs.set_xlabel('accuracy threshold')
axs.set_ylabel('accuracy')
axs.set_title('emualte dtw with random initialized model 50')
axs.legend()

# %%
#accuracy threshold - train and test accuracy stack classifier - mx_iter 50
import matplotlib.pyplot as plt
threshold = [0.6,0.65,0.7,0.75,0.8,0.85,0.9,0.95]
train_accuracy = [0.91,0.82,0.78,0.75,0.74,0.72,0.56,0.53]
test_accuracy = [0.88,0.81,0.77,0.75,0.74,0.72,0.55,0.53]
fig,axs = plt.subplots(1,1)
axs.plot(threshold,train_accuracy,marker = '*',linestyle="--",label = 'train accuracy')
axs.plot(threshold,test_accuracy,marker = '8',linestyle="--",label = 'test accuracy')
axs.set_xticks([0.6,0.65,0.7,0.75,0.8,0.85,0.9,0.95])
axs.set_xlabel('accuracy threshold')
axs.set_ylabel('accuracy')
axs.set_title('emualte dtw with random initialized model 100')
axs.legend()

# %%
#accuracy threshold - test accuracy stack classifier
import matplotlib.pyplot as plt
threshold = [0.6,0.65,0.7,0.75,0.8,0.85,0.9,0.95]
test_accuracy_pretrain = [0.89,0.88,0.87,0.77,0.71,0.69,0.56,0.51]
test_accuracy_pretrain_mx_iter_5 = [0.84,0.81,0.79,0.74,0.66,0.64,0.54,0.52]
test_accuracy_mx_iter_10 = [0.68,0.68,0.67,0.65,0.62,0.61,0.54,0.52]
test_accuracy_mx_iter_50 = [0.82,0.79,0.67,0.65,0.62,0.62,0.55,0.53]
test_accuracy_mx_iter_100 = [0.88,0.81,0.77,0.75,0.72,0.71,0.55,0.53]
fig,axs = plt.subplots(1,1)
axs.plot(threshold,test_accuracy_pretrain,marker = '*',linestyle="--",label = 'pretrain model')
#axs.plot(threshold,test_accuracy_pretrain_mx_iter_5,marker = 'v',linestyle="--",label = 'pretrain model mx_iter 5')
#axs.plot(threshold,test_accuracy_mx_iter_10,marker = ',',linestyle="--",label = 'mx iter 10')
#axs.plot(threshold,test_accuracy_mx_iter_50,marker = '8',linestyle="--",label = 'mx iter 50')
axs.plot(threshold,test_accuracy_mx_iter_100,marker = '.',linestyle="--",label = 'mx iter 100')
axs.set_xticks([0.6,0.65,0.7,0.75,0.8,0.85,0.9,0.95])
axs.set_yticks([0.5,0.6,0.7,0.8,0.9,0.95])
axs.set_xlabel('accuracy threshold')
axs.set_ylabel('test accuracy')
axs.set_title('emualte dtw with random initialized model 100')
axs.legend()

# %%
#accuracy threshold - train accuracy stack classifier
import matplotlib.pyplot as plt
threshold = [0.6,0.65,0.7,0.75,0.8,0.85,0.9,0.95]
train_accuracy_pretrain = [0.91,0.90,0.89,0.8,0.72,0.71,0.57,0.55]
train_accuracy_pretrain_mx_iter5 = [0.83,0.79,0.78,0.72,0.64,0.62,0.54,0.52]
train_accuracy_mx_iter_10 = [0.71,0.7,0.67,0.66,0.64,0.62,0.55,0.52]
train_accuracy_mx_iter_50 = [0.85,0.81,0.7,0.64,0.64,0.64,0.54,0.54]
train_accuracy_mx_iter_100 = [0.91,0.82,0.78,0.75,0.74,0.72,0.56,0.53]
fig,axs = plt.subplots(1,1)
axs.plot(threshold,train_accuracy_pretrain,marker = '*',linestyle="--",label = 'pretrain model')
#axs.plot(threshold,train_accuracy_pretrain_mx_iter5,marker = 'v',linestyle="--",label = 'pretrain model mx_iter 5')
#axs.plot(threshold,train_accuracy_mx_iter_10,marker = ',',linestyle="--",label = 'mx iter 10')
#axs.plot(threshold,train_accuracy_mx_iter_50,marker = '8',linestyle="--",label = 'mx iter 50')
axs.plot(threshold,train_accuracy_mx_iter_100,marker = '.',linestyle="--",label = 'mx iter 100')
axs.set_xticks([0.6,0.65,0.7,0.75,0.8,0.85,0.9,0.95])
axs.set_yticks([0.5,0.6,0.7,0.8,0.9,0.95])
axs.set_xlabel('accuracy threshold')
axs.set_ylabel('train accuracy')
axs.set_title('emualte l2 with random initialized model 100')
axs.legend()

# %%
#evaluate flexim predict
import matplotlib.pyplot as plt
threshold = [0.6,0.65,0.7,0.75,0.8,0.85,0.9,0.95]
accuracy = [0.88,0.88,0.83,0.77,0.69,0.62,0.51,0.5]
#wd_flexim_predict = [0.102,0.092,0.088,0.088,0.091,0.101,0.116,0.119]
#average_l1_flexim = [0.083,0.064,0.120,0.124,0.150,0.181,0.197,0.213]
#wass_flexim = [0.060,0.032,0.0811,0.098,0.069,0.051,0.030,0.053]
fig,axs = plt.subplots(1,1)
axs.plot(threshold,accuracy,marker = '*',linestyle="--",label = 'accuracy')
#axs.plot(threshold,wd_flexim_predict,marker = 'v',linestyle="--",label = 'em flexim predict')
#axs.plot(threshold,average_l1_flexim,marker = ',',linestyle="--",label = 'average l1 flexim')
#axs.plot(threshold,wass_flexim,marker = '8',linestyle="--",label = 'wass flexim')
axs.set_xticks([0.6,0.65,0.7,0.75,0.8,0.85,0.9,0.95])
axs.set_yticks([0.5,0.6,0.7,0.8,0.9,0.95])
axs.set_xlabel('label threshold')
axs.set_ylabel('accuracy')
axs.set_title('emualte dtw with pretrain model')
axs.legend()

# %%
#evaluate flexim predict
import matplotlib.pyplot as plt
threshold = [0.6,0.65,0.7,0.75,0.8,0.85,0.9,0.95]
#accuracy = [0.88,0.88,0.83,0.77,0.69,0.62,0.51,0.5]
wd_flexim_predict = [0.102,0.092,0.088,0.088,0.091,0.101,0.116,0.119]
average_l1_flexim = [0.083,0.064,0.120,0.124,0.150,0.181,0.197,0.213]
wass_flexim = [0.060,0.032,0.0811,0.098,0.069,0.051,0.030,0.053]
fig,axs = plt.subplots(1,1)
#axs.plot(threshold,accuracy,marker = '*',linestyle="--",label = 'accuracy')
axs.plot(threshold,wd_flexim_predict,marker = 'v',linestyle="--",label = 'em flexim predict')
axs.plot(threshold,average_l1_flexim,marker = ',',linestyle="--",label = 'average l1 flexim')
axs.plot(threshold,wass_flexim,marker = '8',linestyle="--",label = 'wass flexim')
axs.set_xticks([0.6,0.65,0.7,0.75,0.8,0.85,0.9,0.95])
axs.set_xlabel('label threshold')
#axs.set_ylabel('emd flexim predict prob')
axs.set_title('emualte dtw with pretrain model')
axs.legend()

# %%
import matplotlib.pyplot as plt
threshold = [0.6,0.65,0.7,0.75,0.8,0.85,0.9,0.95]
wass_flexim = [0.044,0.041,0.05,0.082,0.08,0.054,0.044,0.034]
wass_single_model = [0.088,0.052,0.081,0.038,0.05,0.045,0.042,0.072]
wass_optimal_stack_model = [0.016,0.016,0.016,0.039,0.014,0.031,0.015,0.038]
wass_optimal_single = [0.011,0.013,0.014,0.014,0.017,0.014,0.008,0.008]
fig,axs = plt.subplots(1,1)
axs.plot(threshold,wass_optimal_single,marker = ',',linestyle="--",label = 'optimal wass flexim single')
axs.plot(threshold,wass_flexim,marker = '8',linestyle="--",label = 'wass flexim')
axs.plot(threshold,wass_single_model,marker = 'v',linestyle="--",label = 'wass flexim single')
axs.plot(threshold,wass_optimal_stack_model,marker = '.',linestyle="--",label = 'optimal wass flexim stack')
axs.set_xticks([0.6,0.65,0.7,0.75,0.8,0.85,0.9,0.95])
axs.set_xlabel('threshold')
axs.set_ylabel('emd')
axs.set_title('emualte dtw with pretrain model')
axs.legend()

#compare emd result between flexim predict and real score without data generation

# %%
import matplotlib.pyplot as plt
threshold = [0.6,0.65,0.7,0.75,0.8,0.85,0.9,0.95]
wass_optimal_l2 = [0.016,0.017,0.018,0.017,0.018,0.019,0.02,0.022]
wass_optimal_l2_cosine = [0.016,0.015,0.016,0.017,0.018,0.019,0.019,0.017]
wass_optimal_stack_model = [0.015,0.014,0.013,0.0134,0.013,0.016,0.017,0.013]
wass_optimal_single = [0.018,0.020,0.025,0.024,0.025,0.027,0.028,0.025]
fig,axs = plt.subplots(1,1)
axs.plot(threshold,wass_optimal_single,marker = ',',linestyle="--",label = 'single blank')
axs.plot(threshold,wass_optimal_l2,marker = '8',linestyle="--",label = 'single pre-trained with l2')
axs.plot(threshold,wass_optimal_l2_cosine,marker = 'v',linestyle="--",label = 'stacked l2 and cosine with no blank model')
axs.plot(threshold,wass_optimal_stack_model,marker = '.',linestyle="--",label = 'stacked l2 and cosine with blank model')
axs.set_xticks([0.6,0.65,0.7,0.75,0.8,0.85,0.9,0.95])
axs.set_xlabel('threshold')
axs.set_ylabel('optimal emd')
axs.set_title('emualte dtw with different types of model')
axs.legend()

#compare emd result between flexim predict and real score without data generation

# %%
#single model
import matplotlib.pyplot as plt
data_06 = [0.0216,0.101,0.071,0.133,0.107]
data_065 = [0.070,0.04,0.104,0.029,0.020]
data_070 = [0.031,0.132,0.043,0.155,0.043] #0.0808
data_075 = [0.047,0.0374,0.0529,0.0244,0.0284]
data_080 = [0.071,0.0621,0.0441,0.0374,0.03498]
data_085 = [0.0971,0.0629,0.036,0.0150,0.0171]
data_090 = [0.062,0.048,0.022,0.028,0.049]
data_095 = [0.089,0.092,0.091,0.045,0.043]
box_plot_data = [data_06,data_065,data_070,data_075,data_080,data_085,data_090,data_095]
ax = plt.axes()
ax.set_xticklabels(['0.6', '0.65', '0.7', '0.75','0.8','0.85','0.9','0.95'])
plt.boxplot(box_plot_data)
plt.xlabel('')
plt.title('emd single model')
plt.show()
# Out:
# /var/folders/4z/gzmqjm993zs1qxkglvxg9xwr0000gn/T/ipykernel_50317/231703574.py:13: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(['0.6', '0.65', '0.7', '0.75','0.8','0.85','0.9','0.95'])

# %%
#stack model
import matplotlib.pyplot as plt
data_06 = [0.05,0.05,0.03,0.05,0.04]
data_065 = [0.053,0.055,0.026,0.029,0.042]
data_070 = [0.055,0.052,0.039,0.062,0.045] #0.0808
data_075 = [0.083,0.076,0.080,0.079,0.092]
data_080 = [0.075,0.104,0.074,0.06,0.083]
data_085 = [0.075,0.05,0.053,0.043,0.047]
data_090 = [0.045,0.03,0.053,0.043,0.047]
data_095 = [0.028,0.033,0.043,0.034,0.032]
ax = plt.axes()
ax.set_xticklabels(['0.6', '0.65', '0.7', '0.75','0.8','0.85','0.9','0.95'])
box_plot_data = [data_06,data_065,data_070,data_075,data_080,data_085,data_090,data_095]
plt.boxplot(box_plot_data)
plt.title('emd stack model')
plt.show()
# Out:
# /var/folders/4z/gzmqjm993zs1qxkglvxg9xwr0000gn/T/ipykernel_50317/551078633.py:12: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(['0.6', '0.65', '0.7', '0.75','0.8','0.85','0.9','0.95'])

# %%
import matplotlib.pyplot as plt
threshold = [0.6,0.65,0.7,0.75,0.8,0.85,0.9,0.95]
gamma_parameter = [27,26,25,47,15,0,10,12]
wass_optimal_single = [0.011,0.013,0.014,0.014,0.017,0.014,0.008,0.008]
fig,axs = plt.subplots(1,1)
axs.plot(threshold,wass_optimal_single,marker = ',',linestyle="--",label = 'optimal wass flexim')
axs.plot(threshold,gamma_parameter,marker = '8',linestyle="--",label = 'gamma value')
axs.set_xticks([0.6,0.65,0.7,0.75,0.8,0.85,0.9,0.95])
axs.set_xlabel('threshold')
axs.set_title('emualte dtw with pretrain model')
axs.legend()

# %%
#compare emd of flexim predict and emd of final model(stackclassifier)
import matplotlib.pyplot as plt
mx_iter_time = [2,3,4,5,6,7,8,9,10,20,30]
emd_flexim_predict = [0.088,0.085,0.084,0.092,0.1,0.0914,0.103,0.1,0.106,0.121,0.131]
emd_final_model = [0.05,0.051,0.063,0.048,0.055,0.061,0.062,0.061,0.057,0.069,0.063]
fig,axs = plt.subplots(1,1)
axs.plot(mx_iter_time,emd_flexim_predict,marker = ',',linestyle="--",label = 'emd flexim')
axs.plot(mx_iter_time,emd_final_model,marker = '8',linestyle="--",label = 'emd final')
axs.set_xticks([2,3,4,5,6,7,8,9,10,20,30])
axs.set_xlabel('mx_iter')
axs.set_ylabel('emd')
axs.set_title('gap between flexim emd and final model emd')
axs.legend()
image_format = 'png'
image_name = "emd gap between flexim and final.png"
fig.savefig(image_name, format = image_format,dpi=400)

# %%
#compare emd of flexim predict and emd of final model(single model)
import matplotlib.pyplot as plt
mx_iter_time = [2,3,4,5,6,7,8,9,10,20,30]
emd_flexim_predict_single = [0.13,0.143,0.141,0.144,0.134,0.133,0.129,0.121,0.11,0.11,0.107]
emd_final_model_single = [0.054,0.049,0.033,0.026,0.034,0.067,0.052,0.1,0.053,0.068,0.07]
fig,axs = plt.subplots(1,1)
axs.plot(mx_iter_time,emd_flexim_predict_single,marker = ',',linestyle="--",label = 'optimal emd flexim single')
axs.plot(mx_iter_time,emd_final_model_single,marker = '8',linestyle="--",label = 'optimal emd final single')
axs.set_xticks([2,3,4,5,6,7,8,9,10,20,30])
axs.set_xlabel('mx_iter')
axs.set_title('emualte dtw with single model')
axs.legend()

# %%
#emd flexim predict compare between single and complex
import matplotlib.pyplot as plt
mx_iter_time = [2,3,4,5,6,7,8,9,10,20,30]
emd_flexim_predict = [0.088,0.085,0.084,0.092,0.1,0.0914,0.103,0.1,0.106,0.121,0.131]
emd_flexim_predict_single = [0.13,0.143,0.141,0.144,0.134,0.133,0.129,0.121,0.11,0.11,0.107]
fig,axs = plt.subplots(1,1)
axs.plot(mx_iter_time,emd_flexim_predict,marker = ',',linestyle="--",label = 'emd flexim predict stack')
axs.plot(mx_iter_time,emd_flexim_predict_single,marker = '8',linestyle="--",label = 'emd flexim predict single')
axs.set_xticks([2,3,4,5,6,7,8,9,10,20,30])
axs.set_xlabel('mx_iter')
axs.set_title('compare emd value of stack and single flexim predict')
axs.legend()

# %%
#emd flexim predict compare between single and complex
import matplotlib.pyplot as plt
mx_iter_time = [2,3,4,5,6,7,8,9,10,20,30]
emd_flexim_final_predict = [0.05,0.051,0.063,0.048,0.055,0.061,0.062,0.061,0.057,0.069,0.063]
emd_flexim_final_predict_single = [0.054,0.049,0.033,0.026,0.034,0.067,0.052,0.1,0.053,0.068,0.07]
fig,axs = plt.subplots(1,1)
axs.plot(mx_iter_time,emd_flexim_final_predict,marker = ',',linestyle="--",label = 'emd flexim final predict')
axs.plot(mx_iter_time,emd_flexim_final_predict_single,marker = '8',linestyle="--",label = 'emd flexim final predict single')
axs.set_xticks([2,3,4,5,6,7,8,9,10,20,30])
axs.set_xlabel('mx_iter')
axs.set_title('compare final emd value of stack and single')
axs.legend()

# %%
#emd flexim predict with flexim predict, final predict without nd, final predict(single)
#wnd means without naive data
import matplotlib.pyplot as plt
mx_iter_time = [2,3,4,5,6,7,8,9,10,20,30]
emd_flexim_predict = [0.126,0.135,0.144,0.132,0.137,0.126,0.124,0.118,0.112,0.094,0.089]
emd_flexim_final_predict_wnd = [0.063,0.062,0.085,0.044,0.086,0.026,0.056,0.045,0.074,0.065,0.041]
emd_flexim_final_predict = [0.039,0.06,0.046,0.046,0.057,0.052,0.03,0.055,0.086,0.068,0.037]
fig,axs = plt.subplots(1,1)
axs.plot(mx_iter_time,emd_flexim_predict,marker = ',',linestyle="--",label = 'emd flexim final predict')
axs.plot(mx_iter_time,emd_flexim_final_predict_wnd,marker = '8',linestyle="--",label = 'emd flexim final predict wnd')
axs.plot(mx_iter_time,emd_flexim_final_predict,marker = '.',linestyle="--",label = 'emd flexim final predict single')
axs.set_xticks([2,3,4,5,6,7,8,9,10,20,30])
axs.set_xlabel('mx_iter')
axs.set_title('single model emd')
axs.legend()

# %%
#emd flexim predict with flexim predict, final predict without nd, final predict(stack)
#wnd means without naive data
import matplotlib.pyplot as plt
mx_iter_time = [2,3,4,5,6,7,8,9,10,20,30]
emd_flexim_predict = [0.087,0.087,0.088,0.092,0.092,0.098,0.103,0.108,0.103,0.118,0.121]
emd_flexim_final_predict_wnd = [0.053,0.047,0.067,0.053,0.06,0.067,0.058,0.078,0.055,0.07,0.065]
emd_flexim_final_predict = [0.056,0.055,0.062,0.054,0.058,0.065,0.058,0.061,0.051,0.06,0.054]
fig,axs = plt.subplots(1,1)
axs.plot(mx_iter_time,emd_flexim_predict,marker = ',',linestyle="--",label = 'emd flexim final predict')
axs.plot(mx_iter_time,emd_flexim_final_predict_wnd,marker = '8',linestyle="--",label = 'emd flexim final predict wnd')
axs.plot(mx_iter_time,emd_flexim_final_predict,marker = '.',linestyle="--",label = 'emd flexim final predict stack')
axs.set_xticks([2,3,4,5,6,7,8,9,10,20,30])
axs.set_xlabel('mx_iter')
axs.set_title('stack model emd')
axs.legend()

# %%
#emd compare different structure
import matplotlib.pyplot as plt
mx_iter_time = [2,3,4,5,6,7,8,9,10,20,30]
emd_flexim_final_predict = [0.056,0.055,0.062,0.054,0.058,0.065,0.058,0.061,0.051,0.06,0.054]
emd_flexim_final_predict_single = [0.039,0.06,0.046,0.046,0.057,0.052,0.03,0.055,0.086,0.068,0.037]
emd_flexim_l2_only = [0.044,0.068,0.061,0.054,0.044,0.061,0.052,0.052,0.057,0.074,0.065]
emd_flexim_l2_cosine_only = [0.04,0.04,0.049,0.05,0.067,0.053,0.061,0.057,0.054,0.063,0.063]
#emd_flexim_blank_stack = [0.48,0.236,0.085,0.067,0.149,0.07,0.049,0.095,0.07,0.048,0.069]
fig,axs = plt.subplots(1,1)
axs.plot(mx_iter_time,emd_flexim_final_predict,marker = ',',linestyle="--",label = 'emd flexim predict stack')
axs.plot(mx_iter_time,emd_flexim_final_predict_single,marker = '8',linestyle="--",label = 'emd flexim single')
axs.plot(mx_iter_time,emd_flexim_l2_only,marker = '.',linestyle="--",label = 'emd flexim l2 only')
axs.plot(mx_iter_time,emd_flexim_l2_cosine_only,marker = '*',linestyle="--",label = 'emd flexim l2 cosine only')
#axs.plot(mx_iter_time,emd_flexim_blank_stack,marker = 'v',linestyle="--",label = 'emd flexim stack blank')
axs.set_xticks([2,3,4,5,6,7,8,9,10,20,30])
axs.set_xlabel('mx_iter')
axs.set_title('different model emd')
axs.legend()

# %%
#emd compare different structure
import matplotlib.pyplot as plt
mx_iter_time = [8,12,16,20,24,28,32,36,40,80,120]
accuracy_flexim_final_predict_blank = [0.54,0.57,0.65,0.67,0.72,0.74,0.75,0.76,0.8,0.83,0.85]
accuracy_flexim_final_predict_l2_only_stack = [0.86,0.87,0.846,0.888,0.868,0.896,0.882,0.882,0.902,0.908,0.91]
accuracy_flexim_final_predict_stack = [0.83,0.84,0.85,0.86,0.87,0.87,0.89,0.9,0.88,0.89,0.9]
accuracy_flexim_final_predict_committee_pretrain = [0.81,0.82,0.81,0.81,0.81,0.83,0.83,0.83,0.84,0.89,0.92]
accuracy_flexim_final_predict_committee_blank = [0.69,0.72,0.76,0.78,0.8,0.82,0.83,0.84,0.85,0.9,0.91]
accuracy_committee_dtw = [0.64,0.65,0.68,0.7,0.74,0.76,0.79,0.8,0.82,0.85,0.9]
accuracy_stack_dtw = [0.7,0.75,0.76,0.78,0.79,0.82,0.83,0.84,0.86,0.88,0.89]
accuracy_dtw_l2_cosine = [0.8,0.81,0.84,0.85,0.87,0.87,0.89,0.89,0.88,0.89,0.91]
#accuracy_flexim_final_predict_blank_stack = [0.324,0.5,0.68,0.68,0.6,0.68,0.68,0.68,0.68,0.68,0.68]
fig,axs = plt.subplots(1,1)
plt.tick_params(axis='x', labelsize=8.5)
axs.plot(mx_iter_time,accuracy_flexim_final_predict_blank,marker = ',',linestyle="--",label = 'blank model')
axs.plot(mx_iter_time,accuracy_committee_dtw,marker = '*',linestyle = "--",label = 'committee model')
axs.plot(mx_iter_time,accuracy_stack_dtw,marker = 'v',linestyle = "--",label = 'stack model')
#axs.plot(mx_iter_time,accuracy_flexim_final_predict_l2_only_stack,marker = '8',linestyle="--",label = 'pre-trained model(l2 -> dtw)')
#axs.plot(mx_iter_time,accuracy_flexim_final_predict_stack,marker = '.',linestyle="--",label = 'L2 + cosine + blank -> dtw')
#axs.plot(mx_iter_time,accuracy_dtw_l2_cosine,marker = '*',linestyle="--",label = 'L2 + cosine  -> dtw')
#axs.plot(mx_iter_time,accuracy_flexim_final_predict_committee_pretrain, marker = '*',linestyle="--",label = 'accuracy flexim committee pretrain')
#axs.plot(mx_iter_time,accuracy_flexim_final_predict_committee_blank,marker = 'v',linestyle="--",label = 'accuracy flexim committee blank')
#axs.plot(mx_iter_time,accuracy_flexim_final_predict_blank_stack,marker = '^',linestyle="--",label = 'emd flexim stack blank')
axs.set_xticks([8,12,16,20,24,28,32,36,40,80,120])
axs.set_xlabel('user label sample number')
axs.set_ylabel('emulate dtw accuracy')
axs.set_title('emulate dtw')
axs.legend()
image_format = 'png'
image_name = "different model emulate dtw accuracy.png"
fig.savefig(image_name, format = image_format,dpi=400)

# %%
#import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
threshold = [8,12,16,20,24,28,32,36,40,80,120]
wass_l2 = [0.035,0.033,0.035,0.04,0.05,0.05,0.059,0.04,0.038,0.05,0.035]
wass_stack_model = [0.034,0.036,0.033,0.037,0.04,0.041,0.037,0.028,0.025,0.028,0.035]
wass_single = [0.129,0.108,0.127,0.074,0.058,0.076,0.07,0.1,0.07,0.087,0.068]
wass_l2_cosine_stack = [0.048,0.043,0.032,0.032,0.031,0.042,0.029,0.025,0.025,0.045,0.025]
#wass_single = [0.041,0.04,0.04,0.047,0.05,0.046,0.06,0.057,0.065,0.05,0.042]
fig,axs = plt.subplots(1,1)
plt.tick_params(axis='x', labelsize=8.5)
axs.plot(threshold,wass_single,marker = ',',linestyle="--",label = 'blank model')
axs.plot(threshold,wass_l2,marker = '8',linestyle="--",label = 'Pre-trained (L2 -> DTW)')
#axs.plot(threshold,wass_optimal_l2_cosine,marker = 'v',linestyle="--",label = 'optimal wass flexim l2 cosine')
axs.plot(threshold,wass_l2_cosine_stack,marker = '.',linestyle="--",label = 'l2,cosine -> stack')
axs.plot(threshold,wass_stack_model,marker = '*',linestyle = '--',label = 'stacked model(l2,cosine,blank > DTW)')
axs.set_xticks([8,12,16,20,24,28,32,36,40,80,120])
axs.set_xlabel('user label sample number')
axs.set_ylabel('earth mover distance')
axs.set_title('emualte dtw(three cluster)')
axs.legend()
image_format = 'png'
image_name = "emd_dtw_different_model.png"
fig.savefig(image_name, format = image_format,dpi=400)
#compare emd result between flexim predict and real score without data generation

# %%
#import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
threshold = [8,12,16,20,24,28,32,36,40,80,120]
#wass_l2 = [0.035,0.033,0.035,0.04,0.05,0.05,0.059,0.04,0.038,0.05,0.035]
wass_model_without_focal = [0.283,0.294,0.305,0.334,0.356,0.345,0.323,0.290,0.367,0.415,0.435]
wass_stack_model = [0.034,0.036,0.033,0.037,0.04,0.041,0.037,0.028,0.025,0.028,0.035]
#wass_single = [0.129,0.108,0.127,0.074,0.058,0.076,0.07,0.1,0.07,0.087,0.068]
#wass_l2_cosine_stack = [0.048,0.043,0.032,0.032,0.031,0.042,0.029,0.025,0.025,0.045,0.025]
#wass_single = [0.041,0.04,0.04,0.047,0.05,0.046,0.06,0.057,0.065,0.05,0.042]
fig,axs = plt.subplots(1,1)
plt.tick_params(axis='x', labelsize=8.5)
axs.plot(threshold,wass_model_without_focal,marker = ',',linestyle = "--",label = 'use BinaryCrossentropy')
axs.plot(threshold,wass_stack_model,marker = 'v',linestyle = "--",label = 'use BinaryFocalCrossentropy')
# axs.plot(threshold,wass_single,marker = ',',linestyle="--",label = 'blank model')
# axs.plot(threshold,wass_l2,marker = '8',linestyle="--",label = 'Pre-trained (L2 -> DTW)')
# #axs.plot(threshold,wass_optimal_l2_cosine,marker = 'v',linestyle="--",label = 'optimal wass flexim l2 cosine')
# axs.plot(threshold,wass_l2_cosine_stack,marker = '.',linestyle="--",label = 'l2,cosine -> stack')
# axs.plot(threshold,wass_stack_model,marker = '*',linestyle = '--',label = 'stacked model(l2,cosine,blank > DTW)')
axs.set_xticks([8,12,16,20,24,28,32,36,40,80,120])
axs.set_xlabel('query time per cluster')
axs.set_ylabel('earth mover distance')
# axs.set_title('emualte dtw(three cluster)')
axs.legend()
image_format = 'png'
image_name = "earth mover's distance_1.png"
fig.savefig(image_name, format = image_format,dpi=500)
# #compare emd result between flexim predict and real score without data generation

# %%
import matplotlib.pyplot as plt
threshold = [8,12,16,20,24,28,32,36,40,80,120]
wass_stack_model = [0.034,0.036,0.033,0.037,0.04,0.041,0.037,0.028,0.025,0.028,0.035]
emd_flexim_predict_without_naive_and_cnn = [0.126,0.135,0.144,0.132,0.137,0.126,0.124,0.118,0.112,0.094,0.089]
fig,axs = plt.subplots(1,1)
plt.tick_params(axis='x', labelsize=8.5)
axs.plot(threshold,emd_flexim_predict_without_naive_and_cnn,marker = ',',linestyle = "--",label = 'flexim active leaarning model')
axs.plot(threshold,wass_stack_model,marker = 'v',linestyle = "--",label = 'flexim final classification model')
# axs.plot(threshold,wass_single,marker = ',',linestyle="--",label = 'blank model')
# axs.plot(threshold,wass_l2,marker = '8',linestyle="--",label = 'Pre-trained (L2 -> DTW)')
# #axs.plot(threshold,wass_optimal_l2_cosine,marker = 'v',linestyle="--",label = 'optimal wass flexim l2 cosine')
# axs.plot(threshold,wass_l2_cosine_stack,marker = '.',linestyle="--",label = 'l2,cosine -> stack')
# axs.plot(threshold,wass_stack_model,marker = '*',linestyle = '--',label = 'stacked model(l2,cosine,blank > DTW)')
axs.set_xticks([8,12,16,20,24,28,32,36,40,80,120])
axs.set_xlabel('query time per cluster')
axs.set_ylabel('earth mover distance')
# axs.set_title('emualte dtw(three cluster)')
axs.legend()
image_format = 'png'
image_name = "earth mover's distance_2.png"
fig.savefig(image_name, format = image_format,dpi=500)

# %%
#import matplotlib.pyplot as plt
threshold = [2,3,4,5,6,7,8,9,10,20,30]
wass_l2 = [0.035,0.033,0.035,0.04,0.05,0.05,0.059,0.04,0.038,0.05,0.035]
#wass_stack_model = [0.034,0.036,0.033,0.037,0.05,0.05,0.037,0.028,0.05,0.05,0.035]
wass_single = [0.129,0.108,0.127,0.074,0.058,0.076,0.07,0.1,0.07,0.087,0.068]
#wass_single = [0.041,0.04,0.04,0.047,0.05,0.046,0.06,0.057,0.065,0.05,0.042]
fig,axs = plt.subplots(1,1)
axs.plot(threshold,wass_single,marker = ',',linestyle="--",label = 'emd flexim blank')
axs.plot(threshold,wass_l2,marker = '8',linestyle="--",label = 'emd flexim pretrain l2')
#axs.plot(threshold,wass_optimal_l2_cosine,marker = 'v',linestyle="--",label = 'optimal wass flexim l2 cosine')
#axs.plot(threshold,wass_stack_model,marker = '.',linestyle="--",label = 'emd flexim stack')
axs.set_xticks([2,3,4,5,6,7,8,9,10,20,30])
axs.set_xlabel('user label sample number')
axs.set_ylabel('emd')
axs.set_title('emualte l2(three cluster)')
axs.legend()
image_format = 'png'
image_name = "emd_l2->DTW.png"
fig.savefig(image_name, format = image_format,dpi=400)

# %%
#import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
threshold = [8,12,16,20,24,28,32,36,40,80,120]
wass_l2 = [0.035,0.033,0.035,0.04,0.05,0.05,0.059,0.04,0.038,0.05,0.035]
#wass_stack_model = [0.034,0.036,0.033,0.037,0.05,0.05,0.037,0.028,0.05,0.05,0.035]
wass_single = [0.129,0.108,0.127,0.074,0.058,0.076,0.07,0.1,0.07,0.087,0.068]
#wass_single = [0.041,0.04,0.04,0.047,0.05,0.046,0.06,0.057,0.065,0.05,0.042]
wass_l2_cosine_stack = [0.048,0.033,0.032,0.032,0.031,0.042,0.029,0.025,0.025,0.045,0.025]
fig,axs = plt.subplots(1,1)
plt.tick_params(axis='x', labelsize=8.5)
#axs.plot(threshold,wass_single,marker = ',',linestyle="--",label = 'emd flexim blank')
axs.plot(threshold,wass_l2,marker = '8',linestyle="--",label = 'emd flexim pretrain l2')
axs.plot(threshold,wass_l2_cosine_stack,marker = 'v',linestyle="--",label = 'emd flexim l2 cosine')
#axs.plot(threshold,wass_stack_model,marker = '.',linestyle="--",label = 'emd flexim stack')
axs.set_xticks([8,12,16,20,24,28,32,36,40,80,120])
axs.set_xlabel('user label sample number')
axs.set_ylabel('earth mover distance')
axs.set_title('emualte l2')
axs.legend()
image_format = 'png'
image_name = "emd_l2_cosine->DTW.png"
fig.savefig(image_name, format = image_format,dpi=400)

# %%
#import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
threshold = [8,12,16,20,24,28,32,36,40,80,120]
#wass_l2 = [0.035,0.033,0.035,0.04,0.05,0.05,0.059,0.04,0.038,0.05,0.035]
wass_stack_model = [0.034,0.036,0.033,0.037,0.04,0.041,0.037,0.028,0.025,0.028,0.035]
#wass_single = [0.129,0.108,0.127,0.074,0.058,0.076,0.07,0.1,0.07,0.087,0.068]
#wass_single = [0.041,0.04,0.04,0.047,0.05,0.046,0.06,0.057,0.065,0.05,0.042]
wass_l2_cosine_stack = [0.048,0.043,0.032,0.032,0.031,0.042,0.029,0.025,0.025,0.045,0.025]
fig,axs = plt.subplots(1,1)
plt.tick_params(axis='x', labelsize=8.5)
#axs.plot(threshold,wass_single,marker = ',',linestyle="--",label = 'emd flexim blank')
#axs.plot(threshold,wass_l2,marker = '8',linestyle="--",label = 'emd flexim pretrain l2')
axs.plot(threshold,wass_l2_cosine_stack,marker = 'v',linestyle="--",label = 'emd flexim l2 cosine')
axs.plot(threshold,wass_stack_model,marker = '.',linestyle="--",label = 'emd flexim l2 cosine blank')
axs.set_xticks([8,12,16,20,24,28,32,36,40,80,120])
axs.set_xlabel('user label sample number')
axs.set_ylabel('earth mover distance')
axs.set_title('emualte l2')
axs.legend()
image_format = 'png'
image_name = "emd_l2_cosine_stack->DTW.png"
fig.savefig(image_name, format = image_format,dpi=400)

# %%
#emd experiment emulate dtw accuracy
threshold = [2,3,4,5,6,7,8,9,10,20,30]
accuracy_single = [0.129,0.108,0.127,0.074,0.058,0.076,0.07,0.1,0.07,0.087,0.068]
#wass_stack_model = [0.034,0.036,0.033,0.037,0.05,0.05,0.037,0.028,0.05,0.05,0.035]
accuracy_pretrain_dtw = [0.073,0.046,0.076,0.059,0.042,0.061,0.058,0.074,0.06,0.053,0.043]
#wass_single = [0.041,0.04,0.04,0.047,0.05,0.046,0.06,0.057,0.065,0.05,0.042]
fig,axs = plt.subplots(1,1)
axs.plot(threshold,accuracy_single,marker = ',',linestyle="--",label = 'blank')
#axs.plot(threshold,wass_l2,marker = '8',linestyle="--",label = 'emd flexim pretrain l2')
#axs.plot(threshold,wass_optimal_l2_cosine,marker = 'v',linestyle="--",label = 'optimal wass flexim l2 cosine')
axs.plot(threshold,accuracy_pretrain_dtw,marker = '.',linestyle="--",label = 'pretrain DTW->L2')
axs.set_xticks([2,3,4,5,6,7,8,9,10,20,30])
axs.set_xlabel('query time per cluster')
axs.set_ylabel('emd')
axs.set_title('emualte l2(three cluster)')
axs.legend()
image_format = 'png'
image_name = "emd_DTW->l2.png"
fig.savefig(image_name, format = image_format,dpi=400)

# %%
#emd experiment emulate l2
threshold = [2,3,4,5,6,7,8,9,10,20,30]
accuracy_single = [0.129,0.108,0.127,0.074,0.058,0.076,0.07,0.1,0.07,0.087,0.068]
#wass_stack_model = [0.034,0.036,0.033,0.037,0.05,0.05,0.037,0.028,0.05,0.05,0.035]
accuracy_pretrain_dtw_cosine = [0.08,0.07,0.06,0.058,0.043,0.049,0.05,0.054,0.045,0.052,0.043]
#wass_single = [0.041,0.04,0.04,0.047,0.05,0.046,0.06,0.057,0.065,0.05,0.042]
fig,axs = plt.subplots(1,1)
axs.plot(threshold,accuracy_single,marker = ',',linestyle="--",label = 'blank')
#axs.plot(threshold,wass_l2,marker = '8',linestyle="--",label = 'emd flexim pretrain l2')
#axs.plot(threshold,wass_optimal_l2_cosine,marker = 'v',linestyle="--",label = 'optimal wass flexim l2 cosine')
axs.plot(threshold,accuracy_pretrain_dtw_cosine,marker = '.',linestyle="--",label = 'stack model(DTW,Cosine)')
axs.set_xticks([2,3,4,5,6,7,8,9,10,20,30])
axs.set_xlabel('query time per cluster')
axs.set_ylabel('emd')
axs.set_title('emualte l2(three cluster)')
axs.legend()

# %%
#accuracy experiment emulate l2
threshold = [2,3,4,5,6,7,8,9,10,20,30]
accuracy_single = [0.64,0.64,0.71,0.75,0.81,0.81,0.82,0.83,0.84,0.88,0.89]
#wass_stack_model = [0.034,0.036,0.033,0.037,0.05,0.05,0.037,0.028,0.05,0.05,0.035]
accuracy_pretrain_dtw_cosine = [0.7,0.72,0.78,0.83,0.83,0.84,0.86,0.865,0.87,0.87,0.88]
#wass_single = [0.041,0.04,0.04,0.047,0.05,0.046,0.06,0.057,0.065,0.05,0.042]
fig,axs = plt.subplots(1,1)
axs.plot(threshold,accuracy_single,marker = ',',linestyle="--",label = 'blank')
#axs.plot(threshold,wass_l2,marker = '8',linestyle="--",label = 'emd flexim pretrain l2')
#axs.plot(threshold,wass_optimal_l2_cosine,marker = 'v',linestyle="--",label = 'optimal wass flexim l2 cosine')
axs.plot(threshold,accuracy_pretrain_dtw_cosine,marker = '.',linestyle="--",label = 'stack model(DTW,Cosine -> L2)')
axs.set_xticks([2,3,4,5,6,7,8,9,10,20,30])
axs.set_xlabel('query time per cluster')
axs.set_ylabel('accuracy')
axs.set_title('emualte l2(three cluster)')
axs.legend()

# %%
# fig,ax = plt.subplots()
# x = np.arange(len(labels))
# width = 0.2
# rects1 = ax.bar(x - width/2,query_time_l2_train, width/4, label='l2 pretrain model')
# rects2 = ax.bar(x - width/4,query_time_dtw_train,width/4, label = 'dtw pretrain model')
# rects3 = ax.bar(x + width/4,query_time_cosine_train,width/4, label = 'cosine pretrain model')
# rects4 = ax.bar(x + width/2,query_time_random_initialised_mx_iter_5,width/4, label = 'mx_iter 5')
# rects4 = ax.bar(x + width,query_time_random_initialised_mx_iter_10,width/4, label = 'mx_iter 10')
# ax.set_ylabel('query time')
# ax.set_title('query time of different pretrained model to emulate different measures')
# ax.set_xticks(x, labels)
# ax.legend()
# fig.tight_layout()
# plt.show()

# %%
# accuracy_l2_train = [0.81,0.83,0.92]
# accuracy_dtw_train = [0.78,0.8,0.92]
# accuracy_cosine_train = [0.79,0.81,0.92]
# accuracy_random_initialised_mx_iter_5 = [0.76,0.77,0.95]
# accuracy_random_initialised_mx_iter_10 = [0.84,0.83,0.86]
# fig,ax = plt.subplots()
# x = np.arange(len(labels))
# width = 0.2
# rects1 = ax.bar(x - width/2,accuracy_l2_train, width/4, label='l2 pretrain model')
# rects2 = ax.bar(x - width/4,accuracy_dtw_train,width/4, label = 'dtw pretrain model')
# rects3 = ax.bar(x + width/4,accuracy_cosine_train,width/4, label = 'cosine pretrain model')
# rects4 = ax.bar(x + width/2,accuracy_random_initialised_mx_iter_5,width/4, label = 'mx_iter 5')
# rects4 = ax.bar(x + width,accuracy_random_initialised_mx_iter_10,width/4, label = 'mx_iter 10')
# ax.set_ylabel('final accuracy')
# ax.set_title('accuracy of different pretrained model and random initialised model to emulate different measures')
# ax.set_xticks(x, labels)
# ax.legend()
# fig.tight_layout()
# plt.show()

# %%
# emd_l2_train = [0.03,0.06,0.31]
# emd_dtw_train = [0.08,0.07,0.27]
# emd_cosine_train = [0.07,0.05,0.29]
# emd_random_initialised_mx_iter_5 = [0.10,0.11,0.25]
# emd_random_initialised_mx_iter_10 = [0.04,0.05,0.20]
# fig,ax = plt.subplots()
# x = np.arange(len(labels))
# width = 0.2
# rects1 = ax.bar(x - width/2,emd_l2_train, width/4, label='l2 pretrain model')
# rects2 = ax.bar(x - width/4,emd_dtw_train,width/4, label = 'dtw pretrain model')
# rects3 = ax.bar(x + width/4,emd_cosine_train,width/4, label = 'cosine pretrain model')
# rects4 = ax.bar(x + width/2,emd_random_initialised_mx_iter_5,width/4, label = 'mx_iter 5')
# rects4 = ax.bar(x + width,emd_random_initialised_mx_iter_10,width/4, label = 'mx_iter 10')
# ax.set_ylabel('emd')
# ax.set_title('emd of different pretrained model and random initialised model to emulate different measures')
# ax.set_xticks(x, labels)
# ax.legend()
# fig.tight_layout()
# plt.show()

# %%
#run five times -- latest version
import matplotlib.pyplot as plt
import numpy as np
fig,ax = plt.subplots()
labels = ['l2','dtw','cosine']
x = np.arange(len(labels))
width = 0.2
query_time_l2_train = [1.2,2,4.2]
query_time_dtw_train = [8,7,5.4]
query_time_cosine_train = [19.4,20,0]
query_time_single_mx_5 = [20,20,3.4]
query_time_single_mx_10 = [35,30,5]
rects1 = ax.bar(x - width/2,query_time_l2_train, width/4, label='l2 pretrain model')
rects2 = ax.bar(x - width/4,query_time_dtw_train,width/4, label = 'dtw pretrain model')
rects3 = ax.bar(x + width/4,query_time_cosine_train,width/4, label = 'cosine pretrain model')
rects4 = ax.bar(x + width/2,query_time_single_mx_5,width/4, label = 'mx_iter 5')
rects4 = ax.bar(x + width,query_time_single_mx_10,width/4, label = 'mx_iter 10')
ax.set_ylabel('query time')
ax.set_title('query time of different model to emulate different measures')
ax.set_xticks(x, labels)
ax.legend()
fig.tight_layout()
plt.show()

# %%
#run five times
import matplotlib.pyplot as plt
import numpy as np
fig,ax = plt.subplots()
labels = ['l2','dtw','cosine']
x = np.arange(len(labels))
width = 0.2
accuracy_l2_train = [0.834,0.846,0.852]
accuracy_dtw_train = [0.826,0.794,0.87]
accuracy_cosine_train = [0.79,0.79,0.948]
accuracy_single_mx_5 = [0.748,0.746,0.888]
accuracy_single_mx_10 = [0.8,0.81,0.86]
rects1 = ax.bar(x - width/2,accuracy_l2_train, width/4, label='l2 pretrain model')
rects2 = ax.bar(x - width/4,accuracy_dtw_train,width/4, label = 'dtw pretrain model')
rects3 = ax.bar(x + width/4,accuracy_cosine_train,width/4, label = 'cosine pretrain model')
rects4 = ax.bar(x + width/2,accuracy_single_mx_5,width/4, label = 'mx_iter 5')
rects4 = ax.bar(x + width,accuracy_single_mx_10,width/4, label = 'mx_iter 10')
ax.set_ylabel('accuracy')
ax.set_title('accuracy of different model to emulate different measures')
ax.set_xticks(x, labels)
ax.legend()
fig.tight_layout()
plt.show()

# %%
#run five times
import matplotlib.pyplot as plt
import numpy as np
fig,ax = plt.subplots()
labels = ['l2','dtw','cosine']
x = np.arange(len(labels))
width = 0.2
emd_l2_train = [0.085,0.095,0.17]
emd_dtw_train = [0.103,0.0876,0.191]
emd_cosine_train = [0.096,0.0695,0.102]
emd_single_mx_5 = [0.108,0.07,0.322]
emd_single_mx_10 = [0.04,0.05,0.29]
rects1 = ax.bar(x - width/2,emd_l2_train, width/4, label='l2 pretrain model')
rects2 = ax.bar(x - width/4,emd_dtw_train,width/4, label = 'dtw pretrain model')
rects3 = ax.bar(x + width/4,emd_cosine_train,width/4, label = 'cosine pretrain model')
rects4 = ax.bar(x + width/2,emd_single_mx_5,width/4, label = 'mx_iter 5')
rects4 = ax.bar(x + width,emd_single_mx_10,width/4, label = 'mx_iter 10')
ax.set_ylabel('emd')
ax.set_title('emd of different model to emulate different measures')
ax.set_xticks(x, labels)
ax.legend()
fig.tight_layout()
plt.show()

# %%
#plot sin function
import matplotlib.pyplot as plt
import numpy as np
fig,axs = plt.subplots(1,1)
x = np.arange(0,2*np.pi,0.1)   # start,stop,step
y = np.sin(x)
axs.plot(x,y)
axs.axis('off')
axs.legend()
image_format = 'png'
image_name = "sin-func.png"
fig.savefig(image_name, format = image_format,dpi=2400)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
#plot sin function
import matplotlib.pyplot as plt
import numpy as np
fig,axs = plt.subplots(1,1)
x = np.arange(0,2*np.pi,0.1)   # start,stop,step
y = np.cos(x)
axs.plot(x,y,color = "orange")
axs.axis('off')
axs.legend()
image_format = 'png'
image_name = "cos-func.png"
fig.savefig(image_name, format = image_format,dpi=2400)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
import matplotlib.pyplot as plt
import numpy as np
fig,axs = plt.subplots(1,1)
pattern_1 = np.array([1,2,0,1,1,2,0,1,1,2,0,1,1,2,0,1])
timestamp = np.arange(len(pattern_1))
axs.plot(timestamp,pattern_1,linewidth=2.5,label = 'pattern 1')
plt.xticks(fontsize = 15)
plt.yticks(fontsize = 15)
axs.legend()
image_format = 'png'
image_name = "pattern_1.png"
fig.savefig(image_name, format = image_format,dpi=400)

# %%
import matplotlib.pyplot as plt
import numpy as np
fig,axs = plt.subplots(1,1)
pattern_1 = np.array([0,1,1,2,0,1,1,2,0,1,1,2,0,1,1,2])
timestamp = np.arange(len(pattern_1))
axs.plot(timestamp,pattern_1,label = 'pattern 2')
axs.legend()
image_format = 'png'
image_name = "pattern_2.png"
fig.savefig(image_name, format = image_format,dpi=400)

# %%
import matplotlib.pyplot as plt
import numpy as np
fig,axs = plt.subplots(1,1)
pattern_1 = np.array([0.8,1.5,0,1.2,0,0,0.6,1,1.2,0,0,1,0.2,2.4,0.5,0.4])
timestamp = np.arange(len(pattern_1))
axs.plot(timestamp,pattern_1,label = 'pattern 3')
axs.legend()
image_format = 'png'
image_name = "pattern_3.png"
fig.savefig(image_name, format = image_format,dpi=400)
