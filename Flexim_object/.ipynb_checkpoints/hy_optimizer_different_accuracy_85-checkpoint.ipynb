# %%
import pandas as pd
import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"
data = pd.read_csv("./"+"all_stocks_5yr.csv",index_col = None)
data = data["close"].values

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
data = scaler.fit_transform(data.reshape(-1,1))

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import skopt
from scikeras.wrappers import KerasClassifier
import tensorflow as tf
from modAL.batch import uncertainty_batch_sampling
#from Active_Emulate_TestD_gp import Active_Emulate_Test as ace
#from NN import NN as nn
from keras.utils.np_utils import to_categorical
from sklearn.preprocessing import MinMaxScaler
from dtaidistance import dtw
from numpy import dot
from numpy.linalg import norm
import sys
from sklearn.utils import shuffle
import copy
import emulate_st500_em_new_write_exac as et
import importlib
import Active_Emulate_st500_em_new_exac as at

# %%
parameter_directory = "all_stocks_5yr"
file = open("./"+parameter_directory+".txt","r")
lines = file.readlines()
sample_size = int(lines[0].strip('\n'))
simi_kind = 3
cluster_number = int(lines[2].strip('\n'))
similarity_threshold = 0.85

# %%
#emulate single new
def obj(params,params_2,simi_kind):
    print("simi_kind is {}".format(simi_kind))
    emulate = et.Emulate_TestD(data,parameter_directory,simi_kind,cluster_number,sample_size,similarity_threshold)
    emulate.load_encoder_model(parameter_directory)
    emulate.load_kmeans_model(parameter_directory)
    emulate.__init_lin__()
    emulate.__init_both_cluster_directory__(cluster_number)
    emulate.__init_limit_dictionary__()
    emulate.add_cluster_dict()
    emulate.get_max_distance(instance_number = 30000)
    emulate.sample()
    emulate.load_parameter(params_2)
    emulate.__fetch__(simi_kind,params)
    print("final accuracy is {}".format(emulate.final_accuracy))
    print("accuracy threshold is {}".format(emulate.similarity_threshold))
    print("wass of flexim is {}".format(emulate.wasserstein_distance_flexim))
    print('#######################################################################################')
    return emulate.wasserstein_distance_flexim

# %%
params = [-2.16,6,9]

# %%
SPACE = [
   skopt.space.Integer(0,50,name = 'gamma 1'),
   skopt.space.Real(0,1,name = 'label_smoothing'),
   skopt.space.Integer(0,50,name = 'gamma 2'),
   skopt.space.Real(0,1,name = 'label_smoothing 2')
]

# %%
res = skopt.gp_minimize(lambda x: obj(params,x,simi_kind),SPACE,n_calls = 50,random_state = 44,n_jobs = -1)
# Out:
# simi_kind is 3
# Metal device set to: Apple M1 Max
# 2022-10-26 11:44:44.549044: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2022-10-26 11:44:44.549190: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# length of distance list is 30000
# self.max_distance is 13.016
# random value is 40
# start point is 395718
# has already got sample
# self.training_done is False
# simi kind is 3
# run first fetch
# new1
# 1 binary fetch
# self.training_done is False
# simi kind is 3
# run active learning fetch for current cluster
# generate naive complex alpha parameter
# finish generating naive parameters for current cluster
# finish generating naive parameters for current cluster
# initial active learner model
# active learning keras model run
# gamma is 22
# label smoothing is 0.031774802093509365
# batch size is 5
# active learning keras model run
# gamma is 0
# label smoothing is 0
# 2022-10-26 11:44:47.131486: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2022-10-26 11:44:47.352385: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 3/3 [==============================] - 3s 35ms/step - loss: 1.2242e-06 - accuracy: 0.5500
# 5/5 [==============================] - 0s 11ms/step - loss: 3.4986e-07 - accuracy: 0.3938
# accuracy threshold is 0.85
# run into active learning emulate process
# 1/1 [==============================] - 0s 75ms/step
# active learning initial score is 0.429
# emulate train unlabel shape is (192, 9)
# query instance shape is (48, 9)
# query instance shape is (44, 9)
# transform result shape is (44, 100)
# 6/6 [==============================] - 0s 2ms/step
# query instance shape is (5, 9)
# query instance shape is (3, 9)
# transform result shape is (3, 100)
# train
# 2022-10-26 11:44:50.150089: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 6/6 [==============================] - 1s 146ms/step - loss: 3.9296e-07 - accuracy: 0.5031
# 2/2 [==============================] - 0s 338ms/step
# 1 time active learning score is 0.455
# 6/6 [==============================] - 0s 5ms/step
# query instance shape is (5, 9)
# query instance shape is (4, 9)
# transform result shape is (4, 100)
# train
# 6/6 [==============================] - 1s 138ms/step - loss: 1.9394e-07 - accuracy: 0.5749
# 2/2 [==============================] - 0s 3ms/step
# 2 time active learning score is 0.477
# 6/6 [==============================] - 0s 3ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 6/6 [==============================] - 0s 54ms/step - loss: 1.9594e-07 - accuracy: 0.6279
# 2/2 [==============================] - 0s 12ms/step
# 3 time active learning score is 0.477
# 6/6 [==============================] - 0s 8ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 6/6 [==============================] - 0s 21ms/step - loss: 1.9326e-07 - accuracy: 0.5876
# 2/2 [==============================] - 0s 7ms/step
# 4 time active learning score is 0.432
# 6/6 [==============================] - 0s 3ms/step
# query instance shape is (5, 9)
# query instance shape is (4, 9)
# transform result shape is (4, 100)
# train
# 6/6 [==============================] - 0s 19ms/step - loss: 1.5720e-07 - accuracy: 0.6630
# 2/2 [==============================] - 0s 4ms/step
# 5 time active learning score is 0.455
# 6/6 [==============================] - 0s 5ms/step
# query instance shape is (5, 9)
# query instance shape is (4, 9)
# transform result shape is (4, 100)
# train
# 6/6 [==============================] - 0s 23ms/step - loss: 1.5681e-07 - accuracy: 0.7027
# 2/2 [==============================] - 0s 5ms/step
# 6 time active learning score is 0.409
# 6/6 [==============================] - 0s 30ms/step
# query instance shape is (5, 9)
# query instance shape is (4, 9)
# transform result shape is (4, 100)
# train
# 6/6 [==============================] - 0s 24ms/step - loss: 1.5662e-07 - accuracy: 0.7037
# 2/2 [==============================] - 0s 10ms/step
# 7 time active learning score is 0.5
# 5/5 [==============================] - 0s 5ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 7/7 [==============================] - 0s 47ms/step - loss: 1.4698e-07 - accuracy: 0.7216
# 2/2 [==============================] - 0s 4ms/step
# 8 time active learning score is 0.455
# 5/5 [==============================] - 0s 9ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 7/7 [==============================] - 0s 21ms/step - loss: 1.4853e-07 - accuracy: 0.7035
# 2/2 [==============================] - 0s 5ms/step
# 9 time active learning score is 0.386
# 5/5 [==============================] - 0s 5ms/step
# query instance shape is (5, 9)
# query instance shape is (4, 9)
# transform result shape is (4, 100)
# train
# 7/7 [==============================] - 1s 90ms/step - loss: 1.4909e-07 - accuracy: 0.7044
# 2/2 [==============================] - 0s 4ms/step
# 10 time active learning score is 0.477
# emulate process finishes
# query time is 10
# first stage total query time is 10
# self.training_done is True
# simi kind is 3
# run next cluster
# random value is 106
# start point is 36071
# has already resample
# self.training_done is False
# simi kind is 3
# run first fetch
# new1
# 2 binary fetch
# self.training_done is False
# simi kind is 3
# run active learning fetch for current cluster
# generate naive complex alpha parameter
# finish generating naive parameters for current cluster
# finish generating naive parameters for current cluster
# continue training active learner mdoel
# teach active learning model
# 9/9 [==============================] - 0s 27ms/step - loss: 1.6621e-07 - accuracy: 0.6431
# train unlabel shape is (192, 9)
# run into active learning emulate process
# 1/1 [==============================] - 0s 12ms/step
# active learning initial score is 0.476
# emulate train unlabel shape is (192, 9)
# query instance shape is (48, 9)
# query instance shape is (48, 9)
# transform result shape is (48, 100)
# 6/6 [==============================] - 0s 3ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 9/9 [==============================] - 0s 11ms/step - loss: 1.5968e-07 - accuracy: 0.6493
# 2/2 [==============================] - 0s 13ms/step
# 1 time active learning score is 0.5
# 6/6 [==============================] - 0s 4ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 10/10 [==============================] - 0s 47ms/step - loss: 1.5102e-07 - accuracy: 0.6962
# 2/2 [==============================] - 0s 4ms/step
# 2 time active learning score is 0.417
# 6/6 [==============================] - 0s 3ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 10/10 [==============================] - 0s 53ms/step - loss: 1.5069e-07 - accuracy: 0.6309
# 2/2 [==============================] - 0s 4ms/step
# 3 time active learning score is 0.417
# 6/6 [==============================] - 0s 3ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 10/10 [==============================] - 1s 67ms/step - loss: 1.4633e-07 - accuracy: 0.6964
# 2/2 [==============================] - 0s 4ms/step
# 4 time active learning score is 0.479
# 6/6 [==============================] - 0s 3ms/step
# query instance shape is (5, 9)
# query instance shape is (4, 9)
# transform result shape is (4, 100)
# train
# 10/10 [==============================] - 0s 15ms/step - loss: 1.4576e-07 - accuracy: 0.7231
# 2/2 [==============================] - 0s 4ms/step
# 5 time active learning score is 0.479
# 6/6 [==============================] - 0s 4ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 10/10 [==============================] - 0s 27ms/step - loss: 1.4370e-07 - accuracy: 0.7051
# 2/2 [==============================] - 0s 5ms/step
# 6 time active learning score is 0.521
# 6/6 [==============================] - 0s 4ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 10/10 [==============================] - 0s 24ms/step - loss: 1.4252e-07 - accuracy: 0.7129
# 2/2 [==============================] - 0s 6ms/step
# 7 time active learning score is 0.479
# 5/5 [==============================] - 0s 6ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 11/11 [==============================] - 0s 17ms/step - loss: 1.4090e-07 - accuracy: 0.7050
# 2/2 [==============================] - 0s 11ms/step
# 8 time active learning score is 0.479
# 5/5 [==============================] - 0s 8ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 11/11 [==============================] - 0s 23ms/step - loss: 1.4089e-07 - accuracy: 0.7125
# 2/2 [==============================] - 0s 13ms/step
# 9 time active learning score is 0.479
# 5/5 [==============================] - 0s 11ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 11/11 [==============================] - 0s 13ms/step - loss: 1.4127e-07 - accuracy: 0.7169
# 2/2 [==============================] - 0s 3ms/step
# 10 time active learning score is 0.458
# emulate process finishes
# query time is 10
# first stage total query time is 20
# self.training_done is True
# simi kind is 3
# run next cluster
# random value is 2
# start point is 70704
# has already resample
# self.training_done is False
# simi kind is 3
# run first fetch
# new1
# 3 binary fetch
# self.training_done is False
# simi kind is 3
# run active learning fetch for current cluster
# generate naive complex alpha parameter
# finish generating naive parameters for current cluster
# finish generating naive parameters for current cluster
# continue training active learner mdoel
# teach active learning model
# 13/13 [==============================] - 0s 27ms/step - loss: 1.4623e-07 - accuracy: 0.6748
# train unlabel shape is (192, 9)
# run into active learning emulate process
# 1/1 [==============================] - 0s 10ms/step
# active learning initial score is 0.714
# emulate train unlabel shape is (192, 9)
# query instance shape is (48, 9)
# query instance shape is (44, 9)
# transform result shape is (44, 100)
# 6/6 [==============================] - 0s 3ms/step
# query instance shape is (5, 9)
# query instance shape is (3, 9)
# transform result shape is (3, 100)
# train
# 13/13 [==============================] - 0s 20ms/step - loss: 1.4282e-07 - accuracy: 0.6964
# 2/2 [==============================] - 0s 4ms/step
# 1 time active learning score is 0.455
# 6/6 [==============================] - 0s 6ms/step
# query instance shape is (5, 9)
# query instance shape is (3, 9)
# transform result shape is (3, 100)
# train
# 14/14 [==============================] - 0s 13ms/step - loss: 1.3965e-07 - accuracy: 0.7249
# 2/2 [==============================] - 0s 5ms/step
# 2 time active learning score is 0.432
# 6/6 [==============================] - 0s 4ms/step
# query instance shape is (5, 9)
# query instance shape is (3, 9)
# transform result shape is (3, 100)
# train
# 14/14 [==============================] - 0s 17ms/step - loss: 1.3878e-07 - accuracy: 0.7316
# 2/2 [==============================] - 0s 8ms/step
# 3 time active learning score is 0.409
# 6/6 [==============================] - 0s 7ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 14/14 [==============================] - 0s 19ms/step - loss: 1.3609e-07 - accuracy: 0.7347
# 2/2 [==============================] - 0s 6ms/step
# 4 time active learning score is 0.432
# 6/6 [==============================] - 0s 3ms/step
# query instance shape is (5, 9)
# query instance shape is (4, 9)
# transform result shape is (4, 100)
# train
# 14/14 [==============================] - 1s 52ms/step - loss: 1.3355e-07 - accuracy: 0.7465
# 2/2 [==============================] - 0s 3ms/step
# 5 time active learning score is 0.455
# 6/6 [==============================] - 0s 2ms/step
# query instance shape is (5, 9)
# query instance shape is (4, 9)
# transform result shape is (4, 100)
# train
# 14/14 [==============================] - 0s 20ms/step - loss: 1.3240e-07 - accuracy: 0.7558
# 2/2 [==============================] - 0s 8ms/step
# 6 time active learning score is 0.477
# 6/6 [==============================] - 0s 5ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 14/14 [==============================] - 0s 21ms/step - loss: 1.3324e-07 - accuracy: 0.7654
# 2/2 [==============================] - 0s 9ms/step
# 7 time active learning score is 0.5
# 5/5 [==============================] - 0s 6ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 14/14 [==============================] - 0s 17ms/step - loss: 1.3528e-07 - accuracy: 0.7387
# 2/2 [==============================] - 0s 6ms/step
# 8 time active learning score is 0.455
# 5/5 [==============================] - 0s 4ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 15/15 [==============================] - 2s 110ms/step - loss: 1.3141e-07 - accuracy: 0.7862
# 2/2 [==============================] - 0s 3ms/step
# 9 time active learning score is 0.523
# 5/5 [==============================] - 0s 3ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 15/15 [==============================] - 1s 39ms/step - loss: 1.3124e-07 - accuracy: 0.7709
# 2/2 [==============================] - 0s 2ms/step
# 10 time active learning score is 0.5
# emulate process finishes
# query time is 10
# first stage total query time is 30
# self.training_done is True
# simi kind is 3
# finish all cluster binary and active search
# make modification new new
# generate DTW naive positive and negative data
# (generator pid=5511) has change code 3
# (generator pid=5514) has change code 3
# length of next_result_table is 2
# result table shape is (9000, 101)
# finish generating complex parameters for all clusters and predict label by using active learner
# shape of table is (150000, 9)
# finish split
# finish generate label
# train data shape is (92115, 10)
# validate data shape is (23027, 10)
# 938/938 [==============================] - 4s 4ms/step
# initial active learning accuracy is 0.53
# further learning teach, generate more data
# 2879/2879 [==============================] - 12s 4ms/step
# train complex shape is (92115, 10)
# query index shape is (5,)
# 15/15 [==============================] - 0s 12ms/step - loss: 1.2837e-07 - accuracy: 0.7386
# 720/720 [==============================] - 3s 4ms/step
# 1 time fur active learning score is 0.576
# further learning teach, generate more data
# 2879/2879 [==============================] - 13s 5ms/step
# train complex shape is (92110, 10)
# query index shape is (5,)
# 15/15 [==============================] - 0s 21ms/step - loss: 1.3516e-07 - accuracy: 0.7328
# 720/720 [==============================] - 3s 5ms/step
# 2 time fur active learning score is 0.558
# further learning teach, generate more data
# 2879/2879 [==============================] - 14s 5ms/step
# train complex shape is (92105, 10)
# query index shape is (5,)
# 15/15 [==============================] - 0s 23ms/step - loss: 1.2293e-07 - accuracy: 0.7612
# 720/720 [==============================] - 4s 5ms/step
# 3 time fur active learning score is 0.544
# further learning teach, generate more data
# 2879/2879 [==============================] - 14s 5ms/step
# train complex shape is (92100, 10)
# query index shape is (5,)
# 15/15 [==============================] - 0s 16ms/step - loss: 1.3140e-07 - accuracy: 0.7637
# 720/720 [==============================] - 4s 5ms/step
# 4 time fur active learning score is 0.542
# further learning teach, generate more data
# 2878/2878 [==============================] - 14s 5ms/step
# train complex shape is (92095, 10)
# query index shape is (5,)
# 15/15 [==============================] - 0s 15ms/step - loss: 1.2875e-07 - accuracy: 0.7557
# 720/720 [==============================] - 4s 6ms/step
# 5 time fur active learning score is 0.582
# further learning teach, generate more data
# 2878/2878 [==============================] - 14s 5ms/step
# train complex shape is (92090, 10)
# query index shape is (5,)
# 16/16 [==============================] - 1s 45ms/step - loss: 1.2489e-07 - accuracy: 0.7459
# 720/720 [==============================] - 3s 5ms/step
# 6 time fur active learning score is 0.559
# further learning teach, generate more data
# 2878/2878 [==============================] - 13s 5ms/step
# train complex shape is (92085, 10)
# query index shape is (5,)
# 16/16 [==============================] - 1s 35ms/step - loss: 1.2733e-07 - accuracy: 0.7546
# 720/720 [==============================] - 4s 5ms/step
# 7 time fur active learning score is 0.472
# further learning teach, generate more data
# 2878/2878 [==============================] - 15s 5ms/step
# train complex shape is (92080, 10)
# query index shape is (5,)
# 16/16 [==============================] - 0s 22ms/step - loss: 1.2929e-07 - accuracy: 0.7470
# 720/720 [==============================] - 4s 5ms/step
# 8 time fur active learning score is 0.508
# further learning teach, generate more data
# 2878/2878 [==============================] - 16s 6ms/step
# train complex shape is (92075, 10)
# query index shape is (5,)
# 16/16 [==============================] - 0s 27ms/step - loss: 1.1896e-07 - accuracy: 0.7876
# 720/720 [==============================] - 4s 6ms/step
# 9 time fur active learning score is 0.597
# further learning teach, generate more data
# 2878/2878 [==============================] - 17s 6ms/step
# train complex shape is (92070, 10)
# query index shape is (5,)
# 16/16 [==============================] - 0s 21ms/step - loss: 1.2871e-07 - accuracy: 0.7698
# 720/720 [==============================] - 4s 5ms/step
# 10 time fur active learning score is 0.57
# second stage total query time is 10
# total query time is 40
# 2879/2879 [==============================] - 16s 5ms/step
# 938/938 [==============================] - 5s 6ms/step
# final train AL accuracy is 0.57
# final test AL accuracy is 0.57
# accuracy threshold is 0.85
# 938/938 [==============================] - 5s 5ms/step
# finish generating naive data and complex data
# 2879/2879 [==============================] - 15s 5ms/step
# 2879/2879 [==============================] - 17s 6ms/step
# 720/720 [==============================] - 4s 6ms/step
# 720/720 [==============================] - 4s 6ms/step
# real prob shape is (115142, 1)
# score shape is (9000, 1)
# real train data shape is (101115, 101)
# flexim train data shape is (101115, 101)
# neg number flexim is 43675
# pos number flexim is 57440
# use bias is False
# gamma is 31
# label smoothing is 0.18441869586192697
# new version 1
# Epoch 1/10
# 2022-10-26 11:49:56.218383: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 3160/3160 [==============================] - ETA: 0s - loss: 3.4284e-10 - accuracy: 0.5103 - precision: 0.5459 - recall: 0.8197
# 2022-10-26 11:51:00.608437: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 3160/3160 [==============================] - 73s 22ms/step - loss: 3.4284e-10 - accuracy: 0.5103 - precision: 0.5459 - recall: 0.8197 - val_loss: 3.3430e-10 - val_accuracy: 0.4008 - val_precision: 0.4609 - val_recall: 0.4725
# Epoch 2/10
# 3160/3160 [==============================] - 72s 23ms/step - loss: 3.2818e-10 - accuracy: 0.3903 - precision: 0.4468 - recall: 0.3080 - val_loss: 3.3337e-10 - val_accuracy: 0.3766 - val_precision: 0.3059 - val_recall: 0.0976
# Epoch 3/10
# 3160/3160 [==============================] - 61s 19ms/step - loss: 3.2468e-10 - accuracy: 0.4026 - precision: 0.4168 - recall: 0.1291 - val_loss: 3.3215e-10 - val_accuracy: 0.4026 - val_precision: 0.2324 - val_recall: 0.0334
# Epoch 4/10
# 3160/3160 [==============================] - 59s 19ms/step - loss: 3.2273e-10 - accuracy: 0.4244 - precision: 0.4688 - recall: 0.0990 - val_loss: 3.3052e-10 - val_accuracy: 0.4169 - val_precision: 0.2161 - val_recall: 0.0195
# Epoch 5/10
# 3160/3160 [==============================] - 57s 18ms/step - loss: 3.2141e-10 - accuracy: 0.4331 - precision: 0.5057 - recall: 0.0931 - val_loss: 3.2896e-10 - val_accuracy: 0.4235 - val_precision: 0.2199 - val_recall: 0.0154
# Epoch 6/10
# 3160/3160 [==============================] - 57s 18ms/step - loss: 3.2033e-10 - accuracy: 0.4415 - precision: 0.5492 - recall: 0.0944 - val_loss: 3.2784e-10 - val_accuracy: 0.4290 - val_precision: 0.2325 - val_recall: 0.0128
# Epoch 7/10
# 3160/3160 [==============================] - 46s 15ms/step - loss: 3.1946e-10 - accuracy: 0.4612 - precision: 0.6389 - recall: 0.1186 - val_loss: 3.2694e-10 - val_accuracy: 0.4364 - val_precision: 0.3543 - val_recall: 0.0194
# Epoch 8/10
# 3160/3160 [==============================] - 52s 16ms/step - loss: 3.1869e-10 - accuracy: 0.4737 - precision: 0.6879 - recall: 0.1346 - val_loss: 3.2616e-10 - val_accuracy: 0.4442 - val_precision: 0.4850 - val_recall: 0.0305
# Epoch 9/10
# 3160/3160 [==============================] - 38s 12ms/step - loss: 3.1807e-10 - accuracy: 0.4795 - precision: 0.7065 - recall: 0.1433 - val_loss: 3.2565e-10 - val_accuracy: 0.4483 - val_precision: 0.5382 - val_recall: 0.0391
# Epoch 10/10
# 3160/3160 [==============================] - 45s 14ms/step - loss: 3.1755e-10 - accuracy: 0.4834 - precision: 0.7162 - recall: 0.1501 - val_loss: 3.2521e-10 - val_accuracy: 0.4528 - val_precision: 0.5825 - val_recall: 0.0481
# run validate result
#  37/720 [>.............................] - ETA: 1s
# 2022-10-26 11:59:17.021961: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 720/720 [==============================] - 2s 2ms/step
# score list flexim min and max is 0.0 1.0
# score list flexim std is 0.21044500172138214
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [8], in <cell line: 1>()
# ----> 1 res = skopt.gp_minimize(lambda x: obj(params,x,simi_kind),SPACE,n_calls = 50,random_state = 44,n_jobs = -1)
#
# File ~/miniforge3/lib/python3.9/site-packages/skopt/optimizer/gp.py:259, in gp_minimize(func, dimensions, base_estimator, n_calls, n_random_starts, n_initial_points, initial_point_generator, acq_func, acq_optimizer, x0, y0, random_state, verbose, callback, n_points, n_restarts_optimizer, xi, kappa, noise, n_jobs, model_queue_size)
#     254 if base_estimator is None:
#     255     base_estimator = cook_estimator(
#     256         "GP", space=space, random_state=rng.randint(0, np.iinfo(np.int32).max),
#     257         noise=noise)
# --> 259 return base_minimize(
#     260     func, space, base_estimator=base_estimator,
#     261     acq_func=acq_func,
#     262     xi=xi, kappa=kappa, acq_optimizer=acq_optimizer, n_calls=n_calls,
#     263     n_points=n_points, n_random_starts=n_random_starts,
#     264     n_initial_points=n_initial_points,
#     265     initial_point_generator=initial_point_generator,
#     266     n_restarts_optimizer=n_restarts_optimizer,
#     267     x0=x0, y0=y0, random_state=rng, verbose=verbose,
#     268     callback=callback, n_jobs=n_jobs, model_queue_size=model_queue_size)
#
# File ~/miniforge3/lib/python3.9/site-packages/skopt/optimizer/base.py:299, in base_minimize(func, dimensions, base_estimator, n_calls, n_random_starts, n_initial_points, initial_point_generator, acq_func, acq_optimizer, x0, y0, random_state, verbose, callback, n_points, n_restarts_optimizer, xi, kappa, n_jobs, model_queue_size)
#     297 for n in range(n_calls):
#     298     next_x = optimizer.ask()
# --> 299     next_y = func(next_x)
#     300     result = optimizer.tell(next_x, next_y)
#     301     result.specs = specs
#
# Input In [8], in <lambda>(x)
# ----> 1 res = skopt.gp_minimize(lambda x: obj(params,x,simi_kind),SPACE,n_calls = 50,random_state = 44,n_jobs = -1)
#
# Input In [5], in obj(params, params_2, simi_kind)
#      12 emulate.sample()
#      13 emulate.load_parameter(params_2)
# ---> 14 emulate.__fetch__(simi_kind,params)
#      15 print("final accuracy is {}".format(emulate.final_accuracy))
#      16 print("accuracy threshold is {}".format(emulate.similarity_threshold))
#
# File ~/Documents/Brown-CS-Research/research/Amir/ST500/emulate_st500_em_new_write_exac.py:491, in Emulate_TestD.__fetch__(self, num, params)
#     489 elif not self.f_fetch_done:
#     490     print("run first fetch")
# --> 491     self.__first_fetch__(num,params)
#     492 else:
#     493     print("run active learning fetch for current cluster")
#
# File ~/Documents/Brown-CS-Research/research/Amir/ST500/emulate_st500_em_new_write_exac.py:242, in Emulate_TestD.__first_fetch__(self, num, params)
#     240     self.alphas_counter += 1
#     241 self.f_fetch_done = True
# --> 242 self.__fetch__(num,params)
#
# File ~/Documents/Brown-CS-Research/research/Amir/ST500/emulate_st500_em_new_write_exac.py:494, in Emulate_TestD.__fetch__(self, num, params)
#     492 else:
#     493     print("run active learning fetch for current cluster")
# --> 494     self.__active_fetch__(num,params)
#
# File ~/Documents/Brown-CS-Research/research/Amir/ST500/emulate_st500_em_new_write_exac.py:176, in Emulate_TestD.__active_fetch__(self, num, params)
#     174 print("query time is {}".format(self.active_lr.query_time))
#     175 print("first stage total query time is {}".format(self.total_query_time))
# --> 176 self.__fetch__(num,params)
#
# File ~/Documents/Brown-CS-Research/research/Amir/ST500/emulate_st500_em_new_write_exac.py:488, in Emulate_TestD.__fetch__(self, num, params)
#     486         self.resample()
#     487         self.__init_lin__()
# --> 488         self.__restart_fetch__(num,params)
#     489 elif not self.f_fetch_done:
#     490     print("run first fetch")
#
# File ~/Documents/Brown-CS-Research/research/Amir/ST500/emulate_st500_em_new_write_exac.py:126, in Emulate_TestD.__restart_fetch__(self, num, params)
#     124 self.f_fetch_done = False
#     125 self.unlabled = None
# --> 126 self.__fetch__(num,params)
#
# File ~/Documents/Brown-CS-Research/research/Amir/ST500/emulate_st500_em_new_write_exac.py:491, in Emulate_TestD.__fetch__(self, num, params)
#     489 elif not self.f_fetch_done:
#     490     print("run first fetch")
# --> 491     self.__first_fetch__(num,params)
#     492 else:
#     493     print("run active learning fetch for current cluster")
#
# File ~/Documents/Brown-CS-Research/research/Amir/ST500/emulate_st500_em_new_write_exac.py:242, in Emulate_TestD.__first_fetch__(self, num, params)
#     240     self.alphas_counter += 1
#     241 self.f_fetch_done = True
# --> 242 self.__fetch__(num,params)
#
# File ~/Documents/Brown-CS-Research/research/Amir/ST500/emulate_st500_em_new_write_exac.py:494, in Emulate_TestD.__fetch__(self, num, params)
#     492 else:
#     493     print("run active learning fetch for current cluster")
# --> 494     self.__active_fetch__(num,params)
#
# File ~/Documents/Brown-CS-Research/research/Amir/ST500/emulate_st500_em_new_write_exac.py:176, in Emulate_TestD.__active_fetch__(self, num, params)
#     174 print("query time is {}".format(self.active_lr.query_time))
#     175 print("first stage total query time is {}".format(self.total_query_time))
# --> 176 self.__fetch__(num,params)
#
# File ~/Documents/Brown-CS-Research/research/Amir/ST500/emulate_st500_em_new_write_exac.py:488, in Emulate_TestD.__fetch__(self, num, params)
#     486         self.resample()
#     487         self.__init_lin__()
# --> 488         self.__restart_fetch__(num,params)
#     489 elif not self.f_fetch_done:
#     490     print("run first fetch")
#
# File ~/Documents/Brown-CS-Research/research/Amir/ST500/emulate_st500_em_new_write_exac.py:126, in Emulate_TestD.__restart_fetch__(self, num, params)
#     124 self.f_fetch_done = False
#     125 self.unlabled = None
# --> 126 self.__fetch__(num,params)
#
# File ~/Documents/Brown-CS-Research/research/Amir/ST500/emulate_st500_em_new_write_exac.py:491, in Emulate_TestD.__fetch__(self, num, params)
#     489 elif not self.f_fetch_done:
#     490     print("run first fetch")
# --> 491     self.__first_fetch__(num,params)
#     492 else:
#     493     print("run active learning fetch for current cluster")
#
# File ~/Documents/Brown-CS-Research/research/Amir/ST500/emulate_st500_em_new_write_exac.py:242, in Emulate_TestD.__first_fetch__(self, num, params)
#     240     self.alphas_counter += 1
#     241 self.f_fetch_done = True
# --> 242 self.__fetch__(num,params)
#
# File ~/Documents/Brown-CS-Research/research/Amir/ST500/emulate_st500_em_new_write_exac.py:494, in Emulate_TestD.__fetch__(self, num, params)
#     492 else:
#     493     print("run active learning fetch for current cluster")
# --> 494     self.__active_fetch__(num,params)
#
# File ~/Documents/Brown-CS-Research/research/Amir/ST500/emulate_st500_em_new_write_exac.py:176, in Emulate_TestD.__active_fetch__(self, num, params)
#     174 print("query time is {}".format(self.active_lr.query_time))
#     175 print("first stage total query time is {}".format(self.total_query_time))
# --> 176 self.__fetch__(num,params)
#
# File ~/Documents/Brown-CS-Research/research/Amir/ST500/emulate_st500_em_new_write_exac.py:476, in Emulate_TestD.__fetch__(self, num, params)
#     456 self.neural_network_train(transform_label_train_flexim[:, 0:-1], transform_label_train_flexim[:, -1], (transform_label_valid_flexim[:, 0:-1], transform_label_valid_flexim[:,-1]), class_weight=class_weight_flexim)
#     457 #self.logistic_regression(transform_label_train_flexim[:,0:-1],transform_label_train_flexim[:,-1],(transform_label_valid_flexim[:,0:-1],transform_label_valid_flexim[:,-1]), class_weight=class_weight_flexim)
#     458
#     459 # neg = transform_label_train[transform_label_train[:, -1] < 0.5].shape[0]
#    (...)
#     473 #     transform_label_train[:, 0:-1], transform_label_train[:, -1], (transform_label_valid[:, 0:-1], transform_label_valid[:, -1]), class_weight=class_weight)
#     474 #print("change to regression")
# --> 476 self.validate_result(transform_label_valid_score[:,0:-1],num,file)
#     477 #test_complex = np.delete(test_complex,problem_list_test,axis = 0)
#     478 test_data, problem_index_list = self.gen_complex_active_data(test_complex)
#
# File ~/Documents/Brown-CS-Research/research/Amir/ST500/emulate_st500_em_new_write_exac.py:504, in Emulate_TestD.validate_result(self, validate_data, simi_kind, writefile)
#     502 print("score list flexim min and max is {} {}".format(np.min(score_list_flexim),np.max(score_list_flexim)))
#     503 print("score list flexim std is {}".format(np.std(score_list_flexim)))
# --> 504 score_list_mreal = np.round_(self.neural_network_real_predict(validate_data)[:,0],3)
#     505 score_list_mreal = scaler.fit_transform(
#     506         score_list_mreal.reshape(-1, 1))
#     507 print("score list mreal min and max is {} {}".format(np.min(score_list_mreal),np.max(score_list_mreal)))
#
# File ~/Documents/Brown-CS-Research/research/Amir/ST500/emulate_st500_em_new_write_exac.py:1455, in Emulate_TestD.neural_network_real_predict(self, X)
#    1454 def neural_network_real_predict(self,X):
# -> 1455     similarity_score_real = self.neural_network_real.nn_predict(X)
#    1456     return similarity_score_real
#
# AttributeError: 'Emulate_TestD' object has no attribute 'neural_network_real'
