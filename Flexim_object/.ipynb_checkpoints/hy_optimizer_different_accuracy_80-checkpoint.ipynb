# %%
import pandas as pd
data = pd.read_csv("./"+"all_stocks_5yr.csv",index_col = None)
data = data["close"].values

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
data = scaler.fit_transform(data.reshape(-1,1))

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import skopt
from scikeras.wrappers import KerasClassifier
import tensorflow as tf
from modAL.batch import uncertainty_batch_sampling
#from Active_Emulate_TestD_gp import Active_Emulate_Test as ace
#from NN import NN as nn
from keras.utils.np_utils import to_categorical
from sklearn.preprocessing import MinMaxScaler
from dtaidistance import dtw
from numpy import dot
from numpy.linalg import norm
import sys
from sklearn.utils import shuffle
import copy
import emulate_st500_em_new_write_exac as et
import importlib
import Active_Emulate_st500_em_new_exac as at

# %%
parameter_directory = "all_stocks_5yr"
file = open("./"+parameter_directory+".txt","r")
lines = file.readlines()
sample_size = int(lines[0].strip('\n'))
simi_kind = 3
cluster_number = int(lines[2].strip('\n'))
similarity_threshold = 0.8

# %%
et = importlib.reload(et)
at = importlib.reload(at)

# %%
#emulate single new
def obj(params,params_2,simi_kind):
    print("simi_kind is {}".format(simi_kind))
    emulate = et.Emulate_TestD(data,parameter_directory,simi_kind,cluster_number,sample_size,similarity_threshold)
    emulate.load_encoder_model(parameter_directory)
    emulate.load_kmeans_model(parameter_directory)
    emulate.__init_lin__()
    emulate.__init_both_cluster_directory__(cluster_number)
    emulate.__init_limit_dictionary__()
    emulate.add_cluster_dict()
    emulate.get_max_distance(instance_number = 30000)
    emulate.sample()
    emulate.load_parameter(params_2)
    emulate.__fetch__(simi_kind,params)
    print("final accuracy is {}".format(emulate.final_accuracy))
    print("accuracy threshold is {}".format(emulate.similarity_threshold))
    print('#######################################################################################')
    return emulate.wasserstein_distance_flexim

# %%
params = [-2.16,6,9]

# %%
SPACE = [
   skopt.space.Integer(1,50,name = 'gamma 1'),
   skopt.space.Real(0,1,name = 'label_smoothing'),
   skopt.space.Integer(0,50,name = 'gamma 2'),
   skopt.space.Real(0,1,name = 'label_smoothing 2')
]

# %%
res = skopt.gp_minimize(lambda x: obj(params,x,simi_kind),SPACE,n_calls = 50,random_state = 44,n_jobs = None)
# Out:
# simi_kind is 3
# Metal device set to: Apple M1 Max
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# 2022-10-25 18:15:34.400367: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2022-10-25 18:15:34.400538: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# length of distance list is 30000
# self.max_distance is 13.016
# random value is 40
# start point is 395718
# has already got sample
# self.training_done is False
# simi kind is 3
# run first fetch
# new1
# 1 binary fetch
# self.training_done is False
# simi kind is 3
# run active learning fetch for current cluster
# generate naive complex alpha parameter
# finish generating naive parameters for current cluster
# finish generating naive parameters for current cluster
# initial active learner model
# active learning keras model run
# gamma is 22
# label smoothing is 0.031774802093509365
# batch size is 5
# active learning keras model run
# gamma is 0
# label smoothing is 0
# 2022-10-25 18:15:35.685175: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2022-10-25 18:15:35.861548: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 3/3 [==============================] - 0s 22ms/step - loss: 2.5499e-07 - accuracy: 0.5000
# 5/5 [==============================] - 0s 9ms/step - loss: 1.8081e-07 - accuracy: 0.5250
# accuracy threshold is 0.8
# run into active learning emulate process
# 1/1 [==============================] - 0s 46ms/step
# active learning initial score is 0.571
# emulate train unlabel shape is (192, 9)
# query instance shape is (48, 9)
# query instance shape is (44, 9)
# transform result shape is (44, 100)
# 6/6 [==============================] - 0s 2ms/step
# query instance shape is (5, 9)
# query instance shape is (3, 9)
# transform result shape is (3, 100)
# train
# 1/6 [====>.........................] - ETA: 0s - loss: 2.0134e-07 - accuracy: 0.5312
# 2022-10-25 18:15:36.233218: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 6/6 [==============================] - 0s 20ms/step - loss: 1.8337e-07 - accuracy: 0.6012
# 2/2 [==============================] - 0s 10ms/step
# 1 time active learning score is 0.5
# 6/6 [==============================] - 0s 3ms/step
# query instance shape is (5, 9)
# query instance shape is (3, 9)
# transform result shape is (3, 100)
# train
# 6/6 [==============================] - 0s 14ms/step - loss: 1.6482e-07 - accuracy: 0.6024
# 2/2 [==============================] - 0s 5ms/step
# 2 time active learning score is 0.409
# 6/6 [==============================] - 0s 4ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 6/6 [==============================] - 0s 14ms/step - loss: 1.5880e-07 - accuracy: 0.6608
# 2/2 [==============================] - 0s 3ms/step
# 3 time active learning score is 0.455
# 6/6 [==============================] - 0s 3ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 6/6 [==============================] - 0s 8ms/step - loss: 1.5191e-07 - accuracy: 0.7159
# 2/2 [==============================] - 0s 9ms/step
# 4 time active learning score is 0.477
# 6/6 [==============================] - 0s 6ms/step
# query instance shape is (5, 9)
# query instance shape is (4, 9)
# transform result shape is (4, 100)
# train
# 6/6 [==============================] - 0s 13ms/step - loss: 1.5022e-07 - accuracy: 0.6889
# 2/2 [==============================] - 0s 3ms/step
# 5 time active learning score is 0.523
# 6/6 [==============================] - 0s 4ms/step
# query instance shape is (5, 9)
# query instance shape is (3, 9)
# transform result shape is (3, 100)
# train
# 6/6 [==============================] - 0s 13ms/step - loss: 1.4677e-07 - accuracy: 0.7322
# 2/2 [==============================] - 0s 3ms/step
# 6 time active learning score is 0.432
# 6/6 [==============================] - 0s 3ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 6/6 [==============================] - 0s 13ms/step - loss: 1.4673e-07 - accuracy: 0.7128
# 2/2 [==============================] - 0s 3ms/step
# 7 time active learning score is 0.477
# 5/5 [==============================] - 0s 4ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 7/7 [==============================] - 0s 19ms/step - loss: 1.4375e-07 - accuracy: 0.7202
# 2/2 [==============================] - 0s 3ms/step
# 8 time active learning score is 0.477
# 5/5 [==============================] - 0s 4ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 7/7 [==============================] - 0s 8ms/step - loss: 1.5850e-07 - accuracy: 0.5808
# 2/2 [==============================] - 0s 3ms/step
# 9 time active learning score is 0.455
# 5/5 [==============================] - 0s 4ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 7/7 [==============================] - 0s 8ms/step - loss: 1.4765e-07 - accuracy: 0.6946
# 2/2 [==============================] - 0s 4ms/step
# 10 time active learning score is 0.455
# emulate process finishes
# query time is 10
# first stage total query time is 10
# self.training_done is True
# simi kind is 3
# run next cluster
# random value is 106
# start point is 36071
# has already resample
# self.training_done is False
# simi kind is 3
# run first fetch
# new1
# 2 binary fetch
# self.training_done is False
# simi kind is 3
# run active learning fetch for current cluster
# generate naive complex alpha parameter
# finish generating naive parameters for current cluster
# finish generating naive parameters for current cluster
# continue training active learner mdoel
# teach active learning model
# 9/9 [==============================] - 0s 11ms/step - loss: 1.5883e-07 - accuracy: 0.6219
# train unlabel shape is (192, 9)
# run into active learning emulate process
# 1/1 [==============================] - 0s 10ms/step
# active learning initial score is 0.81
# emulate train unlabel shape is (192, 9)
# query instance shape is (48, 9)
# query instance shape is (48, 9)
# transform result shape is (48, 100)
# 6/6 [==============================] - 0s 2ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 9/9 [==============================] - 0s 8ms/step - loss: 1.5280e-07 - accuracy: 0.6181
# 2/2 [==============================] - 0s 7ms/step
# 1 time active learning score is 0.5
# 6/6 [==============================] - 0s 2ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 10/10 [==============================] - 0s 10ms/step - loss: 1.4811e-07 - accuracy: 0.6689
# 2/2 [==============================] - 0s 4ms/step
# 2 time active learning score is 0.438
# 6/6 [==============================] - 0s 2ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 10/10 [==============================] - 0s 11ms/step - loss: 1.4379e-07 - accuracy: 0.7215
# 2/2 [==============================] - 0s 3ms/step
# 3 time active learning score is 0.417
# 6/6 [==============================] - 0s 2ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 10/10 [==============================] - 0s 12ms/step - loss: 1.4104e-07 - accuracy: 0.6931
# 2/2 [==============================] - 0s 7ms/step
# 4 time active learning score is 0.438
# 6/6 [==============================] - 0s 2ms/step
# query instance shape is (5, 9)
# query instance shape is (4, 9)
# transform result shape is (4, 100)
# train
# 10/10 [==============================] - 0s 11ms/step - loss: 1.3800e-07 - accuracy: 0.7068
# 2/2 [==============================] - 0s 5ms/step
# 5 time active learning score is 0.438
# 6/6 [==============================] - 0s 2ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 10/10 [==============================] - 0s 11ms/step - loss: 1.3611e-07 - accuracy: 0.7276
# 2/2 [==============================] - 0s 3ms/step
# 6 time active learning score is 0.479
# 6/6 [==============================] - 0s 3ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 10/10 [==============================] - 0s 14ms/step - loss: 1.3505e-07 - accuracy: 0.7508
# 2/2 [==============================] - 0s 3ms/step
# 7 time active learning score is 0.521
# 5/5 [==============================] - 0s 3ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 11/11 [==============================] - 0s 15ms/step - loss: 1.3445e-07 - accuracy: 0.7360
# 2/2 [==============================] - 0s 3ms/step
# 8 time active learning score is 0.5
# 5/5 [==============================] - 0s 2ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 11/11 [==============================] - 0s 13ms/step - loss: 1.3691e-07 - accuracy: 0.6697
# 2/2 [==============================] - 0s 3ms/step
# 9 time active learning score is 0.458
# 5/5 [==============================] - 0s 2ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 11/11 [==============================] - 0s 11ms/step - loss: 1.3319e-07 - accuracy: 0.7289
# 2/2 [==============================] - 0s 3ms/step
# 10 time active learning score is 0.479
# emulate process finishes
# query time is 10
# first stage total query time is 20
# self.training_done is True
# simi kind is 3
# run next cluster
# random value is 2
# start point is 70704
# has already resample
# self.training_done is False
# simi kind is 3
# run first fetch
# new1
# 3 binary fetch
# self.training_done is False
# simi kind is 3
# run active learning fetch for current cluster
# generate naive complex alpha parameter
# finish generating naive parameters for current cluster
# finish generating naive parameters for current cluster
# continue training active learner mdoel
# teach active learning model
# 13/13 [==============================] - 0s 9ms/step - loss: 1.4929e-07 - accuracy: 0.7039
# train unlabel shape is (192, 9)
# run into active learning emulate process
# 1/1 [==============================] - 0s 11ms/step
# active learning initial score is 0.571
# emulate train unlabel shape is (192, 9)
# query instance shape is (48, 9)
# query instance shape is (44, 9)
# transform result shape is (44, 100)
# 6/6 [==============================] - 0s 3ms/step
# query instance shape is (5, 9)
# query instance shape is (4, 9)
# transform result shape is (4, 100)
# train
# 13/13 [==============================] - 0s 11ms/step - loss: 1.3938e-07 - accuracy: 0.6875
# 2/2 [==============================] - 0s 4ms/step
# 1 time active learning score is 0.568
# 6/6 [==============================] - 0s 2ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 14/14 [==============================] - 0s 8ms/step - loss: 1.3492e-07 - accuracy: 0.7197
# 2/2 [==============================] - 0s 3ms/step
# 2 time active learning score is 0.523
# 6/6 [==============================] - 0s 3ms/step
# query instance shape is (5, 9)
# query instance shape is (3, 9)
# transform result shape is (3, 100)
# train
# 14/14 [==============================] - 0s 10ms/step - loss: 1.3370e-07 - accuracy: 0.7429
# 2/2 [==============================] - 0s 3ms/step
# 3 time active learning score is 0.455
# 6/6 [==============================] - 0s 3ms/step
# query instance shape is (5, 9)
# query instance shape is (3, 9)
# transform result shape is (3, 100)
# train
# 14/14 [==============================] - 0s 10ms/step - loss: 1.3232e-07 - accuracy: 0.7541
# 2/2 [==============================] - 0s 4ms/step
# 4 time active learning score is 0.5
# 6/6 [==============================] - 0s 3ms/step
# query instance shape is (5, 9)
# query instance shape is (3, 9)
# transform result shape is (3, 100)
# train
# 14/14 [==============================] - 0s 11ms/step - loss: 1.2730e-07 - accuracy: 0.7628
# 2/2 [==============================] - 0s 3ms/step
# 5 time active learning score is 0.545
# 6/6 [==============================] - 0s 3ms/step
# query instance shape is (5, 9)
# query instance shape is (3, 9)
# transform result shape is (3, 100)
# train
# 14/14 [==============================] - 0s 11ms/step - loss: 1.2561e-07 - accuracy: 0.7898
# 2/2 [==============================] - 0s 4ms/step
# 6 time active learning score is 0.545
# 6/6 [==============================] - 0s 3ms/step
# query instance shape is (5, 9)
# query instance shape is (4, 9)
# transform result shape is (4, 100)
# train
# 14/14 [==============================] - 0s 11ms/step - loss: 1.2513e-07 - accuracy: 0.7849
# 2/2 [==============================] - 0s 4ms/step
# 7 time active learning score is 0.477
# 5/5 [==============================] - 0s 3ms/step
# query instance shape is (5, 9)
# query instance shape is (4, 9)
# transform result shape is (4, 100)
# train
# 14/14 [==============================] - 0s 11ms/step - loss: 1.2578e-07 - accuracy: 0.7755
# 2/2 [==============================] - 0s 5ms/step
# 8 time active learning score is 0.568
# 5/5 [==============================] - 0s 4ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 14/14 [==============================] - 0s 12ms/step - loss: 1.2228e-07 - accuracy: 0.7780
# 2/2 [==============================] - 0s 4ms/step
# 9 time active learning score is 0.523
# 5/5 [==============================] - 0s 3ms/step
# query instance shape is (5, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# 15/15 [==============================] - 0s 12ms/step - loss: 1.2143e-07 - accuracy: 0.7982
# 2/2 [==============================] - 0s 8ms/step
# 10 time active learning score is 0.545
# emulate process finishes
# query time is 10
# first stage total query time is 30
# self.training_done is True
# simi kind is 3
# finish all cluster binary and active search
# make modification new new
# generate DTW naive positive and negative data
# length of next_result_table is 2
# result table shape is (9000, 101)
# (generator pid=8874) has change code 3
# (generator pid=8875) has change code 3
# (generator pid=8872) has change code 3
# (generator pid=8871) has change code 3
# (generator pid=8873) has change code 3

# %%
res.fun
# Out:
# -0.62

# %%
res.x
# Out:
# [10, 0.7337549548100735]
# *** SIGTERM received at time=1666145553 ***
# PC: @        0x1a6dc8c20  (unknown)  kevent
# [2022-10-18 22:12:33,278 E 9558 1106218] logging.cc:325: *** SIGTERM received at time=1666145553 ***
# [2022-10-18 22:12:33,278 E 9558 1106218] logging.cc:325: PC: @        0x1a6dc8c20  (unknown)  kevent
# systemMemory: 32.00 GB
# maxCacheSize: 10.67 GB
