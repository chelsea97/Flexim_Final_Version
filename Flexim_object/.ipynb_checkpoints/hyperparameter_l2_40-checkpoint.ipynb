# %%
import pandas as pd
data = pd.read_csv("./"+"all_stocks_5yr.csv",index_col = None)
data = data["close"].values

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
data = scaler.fit_transform(data.reshape(-1,1))

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import skopt
from scikeras.wrappers import KerasClassifier
import tensorflow as tf
from modAL.batch import uncertainty_batch_sampling
#from Active_Emulate_TestD_gp import Active_Emulate_Test as ace
#from NN import NN as nn
from keras.utils.np_utils import to_categorical
from sklearn.preprocessing import MinMaxScaler
from dtaidistance import dtw
from numpy import dot
from numpy.linalg import norm
import sys
from sklearn.utils import shuffle
import copy
import emulate_st500_gp as et
import importlib
import Active_Emulate_TestD_st500_gp as at
import NN_st500_gp as nt

# %%
parameter_directory = "all_stocks_5yr"
file = open("./"+parameter_directory+".txt","r")
lines = file.readlines()
sample_size = int(lines[0].strip('\n'))
simi_kind = int(lines[1].strip('\n'))
cluster_number = int(lines[2].strip('\n'))

# %%
simi_kind = 1

# %%
#emulate single new
def obj(params,simi_kind):
    print("simi_kind is {}".format(simi_kind))
    emulate = et.Emulate_TestD(data,parameter_directory,simi_kind,cluster_number,sample_size)
    emulate.load_encoder_model(parameter_directory)
    emulate.load_kmeans_model(parameter_directory)
    emulate.__init_lin__()
    emulate.__init_both_cluster_directory__(cluster_number)
    emulate.__init_limit_dictionary__()
    emulate.add_cluster_dict()
    emulate.get_max_distance(instance_number = 30000)
    emulate.sample()
    emulate.__fetch__(simi_kind,params)
    print("total query time is {}".format(emulate.total_query_time))
    print("wass distance flexim is {}".format(emulate.wasserstein_distance_flexim))
    print('#######################################################################################')
    return 1000*max(emulate.total_query_sample - 40,0)+emulate.wasserstein_distance_flexim

# %%
SPACE = [
   skopt.space.Real(-4,-1,name = 'al learning rate'),
   skopt.space.Integer(1,10, name='lr unit'),
   skopt.space.Integer(1,10, name='sl unit'),
   skopt.space.Integer(1,40, name='gamma1'),
   skopt.space.Real(0, 0.7, name='label_smoothing1'),
    skopt.space.Integer(1,20,name = 'query batch size'),
   skopt.space.Integer(1, 20, name='alpha1'),
    skopt.space.Integer(1, 20, name='alpha2'),
    skopt.space.Integer(1,10, name='nn lr unit'),
   skopt.space.Integer(1,10, name='nn sl unit'),
    skopt.space.Real(-4,-1,name = 'nn learning rate'),
    skopt.space.Integer(1,40, name='gamma2'),
   skopt.space.Real(0, 0.7, name='label_smoothing2'),
]

# %%
res = skopt.gp_minimize(lambda x: obj(x,simi_kind),SPACE,n_calls = 50,random_state = 44,n_jobs = 2)
# Out:
# simi_kind is 1
# Metal device set to: Apple M1 Max
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# 2022-09-26 22:52:54.722317: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2022-09-26 22:52:54.722463: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# length of distance list is 30000
# self.max_distance is 13.016
# random value is 40
# start point is 395718
# has already got sample
# self.training_done is False
# simi kind is 1
# run first fetch
# new1
# 1 binary fetch
# self.training_done is False
# simi kind is 1
# run active learning fetch for current cluster
# run active fetch
# alpha is 14
# generate naive complex alpha parameter
# finish generating naive parameters for current cluster
# finish generating naive parameters for current cluster
# initial active learner model
# active learning keras model run
# gamma is 8
# label smoothing is 0.2074631491785263
# batch size is 6
# 2022-09-26 22:52:55.459884: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2022-09-26 22:52:55.617967: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 35/35 [==============================] - 1s 6ms/step - loss: 0.0051 - accuracy: 0.5161
# 70/70 [==============================] - 0s 5ms/step - loss: 0.0028 - accuracy: 0.5786
# run into active learning emulate process
# 9/9 [==============================] - 0s 3ms/step
# active learning initial score is 0.651
# emulate train unlabel shape is (2688, 9)
# query instance shape is (672, 9)
# query instance shape is (630, 9)
# transform result shape is (630, 100)
# 52/84 [=================>............] - ETA: 0s
# 2022-09-26 22:52:56.673634: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 84/84 [==============================] - 0s 2ms/step
# query instance shape is (6, 9)
# query instance shape is (3, 9)
# transform result shape is (3, 100)
# train
# X shape is (3, 9)
# Y shape is (3,)
#  8/71 [==>...........................] - ETA: 0s - loss: 0.0027 - accuracy: 0.6523
# 2022-09-26 22:52:57.107095: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 71/71 [==============================] - 1s 9ms/step - loss: 0.0027 - accuracy: 0.5867
# 20/20 [==============================] - 0s 2ms/step
# 1 time active learning score is 0.54
# 84/84 [==============================] - 0s 2ms/step
# query instance shape is (6, 9)
# query instance shape is (2, 9)
# transform result shape is (2, 100)
# train
# X shape is (2, 9)
# Y shape is (2,)
# 71/71 [==============================] - 1s 9ms/step - loss: 0.0026 - accuracy: 0.6316
# 20/20 [==============================] - 0s 2ms/step
# 2 time active learning score is 0.425
# 84/84 [==============================] - 0s 2ms/step
# query instance shape is (6, 9)
# query instance shape is (4, 9)
# transform result shape is (4, 100)
# train
# X shape is (4, 9)
# Y shape is (4,)
# 71/71 [==============================] - 1s 7ms/step - loss: 0.0025 - accuracy: 0.6847
# 20/20 [==============================] - 0s 2ms/step
# 3 time active learning score is 0.486
# 20/20 [==============================] - 0s 2ms/step
# 84/84 [==============================] - 0s 3ms/step
# query instance shape is (6, 9)
# query instance shape is (6, 9)
# transform result shape is (6, 100)
# train
# X shape is (6, 9)
# Y shape is (6,)
# 71/71 [==============================] - 1s 8ms/step - loss: 0.0024 - accuracy: 0.7206
# 20/20 [==============================] - 0s 2ms/step
# 4 time active learning score is 0.49
# 20/20 [==============================] - 0s 2ms/step
# 84/84 [==============================] - 0s 2ms/step
# query instance shape is (6, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# X shape is (5, 9)
# Y shape is (5,)
# 71/71 [==============================] - 0s 6ms/step - loss: 0.0022 - accuracy: 0.8111
# 20/20 [==============================] - 0s 2ms/step
# 5 time active learning score is 0.498
# 20/20 [==============================] - 0s 2ms/step
# 84/84 [==============================] - 0s 2ms/step
# query instance shape is (6, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# X shape is (5, 9)
# Y shape is (5,)
# 71/71 [==============================] - 0s 6ms/step - loss: 0.0019 - accuracy: 0.8653
# 20/20 [==============================] - 0s 2ms/step
# 6 time active learning score is 0.492
# 20/20 [==============================] - 0s 2ms/step
# 83/83 [==============================] - 0s 2ms/step
# query instance shape is (6, 9)
# query instance shape is (6, 9)
# transform result shape is (6, 100)
# train
# X shape is (6, 9)
# Y shape is (6,)
# 71/71 [==============================] - 0s 6ms/step - loss: 0.0016 - accuracy: 0.8842
# 20/20 [==============================] - 0s 2ms/step
# 7 time active learning score is 0.494
# 20/20 [==============================] - 0s 2ms/step
# 83/83 [==============================] - 0s 2ms/step
# query instance shape is (6, 9)
# query instance shape is (6, 9)
# transform result shape is (6, 100)
# train
# X shape is (6, 9)
# Y shape is (6,)
# 72/72 [==============================] - 0s 6ms/step - loss: 0.0014 - accuracy: 0.8964
# 20/20 [==============================] - 0s 1ms/step
# 8 time active learning score is 0.495
# 20/20 [==============================] - 0s 2ms/step
# 83/83 [==============================] - 0s 1ms/step
# query instance shape is (6, 9)
# query instance shape is (6, 9)
# transform result shape is (6, 100)
# train
# X shape is (6, 9)
# Y shape is (6,)
# 72/72 [==============================] - 1s 7ms/step - loss: 0.0013 - accuracy: 0.9071
# 20/20 [==============================] - 0s 2ms/step
# 9 time active learning score is 0.484
# 20/20 [==============================] - 0s 2ms/step
# 83/83 [==============================] - 0s 3ms/step
# query instance shape is (6, 9)
# query instance shape is (6, 9)
# transform result shape is (6, 100)
# train
# X shape is (6, 9)
# Y shape is (6,)
# 72/72 [==============================] - 0s 6ms/step - loss: 0.0013 - accuracy: 0.9109
# 20/20 [==============================] - 0s 2ms/step
# 10 time active learning score is 0.487
# 20/20 [==============================] - 0s 2ms/step
# emulate process finishes
# query time is 10
# first stage total query time is 10
# self.training_done is True
# simi kind is 1
# run next cluster
# random value is 106
# start point is 36071
# has already resample
# self.training_done is False
# simi kind is 1
# run first fetch
# new1
# 2 binary fetch
# self.training_done is False
# simi kind is 1
# run active learning fetch for current cluster
# run active fetch
# alpha is 14
# generate naive complex alpha parameter
# finish generating naive parameters for current cluster
# finish generating naive parameters for current cluster
# continue training active learner mdoel
# teach active learning model
# 107/107 [==============================] - 1s 6ms/step - loss: 0.0012 - accuracy: 0.9111
# train unlabel shape is (2688, 9)
# run into active learning emulate process
# 9/9 [==============================] - 0s 2ms/step
# active learning initial score is 0.907
# emulate train unlabel shape is (2688, 9)
# query instance shape is (672, 9)
# query instance shape is (666, 9)
# transform result shape is (666, 100)
# 84/84 [==============================] - 0s 2ms/step
# query instance shape is (6, 9)
# query instance shape is (6, 9)
# transform result shape is (6, 100)
# train
# X shape is (6, 9)
# Y shape is (6,)
# 107/107 [==============================] - 1s 6ms/step - loss: 0.0011 - accuracy: 0.9145
# 21/21 [==============================] - 0s 2ms/step
# 1 time active learning score is 0.479
# 84/84 [==============================] - 0s 2ms/step
# query instance shape is (6, 9)
# query instance shape is (6, 9)
# transform result shape is (6, 100)
# train
# X shape is (6, 9)
# Y shape is (6,)
# 107/107 [==============================] - 1s 6ms/step - loss: 0.0011 - accuracy: 0.9144
# 21/21 [==============================] - 0s 2ms/step
# 2 time active learning score is 0.483
# 84/84 [==============================] - 0s 2ms/step
# query instance shape is (6, 9)
# query instance shape is (6, 9)
# transform result shape is (6, 100)
# train
# X shape is (6, 9)
# Y shape is (6,)
# 108/108 [==============================] - 1s 6ms/step - loss: 0.0011 - accuracy: 0.9090
# 21/21 [==============================] - 0s 2ms/step
# 3 time active learning score is 0.476
# 21/21 [==============================] - 0s 2ms/step
# 84/84 [==============================] - 0s 2ms/step
# query instance shape is (6, 9)
# query instance shape is (6, 9)
# transform result shape is (6, 100)
# train
# X shape is (6, 9)
# Y shape is (6,)
# 108/108 [==============================] - 1s 6ms/step - loss: 0.0011 - accuracy: 0.9158
# 21/21 [==============================] - 0s 2ms/step
# 4 time active learning score is 0.476
# 21/21 [==============================] - 0s 2ms/step
# 84/84 [==============================] - 0s 2ms/step
# query instance shape is (6, 9)
# query instance shape is (6, 9)
# transform result shape is (6, 100)
# train
# X shape is (6, 9)
# Y shape is (6,)
# 108/108 [==============================] - 1s 6ms/step - loss: 0.0011 - accuracy: 0.9229
# 21/21 [==============================] - 0s 2ms/step
# 5 time active learning score is 0.477
# 21/21 [==============================] - 0s 2ms/step
# 84/84 [==============================] - 0s 2ms/step
# query instance shape is (6, 9)
# query instance shape is (6, 9)
# transform result shape is (6, 100)
# train
# X shape is (6, 9)
# Y shape is (6,)
# 108/108 [==============================] - 1s 6ms/step - loss: 0.0011 - accuracy: 0.9167
# 21/21 [==============================] - 0s 2ms/step
# 6 time active learning score is 0.488
# 21/21 [==============================] - 0s 1ms/step
# 83/83 [==============================] - 0s 2ms/step
# query instance shape is (6, 9)
# query instance shape is (6, 9)
# transform result shape is (6, 100)
# train
# X shape is (6, 9)
# Y shape is (6,)
# 108/108 [==============================] - 1s 6ms/step - loss: 0.0011 - accuracy: 0.9223
# 21/21 [==============================] - 0s 2ms/step
# 7 time active learning score is 0.47
# 21/21 [==============================] - 0s 2ms/step
# 83/83 [==============================] - 0s 1ms/step
# query instance shape is (6, 9)
# query instance shape is (6, 9)
# transform result shape is (6, 100)
# train
# X shape is (6, 9)
# Y shape is (6,)
# 109/109 [==============================] - 1s 7ms/step - loss: 0.0011 - accuracy: 0.9219
# 21/21 [==============================] - 0s 2ms/step
# 8 time active learning score is 0.477
# 21/21 [==============================] - 0s 2ms/step
# 83/83 [==============================] - 0s 1ms/step
# query instance shape is (6, 9)
# query instance shape is (6, 9)
# transform result shape is (6, 100)
# train
# X shape is (6, 9)
# Y shape is (6,)
# 109/109 [==============================] - 1s 7ms/step - loss: 0.0010 - accuracy: 0.9220
# 21/21 [==============================] - 0s 2ms/step
# 9 time active learning score is 0.479
# 21/21 [==============================] - 0s 2ms/step
# 83/83 [==============================] - 0s 1ms/step
# query instance shape is (6, 9)
# query instance shape is (6, 9)
# transform result shape is (6, 100)
# train
# X shape is (6, 9)
# Y shape is (6,)
# 109/109 [==============================] - 1s 7ms/step - loss: 0.0010 - accuracy: 0.9164
# 21/21 [==============================] - 0s 2ms/step
# 10 time active learning score is 0.471
# 21/21 [==============================] - 0s 1ms/step
# 83/83 [==============================] - 0s 2ms/step
# query instance shape is (6, 9)
# query instance shape is (6, 9)
# transform result shape is (6, 100)
# train
# X shape is (6, 9)
# Y shape is (6,)
# 109/109 [==============================] - 1s 7ms/step - loss: 0.0011 - accuracy: 0.9128
# 21/21 [==============================] - 0s 2ms/step
# 11 time active learning score is 0.48
# 21/21 [==============================] - 0s 2ms/step
# 82/82 [==============================] - 0s 2ms/step
# query instance shape is (6, 9)
# query instance shape is (6, 9)
# transform result shape is (6, 100)
# train
# X shape is (6, 9)
# Y shape is (6,)
# 109/109 [==============================] - 1s 6ms/step - loss: 0.0010 - accuracy: 0.9161
# 21/21 [==============================] - 0s 2ms/step
# 12 time active learning score is 0.479
# 21/21 [==============================] - 0s 2ms/step
# 82/82 [==============================] - 0s 2ms/step
# query instance shape is (6, 9)
# query instance shape is (6, 9)
# transform result shape is (6, 100)
# train
# X shape is (6, 9)
# Y shape is (6,)
# 109/109 [==============================] - 1s 6ms/step - loss: 0.0011 - accuracy: 0.9148
# 21/21 [==============================] - 0s 2ms/step
# 13 time active learning score is 0.48
# 21/21 [==============================] - 0s 2ms/step
# 82/82 [==============================] - 0s 2ms/step
# query instance shape is (6, 9)
# query instance shape is (6, 9)
# transform result shape is (6, 100)
# train
# X shape is (6, 9)
# Y shape is (6,)
# 110/110 [==============================] - 1s 7ms/step - loss: 0.0010 - accuracy: 0.9196
# 21/21 [==============================] - 0s 2ms/step
# 14 time active learning score is 0.485
# 21/21 [==============================] - 0s 2ms/step
# 82/82 [==============================] - 0s 3ms/step
# query instance shape is (6, 9)
# query instance shape is (6, 9)
# transform result shape is (6, 100)
# train
# X shape is (6, 9)
# Y shape is (6,)
# 110/110 [==============================] - 1s 7ms/step - loss: 0.0011 - accuracy: 0.9148
# 21/21 [==============================] - 0s 2ms/step
# 15 time active learning score is 0.482
# 21/21 [==============================] - 0s 2ms/step
# 82/82 [==============================] - 0s 2ms/step
# query instance shape is (6, 9)
# query instance shape is (6, 9)
# transform result shape is (6, 100)
# train
# X shape is (6, 9)
# Y shape is (6,)
# 110/110 [==============================] - 1s 7ms/step - loss: 0.0010 - accuracy: 0.9210
# 21/21 [==============================] - 0s 2ms/step
# 16 time active learning score is 0.485
# 21/21 [==============================] - 0s 2ms/step
# 81/81 [==============================] - 0s 2ms/step
# query instance shape is (6, 9)
# query instance shape is (6, 9)
# transform result shape is (6, 100)
# train
# X shape is (6, 9)
# Y shape is (6,)
# 110/110 [==============================] - 1s 7ms/step - loss: 0.0010 - accuracy: 0.9191
# 21/21 [==============================] - 0s 2ms/step
# 17 time active learning score is 0.471
# 21/21 [==============================] - 0s 2ms/step
# 81/81 [==============================] - 0s 2ms/step
# query instance shape is (6, 9)
# query instance shape is (6, 9)
# transform result shape is (6, 100)
# train
# X shape is (6, 9)
# Y shape is (6,)
# 110/110 [==============================] - 1s 7ms/step - loss: 0.0010 - accuracy: 0.9173
# 21/21 [==============================] - 0s 2ms/step
# 18 time active learning score is 0.479
# 21/21 [==============================] - 0s 2ms/step
# 81/81 [==============================] - 0s 2ms/step
# query instance shape is (6, 9)
# query instance shape is (6, 9)
# transform result shape is (6, 100)
# train
# X shape is (6, 9)
# Y shape is (6,)
# 111/111 [==============================] - 1s 6ms/step - loss: 0.0010 - accuracy: 0.9134
# 21/21 [==============================] - 0s 2ms/step
# 19 time active learning score is 0.477
# 21/21 [==============================] - 0s 2ms/step
# 81/81 [==============================] - 0s 2ms/step
# query instance shape is (6, 9)
# query instance shape is (6, 9)
# transform result shape is (6, 100)
# train
# X shape is (6, 9)
# Y shape is (6,)
# 111/111 [==============================] - 1s 7ms/step - loss: 0.0010 - accuracy: 0.9139
# 21/21 [==============================] - 0s 2ms/step
# 20 time active learning score is 0.485
# 21/21 [==============================] - 0s 2ms/step
# emulate process finishes
# query time is 20
# first stage total query time is 30
# self.training_done is True
# simi kind is 1
# run next cluster
# random value is 2
# start point is 70704
# has already resample
# self.training_done is False
# simi kind is 1
# run first fetch
# new1
# 3 binary fetch
# self.training_done is False
# simi kind is 1
# run active learning fetch for current cluster
# run active fetch
# alpha is 14
# generate naive complex alpha parameter
# finish generating naive parameters for current cluster
# finish generating naive parameters for current cluster
# continue training active learner mdoel
# teach active learning model
# 146/146 [==============================] - 1s 7ms/step - loss: 0.0012 - accuracy: 0.8903
# train unlabel shape is (2688, 9)
# run into active learning emulate process
# 9/9 [==============================] - 0s 2ms/step
# active learning initial score is 0.872
# emulate train unlabel shape is (2688, 9)
# query instance shape is (672, 9)
# query instance shape is (625, 9)
# transform result shape is (625, 100)
# 84/84 [==============================] - 0s 2ms/step
# query instance shape is (6, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# X shape is (5, 9)
# Y shape is (5,)
# 146/146 [==============================] - 1s 7ms/step - loss: 0.0011 - accuracy: 0.9121
# 20/20 [==============================] - 0s 2ms/step
# 1 time active learning score is 0.475
# 84/84 [==============================] - 0s 2ms/step
# query instance shape is (6, 9)
# query instance shape is (4, 9)
# transform result shape is (4, 100)
# train
# X shape is (4, 9)
# Y shape is (4,)
# 146/146 [==============================] - 1s 7ms/step - loss: 0.0010 - accuracy: 0.9193
# 20/20 [==============================] - 0s 2ms/step
# 2 time active learning score is 0.485
# 84/84 [==============================] - 0s 2ms/step
# query instance shape is (6, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# X shape is (5, 9)
# Y shape is (5,)
# 146/146 [==============================] - 1s 7ms/step - loss: 9.9993e-04 - accuracy: 0.9234
# 20/20 [==============================] - 0s 2ms/step
# 3 time active learning score is 0.483
# 20/20 [==============================] - 0s 2ms/step
# 84/84 [==============================] - 0s 2ms/step
# query instance shape is (6, 9)
# query instance shape is (3, 9)
# transform result shape is (3, 100)
# train
# X shape is (3, 9)
# Y shape is (3,)
# 146/146 [==============================] - 1s 7ms/step - loss: 0.0010 - accuracy: 0.9209
# 20/20 [==============================] - 0s 2ms/step
# 4 time active learning score is 0.488
# 20/20 [==============================] - 0s 2ms/step
# 84/84 [==============================] - 0s 2ms/step
# query instance shape is (6, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# X shape is (5, 9)
# Y shape is (5,)
# 146/146 [==============================] - 1s 7ms/step - loss: 9.9411e-04 - accuracy: 0.9201
# 20/20 [==============================] - 0s 2ms/step
# 5 time active learning score is 0.491
# 20/20 [==============================] - 0s 2ms/step
# 84/84 [==============================] - 0s 2ms/step
# query instance shape is (6, 9)
# query instance shape is (4, 9)
# transform result shape is (4, 100)
# train
# X shape is (4, 9)
# Y shape is (4,)
# 147/147 [==============================] - 1s 6ms/step - loss: 9.6576e-04 - accuracy: 0.9271
# 20/20 [==============================] - 0s 2ms/step
# 6 time active learning score is 0.498
# 20/20 [==============================] - 0s 2ms/step
# 83/83 [==============================] - 0s 2ms/step
# query instance shape is (6, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# X shape is (5, 9)
# Y shape is (5,)
# 147/147 [==============================] - 1s 7ms/step - loss: 9.9415e-04 - accuracy: 0.9224
# 20/20 [==============================] - 0s 2ms/step
# 7 time active learning score is 0.49
# 20/20 [==============================] - 0s 2ms/step
# 83/83 [==============================] - 0s 2ms/step
# query instance shape is (6, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# X shape is (5, 9)
# Y shape is (5,)
# 147/147 [==============================] - 1s 7ms/step - loss: 9.6515e-04 - accuracy: 0.9225
# 20/20 [==============================] - 0s 2ms/step
# 8 time active learning score is 0.498
# 20/20 [==============================] - 0s 2ms/step
# 83/83 [==============================] - 0s 2ms/step
# query instance shape is (6, 9)
# query instance shape is (6, 9)
# transform result shape is (6, 100)
# train
# X shape is (6, 9)
# Y shape is (6,)
# 147/147 [==============================] - 1s 6ms/step - loss: 9.6210e-04 - accuracy: 0.9198
# 20/20 [==============================] - 0s 2ms/step
# 9 time active learning score is 0.494
# 20/20 [==============================] - 0s 2ms/step
# 83/83 [==============================] - 0s 2ms/step
# query instance shape is (6, 9)
# query instance shape is (5, 9)
# transform result shape is (5, 100)
# train
# X shape is (5, 9)
# Y shape is (5,)
# 147/147 [==============================] - 1s 7ms/step - loss: 9.6055e-04 - accuracy: 0.9280
# 20/20 [==============================] - 0s 2ms/step
# 10 time active learning score is 0.494
# 20/20 [==============================] - 0s 2ms/step
# 83/83 [==============================] - 0s 2ms/step
# query instance shape is (6, 9)
# query instance shape is (6, 9)
# transform result shape is (6, 100)
# train
# X shape is (6, 9)
# Y shape is (6,)
# 147/147 [==============================] - 1s 7ms/step - loss: 9.5654e-04 - accuracy: 0.9275
# 20/20 [==============================] - 0s 2ms/step
# 11 time active learning score is 0.501
# 20/20 [==============================] - 0s 2ms/step
